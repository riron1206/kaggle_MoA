# %%
# !pwd
import sys
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
sys.executable
# Out:
# C:\Users\81908\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124\run_objective_3l
# 'c:\\users\\81908\\appdata\\local\\pypoetry\\cache\\virtualenvs\\tfgpu-ehdmne1y-py3.8\\scripts\\python.exe'

# %%
# tensorflow2.0 + kerasでGPUメモリの使用量を抑える方法(最小限だけ使うように設定)
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"

# %%
import sys
sys.path.append(r'C:\Users\81908\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124')
import moa_MLPs_funcs
# Out:
# Tensorflow version 2.3.1
# n_classes: 206

# %%
params = dict(
    activation="relu",
    denses=[1159, 960, 1811],
    drop_rates=[
        0.4914099166744246,
        0.18817607797795838,
        0.12542057776853896,
        0.20175242230280122,
    ],
)
model_type = "3l_v2"

# %%
oof_score, Y_pred = moa_MLPs_funcs.train_and_evaluate(model_type=model_type, params=params)
# Out:
# WARNING:tensorflow:From C:\Users\81908\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124\moa_MLPs_funcs.py:694: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass shuffle=True, random_state=0 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# 19/19 - 2s - loss: 0.7107 - binary_crossentropy: 0.7106 - val_loss: 0.6071 - val_binary_crossentropy: 0.6063
# Epoch 2/50
# 19/19 - 1s - loss: 0.2306 - binary_crossentropy: 0.2291 - val_loss: 0.0748 - val_binary_crossentropy: 0.0708
# Epoch 3/50
# 19/19 - 1s - loss: 0.0267 - binary_crossentropy: 0.0222 - val_loss: 0.0332 - val_binary_crossentropy: 0.0270
# Epoch 4/50
# 19/19 - 1s - loss: 0.0263 - binary_crossentropy: 0.0211 - val_loss: 0.0301 - val_binary_crossentropy: 0.0242
# Epoch 5/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0202 - val_loss: 0.0264 - val_binary_crossentropy: 0.0212
# Epoch 6/50
# 19/19 - 1s - loss: 0.0244 - binary_crossentropy: 0.0196 - val_loss: 0.0240 - val_binary_crossentropy: 0.0192
# Epoch 7/50
# 19/19 - 1s - loss: 0.0240 - binary_crossentropy: 0.0193 - val_loss: 0.0231 - val_binary_crossentropy: 0.0184
# Epoch 8/50
# 19/19 - 1s - loss: 0.0238 - binary_crossentropy: 0.0192 - val_loss: 0.0228 - val_binary_crossentropy: 0.0181
# Epoch 9/50
# 19/19 - 1s - loss: 0.0234 - binary_crossentropy: 0.0189 - val_loss: 0.0223 - val_binary_crossentropy: 0.0177
# Epoch 10/50
# 19/19 - 1s - loss: 0.0234 - binary_crossentropy: 0.0189 - val_loss: 0.0224 - val_binary_crossentropy: 0.0178
# Epoch 11/50
# 19/19 - 1s - loss: 0.0233 - binary_crossentropy: 0.0187 - val_loss: 0.0226 - val_binary_crossentropy: 0.0181
# Epoch 12/50
# 19/19 - 1s - loss: 0.0232 - binary_crossentropy: 0.0187 - val_loss: 0.0222 - val_binary_crossentropy: 0.0176
# Epoch 13/50
# 19/19 - 1s - loss: 0.0231 - binary_crossentropy: 0.0186 - val_loss: 0.0216 - val_binary_crossentropy: 0.0169
# Epoch 14/50
# 19/19 - 1s - loss: 0.0229 - binary_crossentropy: 0.0184 - val_loss: 0.0215 - val_binary_crossentropy: 0.0169
# Epoch 15/50
# 19/19 - 1s - loss: 0.0230 - binary_crossentropy: 0.0185 - val_loss: 0.0218 - val_binary_crossentropy: 0.0172
# Epoch 16/50
# 19/19 - 1s - loss: 0.0229 - binary_crossentropy: 0.0183 - val_loss: 0.0215 - val_binary_crossentropy: 0.0168
# Epoch 17/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0182 - val_loss: 0.0214 - val_binary_crossentropy: 0.0168
# Epoch 18/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0183 - val_loss: 0.0214 - val_binary_crossentropy: 0.0167
# Epoch 19/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 20/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0181 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 21/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0179 - val_loss: 0.0214 - val_binary_crossentropy: 0.0167
# Epoch 22/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0212 - val_binary_crossentropy: 0.0166
# Epoch 23/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0181 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 24/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0178 - val_loss: 0.0212 - val_binary_crossentropy: 0.0164
# Epoch 25/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0179 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 26/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0179 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 27/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0177 - val_loss: 0.0212 - val_binary_crossentropy: 0.0164
# Epoch 28/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0176 - val_loss: 0.0212 - val_binary_crossentropy: 0.0166
# Epoch 29/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0176 - val_loss: 0.0211 - val_binary_crossentropy: 0.0165
# Epoch 30/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0177 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 31/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0177 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 32/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0175 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 33/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0177 - val_loss: 0.0211 - val_binary_crossentropy: 0.0165
# Epoch 34/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0175 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 35/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0175 - val_loss: 0.0211 - val_binary_crossentropy: 0.0165
# Epoch 36/50
# 19/19 - 1s - loss: 0.0221 - binary_crossentropy: 0.0175 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 37/50
# 19/19 - 1s - loss: 0.0219 - binary_crossentropy: 0.0172 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 38/50
# 19/19 - 1s - loss: 0.0219 - binary_crossentropy: 0.0172 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 39/50
# 19/19 - 1s - loss: 0.0220 - binary_crossentropy: 0.0174 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 40/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0175 - val_loss: 0.0212 - val_binary_crossentropy: 0.0166
# Epoch 41/50
# 19/19 - 1s - loss: 0.0220 - binary_crossentropy: 0.0173 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 42/50
# 19/19 - 1s - loss: 0.0218 - binary_crossentropy: 0.0171 - val_loss: 0.0210 - val_binary_crossentropy: 0.0163
# Epoch 43/50
# 19/19 - 1s - loss: 0.0219 - binary_crossentropy: 0.0172 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 44/50
# 19/19 - 1s - loss: 0.0220 - binary_crossentropy: 0.0173 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 45/50
# 19/19 - 1s - loss: 0.0218 - binary_crossentropy: 0.0171 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 46/50
# 19/19 - 1s - loss: 0.0217 - binary_crossentropy: 0.0171 - val_loss: 0.0210 - val_binary_crossentropy: 0.0163
# Epoch 47/50
# 19/19 - 1s - loss: 0.0218 - binary_crossentropy: 0.0172 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 48/50
# 19/19 - 1s - loss: 0.0216 - binary_crossentropy: 0.0170 - val_loss: 0.0211 - val_binary_crossentropy: 0.0163
# Epoch 49/50
# 19/19 - 1s - loss: 0.0217 - binary_crossentropy: 0.0170 - val_loss: 0.0210 - val_binary_crossentropy: 0.0163
# Epoch 50/50
# 19/19 - 1s - loss: 0.0218 - binary_crossentropy: 0.0172 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# 19/19 - 1s - loss: 0.7128 - binary_crossentropy: 0.7127 - val_loss: 0.8600 - val_binary_crossentropy: 0.8598
# Epoch 2/50
# 19/19 - 1s - loss: 0.2416 - binary_crossentropy: 0.2402 - val_loss: 0.0361 - val_binary_crossentropy: 0.0315
# Epoch 3/50
# 19/19 - 1s - loss: 0.0269 - binary_crossentropy: 0.0224 - val_loss: 0.0323 - val_binary_crossentropy: 0.0258
# Epoch 4/50
# 19/19 - 1s - loss: 0.0262 - binary_crossentropy: 0.0210 - val_loss: 0.0276 - val_binary_crossentropy: 0.0216
# Epoch 5/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0203 - val_loss: 0.0259 - val_binary_crossentropy: 0.0206
# Epoch 6/50
# 19/19 - 1s - loss: 0.0244 - binary_crossentropy: 0.0197 - val_loss: 0.0253 - val_binary_crossentropy: 0.0205
# Epoch 7/50
# 19/19 - 1s - loss: 0.0239 - binary_crossentropy: 0.0193 - val_loss: 0.0226 - val_binary_crossentropy: 0.0179
# Epoch 8/50
# 19/19 - 1s - loss: 0.0237 - binary_crossentropy: 0.0191 - val_loss: 0.0224 - val_binary_crossentropy: 0.0177
# Epoch 9/50
# 19/19 - 1s - loss: 0.0236 - binary_crossentropy: 0.0191 - val_loss: 0.0221 - val_binary_crossentropy: 0.0174
# Epoch 10/50
# 19/19 - 1s - loss: 0.0234 - binary_crossentropy: 0.0189 - val_loss: 0.0219 - val_binary_crossentropy: 0.0172
# Epoch 11/50
# 19/19 - 1s - loss: 0.0233 - binary_crossentropy: 0.0187 - val_loss: 0.0218 - val_binary_crossentropy: 0.0171
# Epoch 12/50
# 19/19 - 1s - loss: 0.0232 - binary_crossentropy: 0.0187 - val_loss: 0.0216 - val_binary_crossentropy: 0.0169
# Epoch 13/50
# 19/19 - 1s - loss: 0.0231 - binary_crossentropy: 0.0186 - val_loss: 0.0215 - val_binary_crossentropy: 0.0168
# Epoch 14/50
# 19/19 - 1s - loss: 0.0230 - binary_crossentropy: 0.0185 - val_loss: 0.0214 - val_binary_crossentropy: 0.0168
# Epoch 15/50
# 19/19 - 1s - loss: 0.0229 - binary_crossentropy: 0.0184 - val_loss: 0.0215 - val_binary_crossentropy: 0.0168
# Epoch 16/50
# 19/19 - 1s - loss: 0.0230 - binary_crossentropy: 0.0184 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 17/50
# 19/19 - 1s - loss: 0.0229 - binary_crossentropy: 0.0183 - val_loss: 0.0214 - val_binary_crossentropy: 0.0168
# Epoch 18/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0182 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 19/50
# 19/19 - 1s - loss: 0.0229 - binary_crossentropy: 0.0183 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 20/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0182 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 21/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0179 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 22/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0211 - val_binary_crossentropy: 0.0163
# Epoch 23/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0181 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 24/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0180 - val_loss: 0.0211 - val_binary_crossentropy: 0.0165
# Epoch 25/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 26/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0179 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 27/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0178 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 28/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0211 - val_binary_crossentropy: 0.0165
# Epoch 29/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0210 - val_binary_crossentropy: 0.0163
# Epoch 30/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0210 - val_binary_crossentropy: 0.0163
# Epoch 31/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0209 - val_binary_crossentropy: 0.0162
# Epoch 32/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0176 - val_loss: 0.0209 - val_binary_crossentropy: 0.0162
# Epoch 33/50
# 19/19 - 1s - loss: 0.0220 - binary_crossentropy: 0.0173 - val_loss: 0.0209 - val_binary_crossentropy: 0.0162
# Epoch 34/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0177 - val_loss: 0.0212 - val_binary_crossentropy: 0.0166
# Epoch 35/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0176 - val_loss: 0.0209 - val_binary_crossentropy: 0.0162
# Epoch 36/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0176 - val_loss: 0.0210 - val_binary_crossentropy: 0.0162
# Epoch 37/50
# 19/19 - 1s - loss: 0.0221 - binary_crossentropy: 0.0174 - val_loss: 0.0210 - val_binary_crossentropy: 0.0163
# Epoch 38/50
# 19/19 - 1s - loss: 0.0219 - binary_crossentropy: 0.0173 - val_loss: 0.0209 - val_binary_crossentropy: 0.0161
# Epoch 39/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0175 - val_loss: 0.0210 - val_binary_crossentropy: 0.0163
# Epoch 40/50
# 19/19 - 1s - loss: 0.0221 - binary_crossentropy: 0.0174 - val_loss: 0.0209 - val_binary_crossentropy: 0.0161
# Epoch 41/50
# 19/19 - 1s - loss: 0.0218 - binary_crossentropy: 0.0171 - val_loss: 0.0209 - val_binary_crossentropy: 0.0162
# Epoch 42/50
# 19/19 - 1s - loss: 0.0219 - binary_crossentropy: 0.0172 - val_loss: 0.0208 - val_binary_crossentropy: 0.0161
# Epoch 43/50
# 19/19 - 1s - loss: 0.0219 - binary_crossentropy: 0.0173 - val_loss: 0.0208 - val_binary_crossentropy: 0.0161
# Epoch 44/50
# 19/19 - 1s - loss: 0.0218 - binary_crossentropy: 0.0171 - val_loss: 0.0208 - val_binary_crossentropy: 0.0161
# Epoch 45/50
# 19/19 - 1s - loss: 0.0219 - binary_crossentropy: 0.0173 - val_loss: 0.0209 - val_binary_crossentropy: 0.0161
# Epoch 46/50
# 19/19 - 1s - loss: 0.0218 - binary_crossentropy: 0.0172 - val_loss: 0.0208 - val_binary_crossentropy: 0.0161
# Epoch 47/50
# 19/19 - 1s - loss: 0.0219 - binary_crossentropy: 0.0172 - val_loss: 0.0208 - val_binary_crossentropy: 0.0161
# Epoch 48/50
# 19/19 - 1s - loss: 0.0218 - binary_crossentropy: 0.0171 - val_loss: 0.0209 - val_binary_crossentropy: 0.0162
# Epoch 49/50
# 19/19 - 1s - loss: 0.0219 - binary_crossentropy: 0.0172 - val_loss: 0.0208 - val_binary_crossentropy: 0.0161
# Epoch 50/50
# 19/19 - 1s - loss: 0.0217 - binary_crossentropy: 0.0170 - val_loss: 0.0208 - val_binary_crossentropy: 0.0161
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# 19/19 - 2s - loss: 0.7108 - binary_crossentropy: 0.7107 - val_loss: 0.8335 - val_binary_crossentropy: 0.8332
# Epoch 2/50
# 19/19 - 1s - loss: 0.2364 - binary_crossentropy: 0.2349 - val_loss: 0.0544 - val_binary_crossentropy: 0.0496
# Epoch 3/50
# 19/19 - 1s - loss: 0.0272 - binary_crossentropy: 0.0227 - val_loss: 0.0356 - val_binary_crossentropy: 0.0295
# Epoch 4/50
# 19/19 - 1s - loss: 0.0265 - binary_crossentropy: 0.0213 - val_loss: 0.0294 - val_binary_crossentropy: 0.0234
# Epoch 5/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0204 - val_loss: 0.0258 - val_binary_crossentropy: 0.0206
# Epoch 6/50
# 19/19 - 1s - loss: 0.0246 - binary_crossentropy: 0.0198 - val_loss: 0.0250 - val_binary_crossentropy: 0.0202
# Epoch 7/50
# 19/19 - 1s - loss: 0.0240 - binary_crossentropy: 0.0194 - val_loss: 0.0233 - val_binary_crossentropy: 0.0186
# Epoch 8/50
# 19/19 - 1s - loss: 0.0237 - binary_crossentropy: 0.0192 - val_loss: 0.0228 - val_binary_crossentropy: 0.0183
# Epoch 9/50
# 19/19 - 1s - loss: 0.0236 - binary_crossentropy: 0.0190 - val_loss: 0.0224 - val_binary_crossentropy: 0.0179
# Epoch 10/50
# 19/19 - 1s - loss: 0.0234 - binary_crossentropy: 0.0189 - val_loss: 0.0222 - val_binary_crossentropy: 0.0177
# Epoch 11/50
# 19/19 - 1s - loss: 0.0234 - binary_crossentropy: 0.0189 - val_loss: 0.0221 - val_binary_crossentropy: 0.0175
# Epoch 12/50
# 19/19 - 1s - loss: 0.0230 - binary_crossentropy: 0.0184 - val_loss: 0.0219 - val_binary_crossentropy: 0.0173
# Epoch 13/50
# 19/19 - 1s - loss: 0.0230 - binary_crossentropy: 0.0185 - val_loss: 0.0218 - val_binary_crossentropy: 0.0172
# Epoch 14/50
# 19/19 - 1s - loss: 0.0230 - binary_crossentropy: 0.0184 - val_loss: 0.0217 - val_binary_crossentropy: 0.0171
# Epoch 15/50
# 19/19 - 1s - loss: 0.0229 - binary_crossentropy: 0.0184 - val_loss: 0.0217 - val_binary_crossentropy: 0.0171
# Epoch 16/50
# 19/19 - 1s - loss: 0.0229 - binary_crossentropy: 0.0183 - val_loss: 0.0215 - val_binary_crossentropy: 0.0169
# Epoch 17/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0181 - val_loss: 0.0215 - val_binary_crossentropy: 0.0168
# Epoch 18/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0182 - val_loss: 0.0216 - val_binary_crossentropy: 0.0169
# Epoch 19/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0181 - val_loss: 0.0214 - val_binary_crossentropy: 0.0168
# Epoch 20/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0214 - val_binary_crossentropy: 0.0168
# Epoch 21/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0214 - val_binary_crossentropy: 0.0168
# Epoch 22/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0179 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 23/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0178 - val_loss: 0.0214 - val_binary_crossentropy: 0.0167
# Epoch 24/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0213 - val_binary_crossentropy: 0.0167
# Epoch 25/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0179 - val_loss: 0.0214 - val_binary_crossentropy: 0.0167
# Epoch 26/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0214 - val_binary_crossentropy: 0.0166
# Epoch 27/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0214 - val_binary_crossentropy: 0.0167
# Epoch 28/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0177 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 29/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0176 - val_loss: 0.0214 - val_binary_crossentropy: 0.0167
# Epoch 30/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0176 - val_loss: 0.0213 - val_binary_crossentropy: 0.0167
# Epoch 31/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0177 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 32/50
# 19/19 - 1s - loss: 0.0221 - binary_crossentropy: 0.0175 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 33/50
# 19/19 - 1s - loss: 0.0221 - binary_crossentropy: 0.0174 - val_loss: 0.0215 - val_binary_crossentropy: 0.0168
# Epoch 34/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0176 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 35/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0175 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 36/50
# 19/19 - 1s - loss: 0.0221 - binary_crossentropy: 0.0175 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 37/50
# 19/19 - 1s - loss: 0.0221 - binary_crossentropy: 0.0174 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 38/50
# 19/19 - 1s - loss: 0.0220 - binary_crossentropy: 0.0174 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 39/50
# 19/19 - 1s - loss: 0.0220 - binary_crossentropy: 0.0173 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 40/50
# 19/19 - 1s - loss: 0.0218 - binary_crossentropy: 0.0171 - val_loss: 0.0212 - val_binary_crossentropy: 0.0164
# Epoch 41/50
# 19/19 - 1s - loss: 0.0220 - binary_crossentropy: 0.0174 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 42/50
# 19/19 - 1s - loss: 0.0218 - binary_crossentropy: 0.0172 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 43/50
# 19/19 - 1s - loss: 0.0217 - binary_crossentropy: 0.0171 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 44/50
# 19/19 - 1s - loss: 0.0219 - binary_crossentropy: 0.0172 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 45/50
# 19/19 - 1s - loss: 0.0217 - binary_crossentropy: 0.0171 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 46/50
# 19/19 - 1s - loss: 0.0216 - binary_crossentropy: 0.0169 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 47/50
# 19/19 - 1s - loss: 0.0217 - binary_crossentropy: 0.0171 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 48/50
# 19/19 - 1s - loss: 0.0217 - binary_crossentropy: 0.0170 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 49/50
# 19/19 - 1s - loss: 0.0215 - binary_crossentropy: 0.0168 - val_loss: 0.0211 - val_binary_crossentropy: 0.0163
# Epoch 50/50
# 19/19 - 1s - loss: 0.0218 - binary_crossentropy: 0.0171 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# 19/19 - 2s - loss: 0.7133 - binary_crossentropy: 0.7132 - val_loss: 0.8458 - val_binary_crossentropy: 0.8455
# Epoch 2/50
# 19/19 - 1s - loss: 0.2423 - binary_crossentropy: 0.2409 - val_loss: 0.0555 - val_binary_crossentropy: 0.0512
# Epoch 3/50
# 19/19 - 1s - loss: 0.0269 - binary_crossentropy: 0.0223 - val_loss: 0.0352 - val_binary_crossentropy: 0.0288
# Epoch 4/50
# 19/19 - 1s - loss: 0.0264 - binary_crossentropy: 0.0212 - val_loss: 0.0300 - val_binary_crossentropy: 0.0240
# Epoch 5/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0203 - val_loss: 0.0258 - val_binary_crossentropy: 0.0205
# Epoch 6/50
# 19/19 - 1s - loss: 0.0244 - binary_crossentropy: 0.0196 - val_loss: 0.0242 - val_binary_crossentropy: 0.0194
# Epoch 7/50
# 19/19 - 1s - loss: 0.0239 - binary_crossentropy: 0.0193 - val_loss: 0.0234 - val_binary_crossentropy: 0.0187
# Epoch 8/50
# 19/19 - 1s - loss: 0.0237 - binary_crossentropy: 0.0192 - val_loss: 0.0228 - val_binary_crossentropy: 0.0181
# Epoch 9/50
# 19/19 - 1s - loss: 0.0235 - binary_crossentropy: 0.0190 - val_loss: 0.0226 - val_binary_crossentropy: 0.0179
# Epoch 10/50
# 19/19 - 1s - loss: 0.0235 - binary_crossentropy: 0.0190 - val_loss: 0.0223 - val_binary_crossentropy: 0.0176
# Epoch 11/50
# 19/19 - 1s - loss: 0.0233 - binary_crossentropy: 0.0187 - val_loss: 0.0222 - val_binary_crossentropy: 0.0174
# Epoch 12/50
# 19/19 - 1s - loss: 0.0232 - binary_crossentropy: 0.0187 - val_loss: 0.0219 - val_binary_crossentropy: 0.0172
# Epoch 13/50
# 19/19 - 1s - loss: 0.0232 - binary_crossentropy: 0.0187 - val_loss: 0.0218 - val_binary_crossentropy: 0.0172
# Epoch 14/50
# 19/19 - 1s - loss: 0.0230 - binary_crossentropy: 0.0185 - val_loss: 0.0218 - val_binary_crossentropy: 0.0171
# Epoch 15/50
# 19/19 - 1s - loss: 0.0229 - binary_crossentropy: 0.0184 - val_loss: 0.0219 - val_binary_crossentropy: 0.0172
# Epoch 16/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0183 - val_loss: 0.0216 - val_binary_crossentropy: 0.0169
# Epoch 17/50
# 19/19 - 1s - loss: 0.0229 - binary_crossentropy: 0.0183 - val_loss: 0.0215 - val_binary_crossentropy: 0.0168
# Epoch 18/50
# 19/19 - 1s - loss: 0.0229 - binary_crossentropy: 0.0183 - val_loss: 0.0216 - val_binary_crossentropy: 0.0168
# Epoch 19/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0214 - val_binary_crossentropy: 0.0167
# Epoch 20/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0183 - val_loss: 0.0214 - val_binary_crossentropy: 0.0167
# Epoch 21/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0213 - val_binary_crossentropy: 0.0167
# Epoch 22/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0213 - val_binary_crossentropy: 0.0167
# Epoch 23/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0214 - val_binary_crossentropy: 0.0168
# Epoch 24/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0179 - val_loss: 0.0214 - val_binary_crossentropy: 0.0167
# Epoch 25/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 26/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0176 - val_loss: 0.0214 - val_binary_crossentropy: 0.0167
# Epoch 27/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 28/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0178 - val_loss: 0.0215 - val_binary_crossentropy: 0.0167
# Epoch 29/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0175 - val_loss: 0.0215 - val_binary_crossentropy: 0.0167
# Epoch 30/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0176 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 31/50
# 19/19 - 1s - loss: 0.0220 - binary_crossentropy: 0.0174 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 32/50
# 19/19 - 1s - loss: 0.0219 - binary_crossentropy: 0.0173 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 33/50
# 19/19 - 1s - loss: 0.0221 - binary_crossentropy: 0.0175 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 34/50
# 19/19 - 1s - loss: 0.0220 - binary_crossentropy: 0.0173 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 35/50
# 19/19 - 1s - loss: 0.0221 - binary_crossentropy: 0.0175 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 36/50
# 19/19 - 1s - loss: 0.0218 - binary_crossentropy: 0.0172 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 37/50
# 19/19 - 1s - loss: 0.0220 - binary_crossentropy: 0.0174 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 38/50
# 19/19 - 1s - loss: 0.0221 - binary_crossentropy: 0.0174 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 39/50
# 19/19 - 1s - loss: 0.0220 - binary_crossentropy: 0.0174 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 40/50
# 19/19 - 1s - loss: 0.0220 - binary_crossentropy: 0.0173 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 41/50
# 19/19 - 1s - loss: 0.0220 - binary_crossentropy: 0.0174 - val_loss: 0.0211 - val_binary_crossentropy: 0.0165
# Epoch 42/50
# 19/19 - 1s - loss: 0.0217 - binary_crossentropy: 0.0171 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 43/50
# 19/19 - 1s - loss: 0.0216 - binary_crossentropy: 0.0170 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 44/50
# 19/19 - 1s - loss: 0.0219 - binary_crossentropy: 0.0173 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 45/50
# 19/19 - 1s - loss: 0.0218 - binary_crossentropy: 0.0171 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 46/50
# 19/19 - 1s - loss: 0.0216 - binary_crossentropy: 0.0169 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 47/50
# 19/19 - 1s - loss: 0.0218 - binary_crossentropy: 0.0172 - val_loss: 0.0212 - val_binary_crossentropy: 0.0164
# Epoch 48/50
# 19/19 - 1s - loss: 0.0217 - binary_crossentropy: 0.0171 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 49/50
# 19/19 - 1s - loss: 0.0216 - binary_crossentropy: 0.0169 - val_loss: 0.0211 - val_binary_crossentropy: 0.0163
# Epoch 50/50
# 19/19 - 1s - loss: 0.0217 - binary_crossentropy: 0.0171 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# 19/19 - 1s - loss: 0.7106 - binary_crossentropy: 0.7106 - val_loss: 0.6281 - val_binary_crossentropy: 0.6275
# Epoch 2/50
# 19/19 - 1s - loss: 0.2421 - binary_crossentropy: 0.2406 - val_loss: 0.0504 - val_binary_crossentropy: 0.0463
# Epoch 3/50
# 19/19 - 1s - loss: 0.0269 - binary_crossentropy: 0.0224 - val_loss: 0.0313 - val_binary_crossentropy: 0.0253
# Epoch 4/50
# 19/19 - 1s - loss: 0.0266 - binary_crossentropy: 0.0214 - val_loss: 0.0279 - val_binary_crossentropy: 0.0220
# Epoch 5/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0204 - val_loss: 0.0262 - val_binary_crossentropy: 0.0210
# Epoch 6/50
# 19/19 - 1s - loss: 0.0244 - binary_crossentropy: 0.0196 - val_loss: 0.0239 - val_binary_crossentropy: 0.0192
# Epoch 7/50
# 19/19 - 1s - loss: 0.0240 - binary_crossentropy: 0.0193 - val_loss: 0.0231 - val_binary_crossentropy: 0.0185
# Epoch 8/50
# 19/19 - 1s - loss: 0.0238 - binary_crossentropy: 0.0193 - val_loss: 0.0225 - val_binary_crossentropy: 0.0179
# Epoch 9/50
# 19/19 - 1s - loss: 0.0236 - binary_crossentropy: 0.0191 - val_loss: 0.0223 - val_binary_crossentropy: 0.0177
# Epoch 10/50
# 19/19 - 1s - loss: 0.0233 - binary_crossentropy: 0.0188 - val_loss: 0.0218 - val_binary_crossentropy: 0.0172
# Epoch 11/50
# 19/19 - 1s - loss: 0.0234 - binary_crossentropy: 0.0189 - val_loss: 0.0218 - val_binary_crossentropy: 0.0171
# Epoch 12/50
# 19/19 - 1s - loss: 0.0232 - binary_crossentropy: 0.0187 - val_loss: 0.0216 - val_binary_crossentropy: 0.0170
# Epoch 13/50
# 19/19 - 1s - loss: 0.0233 - binary_crossentropy: 0.0188 - val_loss: 0.0226 - val_binary_crossentropy: 0.0180
# Epoch 14/50
# 19/19 - 1s - loss: 0.0233 - binary_crossentropy: 0.0187 - val_loss: 0.0216 - val_binary_crossentropy: 0.0170
# Epoch 15/50
# 19/19 - 1s - loss: 0.0230 - binary_crossentropy: 0.0185 - val_loss: 0.0214 - val_binary_crossentropy: 0.0167
# Epoch 16/50
# 19/19 - 1s - loss: 0.0229 - binary_crossentropy: 0.0183 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 17/50
# 19/19 - 1s - loss: 0.0229 - binary_crossentropy: 0.0183 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 18/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0182 - val_loss: 0.0211 - val_binary_crossentropy: 0.0165
# Epoch 19/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0181 - val_loss: 0.0210 - val_binary_crossentropy: 0.0164
# Epoch 20/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0182 - val_loss: 0.0210 - val_binary_crossentropy: 0.0164
# Epoch 21/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 22/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0181 - val_loss: 0.0211 - val_binary_crossentropy: 0.0165
# Epoch 23/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0179 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 24/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0210 - val_binary_crossentropy: 0.0163
# Epoch 25/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0179 - val_loss: 0.0209 - val_binary_crossentropy: 0.0163
# Epoch 26/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0209 - val_binary_crossentropy: 0.0163
# Epoch 27/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0179 - val_loss: 0.0209 - val_binary_crossentropy: 0.0163
# Epoch 28/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 29/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0175 - val_loss: 0.0208 - val_binary_crossentropy: 0.0160
# Epoch 30/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0176 - val_loss: 0.0209 - val_binary_crossentropy: 0.0162
# Epoch 31/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0177 - val_loss: 0.0209 - val_binary_crossentropy: 0.0161
# Epoch 32/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0177 - val_loss: 0.0208 - val_binary_crossentropy: 0.0161
# Epoch 33/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0208 - val_binary_crossentropy: 0.0160
# Epoch 34/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0208 - val_binary_crossentropy: 0.0161
# Epoch 35/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0177 - val_loss: 0.0208 - val_binary_crossentropy: 0.0162
# Epoch 36/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0176 - val_loss: 0.0208 - val_binary_crossentropy: 0.0161
# Epoch 37/50
# 19/19 - 1s - loss: 0.0221 - binary_crossentropy: 0.0174 - val_loss: 0.0208 - val_binary_crossentropy: 0.0161
# Epoch 38/50
# 19/19 - 1s - loss: 0.0220 - binary_crossentropy: 0.0173 - val_loss: 0.0207 - val_binary_crossentropy: 0.0160
# Epoch 39/50
# 19/19 - 1s - loss: 0.0220 - binary_crossentropy: 0.0173 - val_loss: 0.0208 - val_binary_crossentropy: 0.0161
# Epoch 40/50
# 19/19 - 1s - loss: 0.0220 - binary_crossentropy: 0.0173 - val_loss: 0.0207 - val_binary_crossentropy: 0.0160
# Epoch 41/50
# 19/19 - 1s - loss: 0.0219 - binary_crossentropy: 0.0173 - val_loss: 0.0208 - val_binary_crossentropy: 0.0161
# Epoch 42/50
# 19/19 - 1s - loss: 0.0219 - binary_crossentropy: 0.0173 - val_loss: 0.0208 - val_binary_crossentropy: 0.0161
# Epoch 43/50
# 19/19 - 1s - loss: 0.0220 - binary_crossentropy: 0.0174 - val_loss: 0.0208 - val_binary_crossentropy: 0.0161
# Epoch 44/50
# 19/19 - 1s - loss: 0.0218 - binary_crossentropy: 0.0171 - val_loss: 0.0206 - val_binary_crossentropy: 0.0159
# Epoch 45/50
# 19/19 - 1s - loss: 0.0218 - binary_crossentropy: 0.0172 - val_loss: 0.0206 - val_binary_crossentropy: 0.0159
# Epoch 46/50
# 19/19 - 1s - loss: 0.0219 - binary_crossentropy: 0.0172 - val_loss: 0.0206 - val_binary_crossentropy: 0.0159
# Epoch 47/50
# 19/19 - 1s - loss: 0.0219 - binary_crossentropy: 0.0173 - val_loss: 0.0207 - val_binary_crossentropy: 0.0160
# Epoch 48/50
# 19/19 - 1s - loss: 0.0220 - binary_crossentropy: 0.0173 - val_loss: 0.0207 - val_binary_crossentropy: 0.0160
# Epoch 49/50
# 19/19 - 1s - loss: 0.0218 - binary_crossentropy: 0.0171 - val_loss: 0.0207 - val_binary_crossentropy: 0.0160
# Epoch 50/50
# 19/19 - 1s - loss: 0.0219 - binary_crossentropy: 0.0172 - val_loss: 0.0207 - val_binary_crossentropy: 0.0160
#
# oof_score: 0.01599063273188232
# oof_auc_score: 0.6776700131370303
# ----------------------------------------------------------------------------------------------------

# %%
oof_score
# Out:
# 0.01599063273188232
