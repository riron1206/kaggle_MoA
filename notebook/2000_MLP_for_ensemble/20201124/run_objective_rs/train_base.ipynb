# %%
# !pwd
import sys
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
sys.executable
# Out:
# C:\Users\81908\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124\run_objective_rs
# 'c:\\users\\81908\\appdata\\local\\pypoetry\\cache\\virtualenvs\\tfgpu-ehdmne1y-py3.8\\scripts\\python.exe'

# %%
# tensorflow2.0 + kerasでGPUメモリの使用量を抑える方法(最小限だけ使うように設定)
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"

# %%
import sys
sys.path.append(r'C:\Users\81908\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124')
import moa_MLPs_funcs
# Out:
# Tensorflow version 2.3.1
# n_classes: 206

# %%
params = dict(
    activations=["elu", "elu", "relu", "elu", "relu", "elu", "selu", "selu"],
    denses=[512, 256, 512, 512, 256, 256],
    drop_rates=[0.2, 0.3],
)
model_type = "rs"

# %%
oof_score, Y_pred = moa_MLPs_funcs.train_and_evaluate(model_type=model_type, params=params)
# Out:
# WARNING:tensorflow:From C:\Users\81908\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124\moa_MLPs_funcs.py:694: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass shuffle=True, random_state=0 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# 19/19 - 2s - loss: 0.7321 - binary_crossentropy: 0.7321 - val_loss: 1.4079 - val_binary_crossentropy: 1.4078
# Epoch 2/50
# 19/19 - 1s - loss: 0.3946 - binary_crossentropy: 0.3939 - val_loss: 0.6725 - val_binary_crossentropy: 0.6709
# Epoch 3/50
# 19/19 - 1s - loss: 0.0387 - binary_crossentropy: 0.0356 - val_loss: 0.0800 - val_binary_crossentropy: 0.0753
# Epoch 4/50
# 19/19 - 1s - loss: 0.0246 - binary_crossentropy: 0.0203 - val_loss: 0.0450 - val_binary_crossentropy: 0.0400
# Epoch 5/50
# 19/19 - 1s - loss: 0.0239 - binary_crossentropy: 0.0194 - val_loss: 0.0282 - val_binary_crossentropy: 0.0232
# Epoch 6/50
# 19/19 - 1s - loss: 0.0234 - binary_crossentropy: 0.0188 - val_loss: 0.0252 - val_binary_crossentropy: 0.0205
# Epoch 7/50
# 19/19 - 1s - loss: 0.0229 - binary_crossentropy: 0.0184 - val_loss: 0.0235 - val_binary_crossentropy: 0.0189
# Epoch 8/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0179 - val_loss: 0.0229 - val_binary_crossentropy: 0.0184
# Epoch 9/50
# 19/19 - 1s - loss: 0.0218 - binary_crossentropy: 0.0173 - val_loss: 0.0226 - val_binary_crossentropy: 0.0182
# Epoch 10/50
# 19/19 - 1s - loss: 0.0215 - binary_crossentropy: 0.0169 - val_loss: 0.0223 - val_binary_crossentropy: 0.0179
# Epoch 11/50
# 19/19 - 1s - loss: 0.0211 - binary_crossentropy: 0.0166 - val_loss: 0.0222 - val_binary_crossentropy: 0.0178
# Epoch 12/50
# 19/19 - 1s - loss: 0.0208 - binary_crossentropy: 0.0162 - val_loss: 0.0222 - val_binary_crossentropy: 0.0177
# Epoch 13/50
# 19/19 - 1s - loss: 0.0205 - binary_crossentropy: 0.0158 - val_loss: 0.0220 - val_binary_crossentropy: 0.0175
# Epoch 14/50
# 19/19 - 1s - loss: 0.0202 - binary_crossentropy: 0.0155 - val_loss: 0.0217 - val_binary_crossentropy: 0.0171
# Epoch 15/50
# 19/19 - 1s - loss: 0.0199 - binary_crossentropy: 0.0152 - val_loss: 0.0218 - val_binary_crossentropy: 0.0173
# Epoch 16/50
# 19/19 - 1s - loss: 0.0196 - binary_crossentropy: 0.0148 - val_loss: 0.0217 - val_binary_crossentropy: 0.0171
# Epoch 17/50
# 19/19 - 1s - loss: 0.0192 - binary_crossentropy: 0.0144 - val_loss: 0.0222 - val_binary_crossentropy: 0.0176
# Epoch 18/50
# 19/19 - 1s - loss: 0.0188 - binary_crossentropy: 0.0140 - val_loss: 0.0217 - val_binary_crossentropy: 0.0170
# Epoch 19/50
# 19/19 - 1s - loss: 0.0185 - binary_crossentropy: 0.0137 - val_loss: 0.0218 - val_binary_crossentropy: 0.0170
# Epoch 20/50
# 19/19 - 1s - loss: 0.0182 - binary_crossentropy: 0.0133 - val_loss: 0.0219 - val_binary_crossentropy: 0.0171
# Epoch 21/50
# 19/19 - 1s - loss: 0.0178 - binary_crossentropy: 0.0129 - val_loss: 0.0224 - val_binary_crossentropy: 0.0175
# Epoch 22/50
# 19/19 - 1s - loss: 0.0174 - binary_crossentropy: 0.0124 - val_loss: 0.0221 - val_binary_crossentropy: 0.0172
# Epoch 23/50
# 19/19 - 1s - loss: 0.0170 - binary_crossentropy: 0.0120 - val_loss: 0.0228 - val_binary_crossentropy: 0.0178
# Epoch 24/50
# 19/19 - 1s - loss: 0.0165 - binary_crossentropy: 0.0114 - val_loss: 0.0230 - val_binary_crossentropy: 0.0180
# Epoch 25/50
# 19/19 - 1s - loss: 0.0155 - binary_crossentropy: 0.0104 - val_loss: 0.0230 - val_binary_crossentropy: 0.0180
# Epoch 26/50
# 19/19 - 1s - loss: 0.0147 - binary_crossentropy: 0.0096 - val_loss: 0.0233 - val_binary_crossentropy: 0.0182
# Epoch 27/50
# 19/19 - 0s - loss: 0.0141 - binary_crossentropy: 0.0089 - val_loss: 0.0235 - val_binary_crossentropy: 0.0184
# Epoch 28/50
# 19/19 - 1s - loss: 0.0136 - binary_crossentropy: 0.0083 - val_loss: 0.0239 - val_binary_crossentropy: 0.0188
# Epoch 29/50
# 19/19 - 0s - loss: 0.0131 - binary_crossentropy: 0.0078 - val_loss: 0.0238 - val_binary_crossentropy: 0.0186
# Epoch 30/50
# 19/19 - 0s - loss: 0.0127 - binary_crossentropy: 0.0073 - val_loss: 0.0240 - val_binary_crossentropy: 0.0188
# Epoch 31/50
# 19/19 - 0s - loss: 0.0122 - binary_crossentropy: 0.0068 - val_loss: 0.0242 - val_binary_crossentropy: 0.0190
# Epoch 32/50
# 19/19 - 0s - loss: 0.0118 - binary_crossentropy: 0.0063 - val_loss: 0.0244 - val_binary_crossentropy: 0.0192
# Epoch 33/50
# 19/19 - 0s - loss: 0.0114 - binary_crossentropy: 0.0059 - val_loss: 0.0247 - val_binary_crossentropy: 0.0194
# Epoch 34/50
# 19/19 - 0s - loss: 0.0110 - binary_crossentropy: 0.0054 - val_loss: 0.0249 - val_binary_crossentropy: 0.0196
# Epoch 35/50
# 19/19 - 0s - loss: 0.0103 - binary_crossentropy: 0.0046 - val_loss: 0.0246 - val_binary_crossentropy: 0.0194
# Epoch 36/50
# 19/19 - 0s - loss: 0.0097 - binary_crossentropy: 0.0040 - val_loss: 0.0248 - val_binary_crossentropy: 0.0195
# Epoch 37/50
# 19/19 - 1s - loss: 0.0094 - binary_crossentropy: 0.0037 - val_loss: 0.0250 - val_binary_crossentropy: 0.0196
# Epoch 38/50
# 19/19 - 0s - loss: 0.0092 - binary_crossentropy: 0.0034 - val_loss: 0.0250 - val_binary_crossentropy: 0.0196
# Epoch 39/50
# 19/19 - 1s - loss: 0.0089 - binary_crossentropy: 0.0032 - val_loss: 0.0249 - val_binary_crossentropy: 0.0196
# Epoch 40/50
# 19/19 - 1s - loss: 0.0088 - binary_crossentropy: 0.0031 - val_loss: 0.0249 - val_binary_crossentropy: 0.0196
# Epoch 41/50
# 19/19 - 1s - loss: 0.0087 - binary_crossentropy: 0.0029 - val_loss: 0.0251 - val_binary_crossentropy: 0.0197
# Epoch 42/50
# 19/19 - 1s - loss: 0.0086 - binary_crossentropy: 0.0028 - val_loss: 0.0251 - val_binary_crossentropy: 0.0197
# Epoch 43/50
# 19/19 - 1s - loss: 0.0085 - binary_crossentropy: 0.0026 - val_loss: 0.0251 - val_binary_crossentropy: 0.0197
# Epoch 44/50
# 19/19 - 1s - loss: 0.0084 - binary_crossentropy: 0.0025 - val_loss: 0.0253 - val_binary_crossentropy: 0.0199
# Epoch 45/50
# 19/19 - 1s - loss: 0.0082 - binary_crossentropy: 0.0023 - val_loss: 0.0253 - val_binary_crossentropy: 0.0199
# Epoch 46/50
# 19/19 - 1s - loss: 0.0080 - binary_crossentropy: 0.0022 - val_loss: 0.0252 - val_binary_crossentropy: 0.0198
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# 19/19 - 2s - loss: 0.7323 - binary_crossentropy: 0.7323 - val_loss: 1.3453 - val_binary_crossentropy: 1.3451
# Epoch 2/50
# 19/19 - 1s - loss: 0.3893 - binary_crossentropy: 0.3886 - val_loss: 0.2823 - val_binary_crossentropy: 0.2796
# Epoch 3/50
# 19/19 - 1s - loss: 0.0383 - binary_crossentropy: 0.0352 - val_loss: 0.0675 - val_binary_crossentropy: 0.0626
# Epoch 4/50
# 19/19 - 1s - loss: 0.0245 - binary_crossentropy: 0.0202 - val_loss: 0.0359 - val_binary_crossentropy: 0.0305
# Epoch 5/50
# 19/19 - 1s - loss: 0.0237 - binary_crossentropy: 0.0192 - val_loss: 0.0264 - val_binary_crossentropy: 0.0214
# Epoch 6/50
# 19/19 - 1s - loss: 0.0232 - binary_crossentropy: 0.0187 - val_loss: 0.0241 - val_binary_crossentropy: 0.0195
# Epoch 7/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0182 - val_loss: 0.0230 - val_binary_crossentropy: 0.0185
# Epoch 8/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0177 - val_loss: 0.0225 - val_binary_crossentropy: 0.0180
# Epoch 9/50
# 19/19 - 1s - loss: 0.0217 - binary_crossentropy: 0.0172 - val_loss: 0.0221 - val_binary_crossentropy: 0.0177
# Epoch 10/50
# 19/19 - 1s - loss: 0.0213 - binary_crossentropy: 0.0168 - val_loss: 0.0219 - val_binary_crossentropy: 0.0174
# Epoch 11/50
# 19/19 - 1s - loss: 0.0210 - binary_crossentropy: 0.0164 - val_loss: 0.0218 - val_binary_crossentropy: 0.0174
# Epoch 12/50
# 19/19 - 1s - loss: 0.0207 - binary_crossentropy: 0.0160 - val_loss: 0.0217 - val_binary_crossentropy: 0.0172
# Epoch 13/50
# 19/19 - 1s - loss: 0.0204 - binary_crossentropy: 0.0157 - val_loss: 0.0215 - val_binary_crossentropy: 0.0169
# Epoch 14/50
# 19/19 - 1s - loss: 0.0201 - binary_crossentropy: 0.0154 - val_loss: 0.0218 - val_binary_crossentropy: 0.0173
# Epoch 15/50
# 19/19 - 1s - loss: 0.0198 - binary_crossentropy: 0.0150 - val_loss: 0.0215 - val_binary_crossentropy: 0.0169
# Epoch 16/50
# 19/19 - 1s - loss: 0.0195 - binary_crossentropy: 0.0147 - val_loss: 0.0215 - val_binary_crossentropy: 0.0168
# Epoch 17/50
# 19/19 - 1s - loss: 0.0192 - binary_crossentropy: 0.0144 - val_loss: 0.0217 - val_binary_crossentropy: 0.0171
# Epoch 18/50
# 19/19 - 1s - loss: 0.0188 - binary_crossentropy: 0.0140 - val_loss: 0.0218 - val_binary_crossentropy: 0.0171
# Epoch 19/50
# 19/19 - 1s - loss: 0.0185 - binary_crossentropy: 0.0137 - val_loss: 0.0218 - val_binary_crossentropy: 0.0171
# Epoch 20/50
# 19/19 - 1s - loss: 0.0182 - binary_crossentropy: 0.0133 - val_loss: 0.0218 - val_binary_crossentropy: 0.0171
# Epoch 21/50
# 19/19 - 1s - loss: 0.0178 - binary_crossentropy: 0.0129 - val_loss: 0.0219 - val_binary_crossentropy: 0.0172
# Epoch 22/50
# 19/19 - 1s - loss: 0.0174 - binary_crossentropy: 0.0124 - val_loss: 0.0223 - val_binary_crossentropy: 0.0175
# Epoch 23/50
# 19/19 - 1s - loss: 0.0169 - binary_crossentropy: 0.0119 - val_loss: 0.0224 - val_binary_crossentropy: 0.0174
# Epoch 24/50
# 19/19 - 1s - loss: 0.0160 - binary_crossentropy: 0.0109 - val_loss: 0.0224 - val_binary_crossentropy: 0.0174
# Epoch 25/50
# 19/19 - 1s - loss: 0.0153 - binary_crossentropy: 0.0102 - val_loss: 0.0227 - val_binary_crossentropy: 0.0176
# Epoch 26/50
# 19/19 - 1s - loss: 0.0147 - binary_crossentropy: 0.0096 - val_loss: 0.0228 - val_binary_crossentropy: 0.0178
# Epoch 27/50
# 19/19 - 1s - loss: 0.0143 - binary_crossentropy: 0.0091 - val_loss: 0.0231 - val_binary_crossentropy: 0.0180
# Epoch 28/50
# 19/19 - 1s - loss: 0.0139 - binary_crossentropy: 0.0086 - val_loss: 0.0237 - val_binary_crossentropy: 0.0186
# Epoch 29/50
# 19/19 - 0s - loss: 0.0134 - binary_crossentropy: 0.0081 - val_loss: 0.0236 - val_binary_crossentropy: 0.0184
# Epoch 30/50
# 19/19 - 1s - loss: 0.0130 - binary_crossentropy: 0.0076 - val_loss: 0.0240 - val_binary_crossentropy: 0.0187
# Epoch 31/50
# 19/19 - 1s - loss: 0.0125 - binary_crossentropy: 0.0071 - val_loss: 0.0241 - val_binary_crossentropy: 0.0188
# Epoch 32/50
# 19/19 - 1s - loss: 0.0120 - binary_crossentropy: 0.0065 - val_loss: 0.0243 - val_binary_crossentropy: 0.0190
# Epoch 33/50
# 19/19 - 1s - loss: 0.0117 - binary_crossentropy: 0.0061 - val_loss: 0.0246 - val_binary_crossentropy: 0.0193
# Epoch 34/50
# 19/19 - 1s - loss: 0.0108 - binary_crossentropy: 0.0053 - val_loss: 0.0244 - val_binary_crossentropy: 0.0192
# Epoch 35/50
# 19/19 - 1s - loss: 0.0102 - binary_crossentropy: 0.0046 - val_loss: 0.0245 - val_binary_crossentropy: 0.0191
# Epoch 36/50
# 19/19 - 1s - loss: 0.0099 - binary_crossentropy: 0.0043 - val_loss: 0.0244 - val_binary_crossentropy: 0.0191
# Epoch 37/50
# 19/19 - 1s - loss: 0.0096 - binary_crossentropy: 0.0039 - val_loss: 0.0246 - val_binary_crossentropy: 0.0193
# Epoch 38/50
# 19/19 - 1s - loss: 0.0094 - binary_crossentropy: 0.0037 - val_loss: 0.0246 - val_binary_crossentropy: 0.0192
# Epoch 39/50
# 19/19 - 1s - loss: 0.0092 - binary_crossentropy: 0.0035 - val_loss: 0.0247 - val_binary_crossentropy: 0.0192
# Epoch 40/50
# 19/19 - 1s - loss: 0.0091 - binary_crossentropy: 0.0033 - val_loss: 0.0246 - val_binary_crossentropy: 0.0193
# Epoch 41/50
# 19/19 - 1s - loss: 0.0089 - binary_crossentropy: 0.0031 - val_loss: 0.0246 - val_binary_crossentropy: 0.0193
# Epoch 42/50
# 19/19 - 1s - loss: 0.0087 - binary_crossentropy: 0.0030 - val_loss: 0.0247 - val_binary_crossentropy: 0.0193
# Epoch 43/50
# 19/19 - 1s - loss: 0.0086 - binary_crossentropy: 0.0028 - val_loss: 0.0247 - val_binary_crossentropy: 0.0194
# Epoch 44/50
# 19/19 - 1s - loss: 0.0084 - binary_crossentropy: 0.0026 - val_loss: 0.0247 - val_binary_crossentropy: 0.0194
# Epoch 45/50
# 19/19 - 1s - loss: 0.0082 - binary_crossentropy: 0.0024 - val_loss: 0.0249 - val_binary_crossentropy: 0.0195
# Epoch 46/50
# 19/19 - 1s - loss: 0.0081 - binary_crossentropy: 0.0022 - val_loss: 0.0249 - val_binary_crossentropy: 0.0195
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# 19/19 - 2s - loss: 0.7308 - binary_crossentropy: 0.7308 - val_loss: 1.1231 - val_binary_crossentropy: 1.1227
# Epoch 2/50
# 19/19 - 1s - loss: 0.3872 - binary_crossentropy: 0.3865 - val_loss: 0.2266 - val_binary_crossentropy: 0.2237
# Epoch 3/50
# 19/19 - 1s - loss: 0.0380 - binary_crossentropy: 0.0349 - val_loss: 0.0852 - val_binary_crossentropy: 0.0802
# Epoch 4/50
# 19/19 - 1s - loss: 0.0245 - binary_crossentropy: 0.0202 - val_loss: 0.0416 - val_binary_crossentropy: 0.0360
# Epoch 5/50
# 19/19 - 1s - loss: 0.0237 - binary_crossentropy: 0.0192 - val_loss: 0.0293 - val_binary_crossentropy: 0.0241
# Epoch 6/50
# 19/19 - 1s - loss: 0.0231 - binary_crossentropy: 0.0186 - val_loss: 0.0254 - val_binary_crossentropy: 0.0207
# Epoch 7/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0180 - val_loss: 0.0235 - val_binary_crossentropy: 0.0190
# Epoch 8/50
# 19/19 - 1s - loss: 0.0219 - binary_crossentropy: 0.0174 - val_loss: 0.0225 - val_binary_crossentropy: 0.0181
# Epoch 9/50
# 19/19 - 1s - loss: 0.0215 - binary_crossentropy: 0.0169 - val_loss: 0.0223 - val_binary_crossentropy: 0.0180
# Epoch 10/50
# 19/19 - 1s - loss: 0.0211 - binary_crossentropy: 0.0165 - val_loss: 0.0221 - val_binary_crossentropy: 0.0176
# Epoch 11/50
# 19/19 - 1s - loss: 0.0208 - binary_crossentropy: 0.0162 - val_loss: 0.0219 - val_binary_crossentropy: 0.0175
# Epoch 12/50
# 19/19 - 1s - loss: 0.0205 - binary_crossentropy: 0.0159 - val_loss: 0.0220 - val_binary_crossentropy: 0.0176
# Epoch 13/50
# 19/19 - 1s - loss: 0.0203 - binary_crossentropy: 0.0156 - val_loss: 0.0218 - val_binary_crossentropy: 0.0173
# Epoch 14/50
# 19/19 - 1s - loss: 0.0200 - binary_crossentropy: 0.0153 - val_loss: 0.0218 - val_binary_crossentropy: 0.0172
# Epoch 15/50
# 19/19 - 1s - loss: 0.0196 - binary_crossentropy: 0.0149 - val_loss: 0.0218 - val_binary_crossentropy: 0.0172
# Epoch 16/50
# 19/19 - 1s - loss: 0.0193 - binary_crossentropy: 0.0145 - val_loss: 0.0221 - val_binary_crossentropy: 0.0174
# Epoch 17/50
# 19/19 - 1s - loss: 0.0190 - binary_crossentropy: 0.0142 - val_loss: 0.0216 - val_binary_crossentropy: 0.0170
# Epoch 18/50
# 19/19 - 1s - loss: 0.0186 - binary_crossentropy: 0.0138 - val_loss: 0.0220 - val_binary_crossentropy: 0.0173
# Epoch 19/50
# 19/19 - 1s - loss: 0.0183 - binary_crossentropy: 0.0134 - val_loss: 0.0218 - val_binary_crossentropy: 0.0170
# Epoch 20/50
# 19/19 - 1s - loss: 0.0181 - binary_crossentropy: 0.0132 - val_loss: 0.0221 - val_binary_crossentropy: 0.0173
# Epoch 21/50
# 19/19 - 1s - loss: 0.0177 - binary_crossentropy: 0.0128 - val_loss: 0.0221 - val_binary_crossentropy: 0.0172
# Epoch 22/50
# 19/19 - 1s - loss: 0.0172 - binary_crossentropy: 0.0122 - val_loss: 0.0225 - val_binary_crossentropy: 0.0175
# Epoch 23/50
# 19/19 - 1s - loss: 0.0167 - binary_crossentropy: 0.0117 - val_loss: 0.0229 - val_binary_crossentropy: 0.0180
# Epoch 24/50
# 19/19 - 1s - loss: 0.0163 - binary_crossentropy: 0.0112 - val_loss: 0.0237 - val_binary_crossentropy: 0.0185
# Epoch 25/50
# 19/19 - 1s - loss: 0.0157 - binary_crossentropy: 0.0106 - val_loss: 0.0240 - val_binary_crossentropy: 0.0189
# Epoch 26/50
# 19/19 - 1s - loss: 0.0152 - binary_crossentropy: 0.0100 - val_loss: 0.0239 - val_binary_crossentropy: 0.0188
# Epoch 27/50
# 19/19 - 1s - loss: 0.0147 - binary_crossentropy: 0.0094 - val_loss: 0.0240 - val_binary_crossentropy: 0.0188
# Epoch 28/50
# 19/19 - 1s - loss: 0.0135 - binary_crossentropy: 0.0082 - val_loss: 0.0241 - val_binary_crossentropy: 0.0189
# Epoch 29/50
# 19/19 - 1s - loss: 0.0126 - binary_crossentropy: 0.0072 - val_loss: 0.0240 - val_binary_crossentropy: 0.0189
# Epoch 30/50
# 19/19 - 1s - loss: 0.0120 - binary_crossentropy: 0.0065 - val_loss: 0.0246 - val_binary_crossentropy: 0.0194
# Epoch 31/50
# 19/19 - 1s - loss: 0.0114 - binary_crossentropy: 0.0059 - val_loss: 0.0246 - val_binary_crossentropy: 0.0194
# Epoch 32/50
# 19/19 - 1s - loss: 0.0111 - binary_crossentropy: 0.0055 - val_loss: 0.0249 - val_binary_crossentropy: 0.0196
# Epoch 33/50
# 19/19 - 1s - loss: 0.0107 - binary_crossentropy: 0.0051 - val_loss: 0.0249 - val_binary_crossentropy: 0.0196
# Epoch 34/50
# 19/19 - 1s - loss: 0.0105 - binary_crossentropy: 0.0048 - val_loss: 0.0252 - val_binary_crossentropy: 0.0198
# Epoch 35/50
# 19/19 - 1s - loss: 0.0102 - binary_crossentropy: 0.0045 - val_loss: 0.0250 - val_binary_crossentropy: 0.0196
# Epoch 36/50
# 19/19 - 1s - loss: 0.0099 - binary_crossentropy: 0.0042 - val_loss: 0.0255 - val_binary_crossentropy: 0.0202
# Epoch 37/50
# 19/19 - 1s - loss: 0.0097 - binary_crossentropy: 0.0039 - val_loss: 0.0255 - val_binary_crossentropy: 0.0201
# Epoch 38/50
# 19/19 - 1s - loss: 0.0092 - binary_crossentropy: 0.0033 - val_loss: 0.0253 - val_binary_crossentropy: 0.0199
# Epoch 39/50
# 19/19 - 1s - loss: 0.0087 - binary_crossentropy: 0.0029 - val_loss: 0.0254 - val_binary_crossentropy: 0.0199
# Epoch 40/50
# 19/19 - 1s - loss: 0.0085 - binary_crossentropy: 0.0027 - val_loss: 0.0253 - val_binary_crossentropy: 0.0199
# Epoch 41/50
# 19/19 - 1s - loss: 0.0084 - binary_crossentropy: 0.0025 - val_loss: 0.0254 - val_binary_crossentropy: 0.0200
# Epoch 42/50
# 19/19 - 1s - loss: 0.0083 - binary_crossentropy: 0.0024 - val_loss: 0.0254 - val_binary_crossentropy: 0.0200
# Epoch 43/50
# 19/19 - 1s - loss: 0.0081 - binary_crossentropy: 0.0023 - val_loss: 0.0254 - val_binary_crossentropy: 0.0200
# Epoch 44/50
# 19/19 - 1s - loss: 0.0080 - binary_crossentropy: 0.0022 - val_loss: 0.0255 - val_binary_crossentropy: 0.0201
# Epoch 45/50
# 19/19 - 1s - loss: 0.0080 - binary_crossentropy: 0.0021 - val_loss: 0.0255 - val_binary_crossentropy: 0.0201
# Epoch 46/50
# 19/19 - 1s - loss: 0.0079 - binary_crossentropy: 0.0020 - val_loss: 0.0255 - val_binary_crossentropy: 0.0200
# Epoch 47/50
# 19/19 - 1s - loss: 0.0078 - binary_crossentropy: 0.0019 - val_loss: 0.0256 - val_binary_crossentropy: 0.0202
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# 19/19 - 2s - loss: 0.7314 - binary_crossentropy: 0.7314 - val_loss: 1.1354 - val_binary_crossentropy: 1.1350
# Epoch 2/50
# 19/19 - 1s - loss: 0.3851 - binary_crossentropy: 0.3844 - val_loss: 0.1357 - val_binary_crossentropy: 0.1320
# Epoch 3/50
# 19/19 - 1s - loss: 0.0374 - binary_crossentropy: 0.0343 - val_loss: 0.0647 - val_binary_crossentropy: 0.0592
# Epoch 4/50
# 19/19 - 1s - loss: 0.0245 - binary_crossentropy: 0.0202 - val_loss: 0.0459 - val_binary_crossentropy: 0.0404
# Epoch 5/50
# 19/19 - 1s - loss: 0.0238 - binary_crossentropy: 0.0193 - val_loss: 0.0307 - val_binary_crossentropy: 0.0257
# Epoch 6/50
# 19/19 - 1s - loss: 0.0233 - binary_crossentropy: 0.0187 - val_loss: 0.0257 - val_binary_crossentropy: 0.0210
# Epoch 7/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0183 - val_loss: 0.0237 - val_binary_crossentropy: 0.0192
# Epoch 8/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0179 - val_loss: 0.0230 - val_binary_crossentropy: 0.0186
# Epoch 9/50
# 19/19 - 1s - loss: 0.0219 - binary_crossentropy: 0.0174 - val_loss: 0.0226 - val_binary_crossentropy: 0.0182
# Epoch 10/50
# 19/19 - 1s - loss: 0.0215 - binary_crossentropy: 0.0169 - val_loss: 0.0225 - val_binary_crossentropy: 0.0181
# Epoch 11/50
# 19/19 - 1s - loss: 0.0211 - binary_crossentropy: 0.0165 - val_loss: 0.0223 - val_binary_crossentropy: 0.0179
# Epoch 12/50
# 19/19 - 1s - loss: 0.0207 - binary_crossentropy: 0.0161 - val_loss: 0.0220 - val_binary_crossentropy: 0.0175
# Epoch 13/50
# 19/19 - 1s - loss: 0.0204 - binary_crossentropy: 0.0158 - val_loss: 0.0218 - val_binary_crossentropy: 0.0173
# Epoch 14/50
# 19/19 - 1s - loss: 0.0200 - binary_crossentropy: 0.0154 - val_loss: 0.0218 - val_binary_crossentropy: 0.0173
# Epoch 15/50
# 19/19 - 1s - loss: 0.0197 - binary_crossentropy: 0.0150 - val_loss: 0.0219 - val_binary_crossentropy: 0.0174
# Epoch 16/50
# 19/19 - 1s - loss: 0.0195 - binary_crossentropy: 0.0148 - val_loss: 0.0217 - val_binary_crossentropy: 0.0170
# Epoch 17/50
# 19/19 - 0s - loss: 0.0192 - binary_crossentropy: 0.0144 - val_loss: 0.0217 - val_binary_crossentropy: 0.0171
# Epoch 18/50
# 19/19 - 1s - loss: 0.0188 - binary_crossentropy: 0.0140 - val_loss: 0.0227 - val_binary_crossentropy: 0.0179
# Epoch 19/50
# 19/19 - 0s - loss: 0.0185 - binary_crossentropy: 0.0136 - val_loss: 0.0219 - val_binary_crossentropy: 0.0171
# Epoch 20/50
# 19/19 - 0s - loss: 0.0181 - binary_crossentropy: 0.0132 - val_loss: 0.0221 - val_binary_crossentropy: 0.0173
# Epoch 21/50
# 19/19 - 0s - loss: 0.0177 - binary_crossentropy: 0.0127 - val_loss: 0.0223 - val_binary_crossentropy: 0.0173
# Epoch 22/50
# 19/19 - 0s - loss: 0.0173 - binary_crossentropy: 0.0123 - val_loss: 0.0226 - val_binary_crossentropy: 0.0176
# Epoch 23/50
# 19/19 - 0s - loss: 0.0168 - binary_crossentropy: 0.0118 - val_loss: 0.0228 - val_binary_crossentropy: 0.0179
# Epoch 24/50
# 19/19 - 0s - loss: 0.0164 - binary_crossentropy: 0.0113 - val_loss: 0.0232 - val_binary_crossentropy: 0.0181
# Epoch 25/50
# 19/19 - 0s - loss: 0.0159 - binary_crossentropy: 0.0107 - val_loss: 0.0233 - val_binary_crossentropy: 0.0183
# Epoch 26/50
# 19/19 - 0s - loss: 0.0152 - binary_crossentropy: 0.0100 - val_loss: 0.0241 - val_binary_crossentropy: 0.0190
# Epoch 27/50
# 19/19 - 0s - loss: 0.0141 - binary_crossentropy: 0.0088 - val_loss: 0.0234 - val_binary_crossentropy: 0.0183
# Epoch 28/50
# 19/19 - 0s - loss: 0.0131 - binary_crossentropy: 0.0079 - val_loss: 0.0237 - val_binary_crossentropy: 0.0186
# Epoch 29/50
# 19/19 - 0s - loss: 0.0125 - binary_crossentropy: 0.0071 - val_loss: 0.0240 - val_binary_crossentropy: 0.0188
# Epoch 30/50
# 19/19 - 0s - loss: 0.0121 - binary_crossentropy: 0.0066 - val_loss: 0.0241 - val_binary_crossentropy: 0.0188
# Epoch 31/50
# 19/19 - 0s - loss: 0.0116 - binary_crossentropy: 0.0061 - val_loss: 0.0243 - val_binary_crossentropy: 0.0190
# Epoch 32/50
# 19/19 - 0s - loss: 0.0112 - binary_crossentropy: 0.0057 - val_loss: 0.0244 - val_binary_crossentropy: 0.0191
# Epoch 33/50
# 19/19 - 0s - loss: 0.0109 - binary_crossentropy: 0.0053 - val_loss: 0.0247 - val_binary_crossentropy: 0.0194
# Epoch 34/50
# 19/19 - 0s - loss: 0.0106 - binary_crossentropy: 0.0050 - val_loss: 0.0248 - val_binary_crossentropy: 0.0195
# Epoch 35/50
# 19/19 - 0s - loss: 0.0103 - binary_crossentropy: 0.0046 - val_loss: 0.0252 - val_binary_crossentropy: 0.0198
# Epoch 36/50
# 19/19 - 0s - loss: 0.0100 - binary_crossentropy: 0.0042 - val_loss: 0.0249 - val_binary_crossentropy: 0.0197
# Epoch 37/50
# 19/19 - 0s - loss: 0.0094 - binary_crossentropy: 0.0036 - val_loss: 0.0249 - val_binary_crossentropy: 0.0196
# Epoch 38/50
# 19/19 - 0s - loss: 0.0090 - binary_crossentropy: 0.0032 - val_loss: 0.0249 - val_binary_crossentropy: 0.0196
# Epoch 39/50
# 19/19 - 0s - loss: 0.0087 - binary_crossentropy: 0.0029 - val_loss: 0.0248 - val_binary_crossentropy: 0.0195
# Epoch 40/50
# 19/19 - 0s - loss: 0.0085 - binary_crossentropy: 0.0027 - val_loss: 0.0253 - val_binary_crossentropy: 0.0199
# Epoch 41/50
# 19/19 - 0s - loss: 0.0084 - binary_crossentropy: 0.0026 - val_loss: 0.0251 - val_binary_crossentropy: 0.0196
# Epoch 42/50
# 19/19 - 0s - loss: 0.0082 - binary_crossentropy: 0.0024 - val_loss: 0.0251 - val_binary_crossentropy: 0.0197
# Epoch 43/50
# 19/19 - 0s - loss: 0.0082 - binary_crossentropy: 0.0023 - val_loss: 0.0252 - val_binary_crossentropy: 0.0198
# Epoch 44/50
# 19/19 - 0s - loss: 0.0081 - binary_crossentropy: 0.0022 - val_loss: 0.0252 - val_binary_crossentropy: 0.0198
# Epoch 45/50
# 19/19 - 0s - loss: 0.0080 - binary_crossentropy: 0.0021 - val_loss: 0.0254 - val_binary_crossentropy: 0.0199
# Epoch 46/50
# 19/19 - 0s - loss: 0.0079 - binary_crossentropy: 0.0021 - val_loss: 0.0253 - val_binary_crossentropy: 0.0199
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
# Epoch 1/50
# 19/19 - 1s - loss: 0.7315 - binary_crossentropy: 0.7315 - val_loss: 1.6640 - val_binary_crossentropy: 1.6643
# Epoch 2/50
# 19/19 - 1s - loss: 0.3925 - binary_crossentropy: 0.3918 - val_loss: 0.4342 - val_binary_crossentropy: 0.4322
# Epoch 3/50
# 19/19 - 1s - loss: 0.0383 - binary_crossentropy: 0.0352 - val_loss: 0.0801 - val_binary_crossentropy: 0.0757
# Epoch 4/50
# 19/19 - 1s - loss: 0.0245 - binary_crossentropy: 0.0202 - val_loss: 0.0431 - val_binary_crossentropy: 0.0379
# Epoch 5/50
# 19/19 - 1s - loss: 0.0238 - binary_crossentropy: 0.0193 - val_loss: 0.0328 - val_binary_crossentropy: 0.0281
# Epoch 6/50
# 19/19 - 1s - loss: 0.0233 - binary_crossentropy: 0.0188 - val_loss: 0.0269 - val_binary_crossentropy: 0.0224
# Epoch 7/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0183 - val_loss: 0.0239 - val_binary_crossentropy: 0.0195
# Epoch 8/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0178 - val_loss: 0.0226 - val_binary_crossentropy: 0.0181
# Epoch 9/50
# 19/19 - 1s - loss: 0.0218 - binary_crossentropy: 0.0173 - val_loss: 0.0222 - val_binary_crossentropy: 0.0178
# Epoch 10/50
# 19/19 - 1s - loss: 0.0214 - binary_crossentropy: 0.0168 - val_loss: 0.0221 - val_binary_crossentropy: 0.0177
# Epoch 11/50
# 19/19 - 1s - loss: 0.0210 - binary_crossentropy: 0.0164 - val_loss: 0.0217 - val_binary_crossentropy: 0.0172
# Epoch 12/50
# 19/19 - 1s - loss: 0.0207 - binary_crossentropy: 0.0160 - val_loss: 0.0215 - val_binary_crossentropy: 0.0170
# Epoch 13/50
# 19/19 - 1s - loss: 0.0204 - binary_crossentropy: 0.0157 - val_loss: 0.0214 - val_binary_crossentropy: 0.0169
# Epoch 14/50
# 19/19 - 1s - loss: 0.0200 - binary_crossentropy: 0.0153 - val_loss: 0.0213 - val_binary_crossentropy: 0.0167
# Epoch 15/50
# 19/19 - 0s - loss: 0.0197 - binary_crossentropy: 0.0150 - val_loss: 0.0213 - val_binary_crossentropy: 0.0167
# Epoch 16/50
# 19/19 - 0s - loss: 0.0194 - binary_crossentropy: 0.0147 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 17/50
# 19/19 - 1s - loss: 0.0191 - binary_crossentropy: 0.0143 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 18/50
# 19/19 - 0s - loss: 0.0188 - binary_crossentropy: 0.0140 - val_loss: 0.0214 - val_binary_crossentropy: 0.0167
# Epoch 19/50
# 19/19 - 1s - loss: 0.0185 - binary_crossentropy: 0.0136 - val_loss: 0.0212 - val_binary_crossentropy: 0.0164
# Epoch 20/50
# 19/19 - 0s - loss: 0.0181 - binary_crossentropy: 0.0132 - val_loss: 0.0218 - val_binary_crossentropy: 0.0170
# Epoch 21/50
# 19/19 - 0s - loss: 0.0177 - binary_crossentropy: 0.0128 - val_loss: 0.0219 - val_binary_crossentropy: 0.0170
# Epoch 22/50
# 19/19 - 0s - loss: 0.0174 - binary_crossentropy: 0.0124 - val_loss: 0.0221 - val_binary_crossentropy: 0.0172
# Epoch 23/50
# 19/19 - 0s - loss: 0.0168 - binary_crossentropy: 0.0118 - val_loss: 0.0224 - val_binary_crossentropy: 0.0173
# Epoch 24/50
# 19/19 - 0s - loss: 0.0164 - binary_crossentropy: 0.0113 - val_loss: 0.0228 - val_binary_crossentropy: 0.0177
# Epoch 25/50
# 19/19 - 0s - loss: 0.0154 - binary_crossentropy: 0.0102 - val_loss: 0.0224 - val_binary_crossentropy: 0.0174
# Epoch 26/50
# 19/19 - 0s - loss: 0.0145 - binary_crossentropy: 0.0094 - val_loss: 0.0229 - val_binary_crossentropy: 0.0178
# Epoch 27/50
# 19/19 - 0s - loss: 0.0139 - binary_crossentropy: 0.0087 - val_loss: 0.0233 - val_binary_crossentropy: 0.0182
# Epoch 28/50
# 19/19 - 0s - loss: 0.0134 - binary_crossentropy: 0.0081 - val_loss: 0.0236 - val_binary_crossentropy: 0.0184
# Epoch 29/50
# 19/19 - 0s - loss: 0.0130 - binary_crossentropy: 0.0076 - val_loss: 0.0239 - val_binary_crossentropy: 0.0185
# Epoch 30/50
# 19/19 - 0s - loss: 0.0125 - binary_crossentropy: 0.0072 - val_loss: 0.0240 - val_binary_crossentropy: 0.0188
# Epoch 31/50
# 19/19 - 0s - loss: 0.0121 - binary_crossentropy: 0.0067 - val_loss: 0.0242 - val_binary_crossentropy: 0.0189
# Epoch 32/50
# 19/19 - 0s - loss: 0.0118 - binary_crossentropy: 0.0063 - val_loss: 0.0242 - val_binary_crossentropy: 0.0189
# Epoch 33/50
# 19/19 - 0s - loss: 0.0114 - binary_crossentropy: 0.0058 - val_loss: 0.0245 - val_binary_crossentropy: 0.0192
# Epoch 34/50
# 19/19 - 0s - loss: 0.0111 - binary_crossentropy: 0.0055 - val_loss: 0.0246 - val_binary_crossentropy: 0.0193
# Epoch 35/50
# 19/19 - 0s - loss: 0.0103 - binary_crossentropy: 0.0047 - val_loss: 0.0244 - val_binary_crossentropy: 0.0191
# Epoch 36/50
# 19/19 - 0s - loss: 0.0098 - binary_crossentropy: 0.0041 - val_loss: 0.0245 - val_binary_crossentropy: 0.0191
# Epoch 37/50
# 19/19 - 0s - loss: 0.0094 - binary_crossentropy: 0.0037 - val_loss: 0.0247 - val_binary_crossentropy: 0.0193
# Epoch 38/50
# 19/19 - 0s - loss: 0.0092 - binary_crossentropy: 0.0035 - val_loss: 0.0249 - val_binary_crossentropy: 0.0194
# Epoch 39/50
# 19/19 - 0s - loss: 0.0090 - binary_crossentropy: 0.0033 - val_loss: 0.0247 - val_binary_crossentropy: 0.0193
# Epoch 40/50
# 19/19 - 0s - loss: 0.0089 - binary_crossentropy: 0.0031 - val_loss: 0.0246 - val_binary_crossentropy: 0.0192
# Epoch 41/50
# 19/19 - 0s - loss: 0.0088 - binary_crossentropy: 0.0029 - val_loss: 0.0248 - val_binary_crossentropy: 0.0193
# Epoch 42/50
# 19/19 - 0s - loss: 0.0086 - binary_crossentropy: 0.0028 - val_loss: 0.0248 - val_binary_crossentropy: 0.0194
# Epoch 43/50
# 19/19 - 0s - loss: 0.0085 - binary_crossentropy: 0.0027 - val_loss: 0.0251 - val_binary_crossentropy: 0.0196
# Epoch 44/50
# 19/19 - 0s - loss: 0.0084 - binary_crossentropy: 0.0026 - val_loss: 0.0251 - val_binary_crossentropy: 0.0196
# Epoch 45/50
# 19/19 - 0s - loss: 0.0082 - binary_crossentropy: 0.0023 - val_loss: 0.0250 - val_binary_crossentropy: 0.0195
# Epoch 46/50
# 19/19 - 0s - loss: 0.0080 - binary_crossentropy: 0.0022 - val_loss: 0.0252 - val_binary_crossentropy: 0.0197
# Epoch 47/50
# 19/19 - 0s - loss: 0.0080 - binary_crossentropy: 0.0021 - val_loss: 0.0251 - val_binary_crossentropy: 0.0196
# Epoch 48/50
# 19/19 - 0s - loss: 0.0079 - binary_crossentropy: 0.0020 - val_loss: 0.0250 - val_binary_crossentropy: 0.0195
# Epoch 49/50
# 19/19 - 0s - loss: 0.0078 - binary_crossentropy: 0.0019 - val_loss: 0.0251 - val_binary_crossentropy: 0.0196
#
# oof_score: 0.01667101289063038
# oof_auc_score: 0.6559833735832494
# ----------------------------------------------------------------------------------------------------

# %%
oof_score
# Out:
# 0.01667101289063038
