# %%
# !pwd
import sys
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
sys.executable
# Out:
# C:\Users\81908\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124\run_objective_2l
# 'c:\\users\\81908\\appdata\\local\\pypoetry\\cache\\virtualenvs\\tfgpu-ehdmne1y-py3.8\\scripts\\python.exe'

# %%
# tensorflow2.0 + kerasでGPUメモリの使用量を抑える方法(最小限だけ使うように設定)
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"

# %%
import sys
sys.path.append(r'C:\Users\81908\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124')
import moa_MLPs_funcs
# Out:
# Tensorflow version 2.3.1
# n_classes: 206

# %%
params = dict(
    activation="relu",
    denses=[1292, 983],
    drop_rates=[0.2688628097505064, 0.4598218403250696, 0.4703144018483698],
    sync_period=10,
)
model_type = "2l"

# %%
oof_score, Y_pred = moa_MLPs_funcs.train_and_evaluate(model_type=model_type, params=params)
# Out:
# WARNING:tensorflow:From C:\Users\81908\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124\moa_MLPs_funcs.py:694: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass shuffle=True, random_state=0 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# Epoch 1/50
# 19/19 - 1s - loss: 0.3210 - binary_crossentropy: 0.3195 - val_loss: 0.0394 - val_binary_crossentropy: 0.0332
# Epoch 2/50
# 19/19 - 1s - loss: 0.0295 - binary_crossentropy: 0.0255 - val_loss: 0.0296 - val_binary_crossentropy: 0.0241
# Epoch 3/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0207 - val_loss: 0.0263 - val_binary_crossentropy: 0.0211
# Epoch 4/50
# 19/19 - 1s - loss: 0.0248 - binary_crossentropy: 0.0203 - val_loss: 0.0252 - val_binary_crossentropy: 0.0202
# Epoch 5/50
# 19/19 - 1s - loss: 0.0247 - binary_crossentropy: 0.0202 - val_loss: 0.0248 - val_binary_crossentropy: 0.0200
# Epoch 6/50
# 19/19 - 1s - loss: 0.0246 - binary_crossentropy: 0.0201 - val_loss: 0.0244 - val_binary_crossentropy: 0.0196
# Epoch 7/50
# 19/19 - 1s - loss: 0.0245 - binary_crossentropy: 0.0200 - val_loss: 0.0241 - val_binary_crossentropy: 0.0194
# Epoch 8/50
# 19/19 - 1s - loss: 0.0245 - binary_crossentropy: 0.0200 - val_loss: 0.0239 - val_binary_crossentropy: 0.0192
# Epoch 9/50
# 19/19 - 1s - loss: 0.0243 - binary_crossentropy: 0.0198 - val_loss: 0.0238 - val_binary_crossentropy: 0.0191
# Epoch 10/50
# 19/19 - 1s - loss: 0.0243 - binary_crossentropy: 0.0198 - val_loss: 0.0235 - val_binary_crossentropy: 0.0188
# Epoch 11/50
# 19/19 - 1s - loss: 0.0242 - binary_crossentropy: 0.0197 - val_loss: 0.0234 - val_binary_crossentropy: 0.0188
# Epoch 12/50
# 19/19 - 1s - loss: 0.0242 - binary_crossentropy: 0.0197 - val_loss: 0.0231 - val_binary_crossentropy: 0.0185
# Epoch 13/50
# 19/19 - 1s - loss: 0.0241 - binary_crossentropy: 0.0196 - val_loss: 0.0230 - val_binary_crossentropy: 0.0183
# Epoch 14/50
# 19/19 - 1s - loss: 0.0239 - binary_crossentropy: 0.0193 - val_loss: 0.0228 - val_binary_crossentropy: 0.0182
# Epoch 15/50
# 19/19 - 1s - loss: 0.0239 - binary_crossentropy: 0.0193 - val_loss: 0.0225 - val_binary_crossentropy: 0.0180
# Epoch 16/50
# 19/19 - 1s - loss: 0.0237 - binary_crossentropy: 0.0191 - val_loss: 0.0224 - val_binary_crossentropy: 0.0178
# Epoch 17/50
# 19/19 - 1s - loss: 0.0236 - binary_crossentropy: 0.0191 - val_loss: 0.0224 - val_binary_crossentropy: 0.0178
# Epoch 18/50
# 19/19 - 1s - loss: 0.0236 - binary_crossentropy: 0.0190 - val_loss: 0.0222 - val_binary_crossentropy: 0.0176
# Epoch 19/50
# 19/19 - 1s - loss: 0.0233 - binary_crossentropy: 0.0188 - val_loss: 0.0221 - val_binary_crossentropy: 0.0176
# Epoch 20/50
# 19/19 - 1s - loss: 0.0234 - binary_crossentropy: 0.0188 - val_loss: 0.0220 - val_binary_crossentropy: 0.0175
# Epoch 21/50
# 19/19 - 1s - loss: 0.0232 - binary_crossentropy: 0.0186 - val_loss: 0.0220 - val_binary_crossentropy: 0.0175
# Epoch 22/50
# 19/19 - 1s - loss: 0.0233 - binary_crossentropy: 0.0187 - val_loss: 0.0219 - val_binary_crossentropy: 0.0174
# Epoch 23/50
# 19/19 - 1s - loss: 0.0233 - binary_crossentropy: 0.0187 - val_loss: 0.0219 - val_binary_crossentropy: 0.0173
# Epoch 24/50
# 19/19 - 1s - loss: 0.0230 - binary_crossentropy: 0.0184 - val_loss: 0.0217 - val_binary_crossentropy: 0.0172
# Epoch 25/50
# 19/19 - 1s - loss: 0.0231 - binary_crossentropy: 0.0185 - val_loss: 0.0217 - val_binary_crossentropy: 0.0172
# Epoch 26/50
# 19/19 - 1s - loss: 0.0230 - binary_crossentropy: 0.0184 - val_loss: 0.0216 - val_binary_crossentropy: 0.0171
# Epoch 27/50
# 19/19 - 1s - loss: 0.0229 - binary_crossentropy: 0.0183 - val_loss: 0.0216 - val_binary_crossentropy: 0.0170
# Epoch 28/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0182 - val_loss: 0.0215 - val_binary_crossentropy: 0.0169
# Epoch 29/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0182 - val_loss: 0.0216 - val_binary_crossentropy: 0.0170
# Epoch 30/50
# 19/19 - 1s - loss: 0.0229 - binary_crossentropy: 0.0182 - val_loss: 0.0215 - val_binary_crossentropy: 0.0168
# Epoch 31/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0182 - val_loss: 0.0215 - val_binary_crossentropy: 0.0168
# Epoch 32/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0181 - val_loss: 0.0214 - val_binary_crossentropy: 0.0168
# Epoch 33/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0181 - val_loss: 0.0213 - val_binary_crossentropy: 0.0167
# Epoch 34/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0180 - val_loss: 0.0213 - val_binary_crossentropy: 0.0167
# Epoch 35/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0214 - val_binary_crossentropy: 0.0168
# Epoch 36/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 37/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0177 - val_loss: 0.0212 - val_binary_crossentropy: 0.0166
# Epoch 38/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0177 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 39/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 40/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0180 - val_loss: 0.0212 - val_binary_crossentropy: 0.0166
# Epoch 41/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 42/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0177 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 43/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 44/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0179 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 45/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0177 - val_loss: 0.0211 - val_binary_crossentropy: 0.0165
# Epoch 46/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0176 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 47/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0177 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 48/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0175 - val_loss: 0.0210 - val_binary_crossentropy: 0.0163
# Epoch 49/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0175 - val_loss: 0.0210 - val_binary_crossentropy: 0.0163
# Epoch 50/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0177 - val_loss: 0.0210 - val_binary_crossentropy: 0.0163
# Epoch 1/50
# 19/19 - 1s - loss: 0.3107 - binary_crossentropy: 0.3092 - val_loss: 0.0412 - val_binary_crossentropy: 0.0355
# Epoch 2/50
# 19/19 - 1s - loss: 0.0287 - binary_crossentropy: 0.0246 - val_loss: 0.0310 - val_binary_crossentropy: 0.0256
# Epoch 3/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0207 - val_loss: 0.0259 - val_binary_crossentropy: 0.0208
# Epoch 4/50
# 19/19 - 1s - loss: 0.0247 - binary_crossentropy: 0.0202 - val_loss: 0.0249 - val_binary_crossentropy: 0.0200
# Epoch 5/50
# 19/19 - 1s - loss: 0.0247 - binary_crossentropy: 0.0202 - val_loss: 0.0242 - val_binary_crossentropy: 0.0194
# Epoch 6/50
# 19/19 - 1s - loss: 0.0246 - binary_crossentropy: 0.0201 - val_loss: 0.0238 - val_binary_crossentropy: 0.0191
# Epoch 7/50
# 19/19 - 1s - loss: 0.0245 - binary_crossentropy: 0.0200 - val_loss: 0.0236 - val_binary_crossentropy: 0.0188
# Epoch 8/50
# 19/19 - 1s - loss: 0.0244 - binary_crossentropy: 0.0198 - val_loss: 0.0233 - val_binary_crossentropy: 0.0186
# Epoch 9/50
# 19/19 - 1s - loss: 0.0244 - binary_crossentropy: 0.0199 - val_loss: 0.0233 - val_binary_crossentropy: 0.0186
# Epoch 10/50
# 19/19 - 1s - loss: 0.0242 - binary_crossentropy: 0.0197 - val_loss: 0.0230 - val_binary_crossentropy: 0.0184
# Epoch 11/50
# 19/19 - 1s - loss: 0.0241 - binary_crossentropy: 0.0195 - val_loss: 0.0228 - val_binary_crossentropy: 0.0182
# Epoch 12/50
# 19/19 - 1s - loss: 0.0240 - binary_crossentropy: 0.0195 - val_loss: 0.0226 - val_binary_crossentropy: 0.0180
# Epoch 13/50
# 19/19 - 1s - loss: 0.0239 - binary_crossentropy: 0.0193 - val_loss: 0.0225 - val_binary_crossentropy: 0.0179
# Epoch 14/50
# 19/19 - 1s - loss: 0.0238 - binary_crossentropy: 0.0192 - val_loss: 0.0224 - val_binary_crossentropy: 0.0178
# Epoch 15/50
# 19/19 - 1s - loss: 0.0237 - binary_crossentropy: 0.0191 - val_loss: 0.0222 - val_binary_crossentropy: 0.0177
# Epoch 16/50
# 19/19 - 1s - loss: 0.0236 - binary_crossentropy: 0.0190 - val_loss: 0.0222 - val_binary_crossentropy: 0.0176
# Epoch 17/50
# 19/19 - 1s - loss: 0.0236 - binary_crossentropy: 0.0191 - val_loss: 0.0220 - val_binary_crossentropy: 0.0174
# Epoch 18/50
# 19/19 - 1s - loss: 0.0235 - binary_crossentropy: 0.0189 - val_loss: 0.0220 - val_binary_crossentropy: 0.0174
# Epoch 19/50
# 19/19 - 1s - loss: 0.0234 - binary_crossentropy: 0.0188 - val_loss: 0.0218 - val_binary_crossentropy: 0.0173
# Epoch 20/50
# 19/19 - 1s - loss: 0.0233 - binary_crossentropy: 0.0188 - val_loss: 0.0218 - val_binary_crossentropy: 0.0172
# Epoch 21/50
# 19/19 - 1s - loss: 0.0232 - binary_crossentropy: 0.0186 - val_loss: 0.0218 - val_binary_crossentropy: 0.0172
# Epoch 22/50
# 19/19 - 1s - loss: 0.0232 - binary_crossentropy: 0.0186 - val_loss: 0.0216 - val_binary_crossentropy: 0.0171
# Epoch 23/50
# 19/19 - 1s - loss: 0.0232 - binary_crossentropy: 0.0186 - val_loss: 0.0216 - val_binary_crossentropy: 0.0170
# Epoch 24/50
# 19/19 - 1s - loss: 0.0231 - binary_crossentropy: 0.0185 - val_loss: 0.0216 - val_binary_crossentropy: 0.0170
# Epoch 25/50
# 19/19 - 1s - loss: 0.0231 - binary_crossentropy: 0.0185 - val_loss: 0.0215 - val_binary_crossentropy: 0.0169
# Epoch 26/50
# 19/19 - 1s - loss: 0.0230 - binary_crossentropy: 0.0184 - val_loss: 0.0215 - val_binary_crossentropy: 0.0169
# Epoch 27/50
# 19/19 - 1s - loss: 0.0229 - binary_crossentropy: 0.0183 - val_loss: 0.0214 - val_binary_crossentropy: 0.0168
# Epoch 28/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0182 - val_loss: 0.0214 - val_binary_crossentropy: 0.0168
# Epoch 29/50
# 19/19 - 1s - loss: 0.0229 - binary_crossentropy: 0.0183 - val_loss: 0.0213 - val_binary_crossentropy: 0.0167
# Epoch 30/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0182 - val_loss: 0.0212 - val_binary_crossentropy: 0.0166
# Epoch 31/50
# 19/19 - 1s - loss: 0.0229 - binary_crossentropy: 0.0183 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 32/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0181 - val_loss: 0.0212 - val_binary_crossentropy: 0.0166
# Epoch 33/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0212 - val_binary_crossentropy: 0.0166
# Epoch 34/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0181 - val_loss: 0.0212 - val_binary_crossentropy: 0.0166
# Epoch 35/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0211 - val_binary_crossentropy: 0.0165
# Epoch 36/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 37/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0179 - val_loss: 0.0211 - val_binary_crossentropy: 0.0165
# Epoch 38/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0177 - val_loss: 0.0210 - val_binary_crossentropy: 0.0163
# Epoch 39/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0179 - val_loss: 0.0210 - val_binary_crossentropy: 0.0164
# Epoch 40/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0178 - val_loss: 0.0210 - val_binary_crossentropy: 0.0163
# Epoch 41/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0176 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 42/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0177 - val_loss: 0.0209 - val_binary_crossentropy: 0.0163
# Epoch 43/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0210 - val_binary_crossentropy: 0.0163
# Epoch 44/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0176 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 45/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0210 - val_binary_crossentropy: 0.0163
# Epoch 46/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0176 - val_loss: 0.0209 - val_binary_crossentropy: 0.0162
# Epoch 47/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0177 - val_loss: 0.0209 - val_binary_crossentropy: 0.0162
# Epoch 48/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0176 - val_loss: 0.0210 - val_binary_crossentropy: 0.0163
# Epoch 49/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0176 - val_loss: 0.0209 - val_binary_crossentropy: 0.0161
# Epoch 50/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0175 - val_loss: 0.0209 - val_binary_crossentropy: 0.0161
# Epoch 1/50
# 19/19 - 1s - loss: 0.3313 - binary_crossentropy: 0.3299 - val_loss: 0.0407 - val_binary_crossentropy: 0.0335
# Epoch 2/50
# 19/19 - 1s - loss: 0.0299 - binary_crossentropy: 0.0260 - val_loss: 0.0299 - val_binary_crossentropy: 0.0244
# Epoch 3/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0207 - val_loss: 0.0263 - val_binary_crossentropy: 0.0211
# Epoch 4/50
# 19/19 - 1s - loss: 0.0248 - binary_crossentropy: 0.0203 - val_loss: 0.0249 - val_binary_crossentropy: 0.0200
# Epoch 5/50
# 19/19 - 1s - loss: 0.0247 - binary_crossentropy: 0.0203 - val_loss: 0.0247 - val_binary_crossentropy: 0.0198
# Epoch 6/50
# 19/19 - 1s - loss: 0.0246 - binary_crossentropy: 0.0202 - val_loss: 0.0244 - val_binary_crossentropy: 0.0196
# Epoch 7/50
# 19/19 - 1s - loss: 0.0244 - binary_crossentropy: 0.0199 - val_loss: 0.0241 - val_binary_crossentropy: 0.0194
# Epoch 8/50
# 19/19 - 1s - loss: 0.0244 - binary_crossentropy: 0.0199 - val_loss: 0.0237 - val_binary_crossentropy: 0.0190
# Epoch 9/50
# 19/19 - 1s - loss: 0.0243 - binary_crossentropy: 0.0198 - val_loss: 0.0236 - val_binary_crossentropy: 0.0189
# Epoch 10/50
# 19/19 - 1s - loss: 0.0241 - binary_crossentropy: 0.0196 - val_loss: 0.0234 - val_binary_crossentropy: 0.0187
# Epoch 11/50
# 19/19 - 1s - loss: 0.0241 - binary_crossentropy: 0.0196 - val_loss: 0.0232 - val_binary_crossentropy: 0.0185
# Epoch 12/50
# 19/19 - 1s - loss: 0.0237 - binary_crossentropy: 0.0192 - val_loss: 0.0231 - val_binary_crossentropy: 0.0185
# Epoch 13/50
# 19/19 - 1s - loss: 0.0238 - binary_crossentropy: 0.0192 - val_loss: 0.0228 - val_binary_crossentropy: 0.0182
# Epoch 14/50
# 19/19 - 1s - loss: 0.0237 - binary_crossentropy: 0.0191 - val_loss: 0.0227 - val_binary_crossentropy: 0.0181
# Epoch 15/50
# 19/19 - 1s - loss: 0.0236 - binary_crossentropy: 0.0190 - val_loss: 0.0225 - val_binary_crossentropy: 0.0179
# Epoch 16/50
# 19/19 - 1s - loss: 0.0235 - binary_crossentropy: 0.0190 - val_loss: 0.0224 - val_binary_crossentropy: 0.0178
# Epoch 17/50
# 19/19 - 1s - loss: 0.0234 - binary_crossentropy: 0.0188 - val_loss: 0.0222 - val_binary_crossentropy: 0.0177
# Epoch 18/50
# 19/19 - 1s - loss: 0.0234 - binary_crossentropy: 0.0189 - val_loss: 0.0222 - val_binary_crossentropy: 0.0176
# Epoch 19/50
# 19/19 - 1s - loss: 0.0233 - binary_crossentropy: 0.0187 - val_loss: 0.0221 - val_binary_crossentropy: 0.0175
# Epoch 20/50
# 19/19 - 1s - loss: 0.0231 - binary_crossentropy: 0.0186 - val_loss: 0.0220 - val_binary_crossentropy: 0.0174
# Epoch 21/50
# 19/19 - 1s - loss: 0.0232 - binary_crossentropy: 0.0186 - val_loss: 0.0220 - val_binary_crossentropy: 0.0174
# Epoch 22/50
# 19/19 - 1s - loss: 0.0231 - binary_crossentropy: 0.0185 - val_loss: 0.0219 - val_binary_crossentropy: 0.0173
# Epoch 23/50
# 19/19 - 1s - loss: 0.0230 - binary_crossentropy: 0.0184 - val_loss: 0.0219 - val_binary_crossentropy: 0.0173
# Epoch 24/50
# 19/19 - 1s - loss: 0.0229 - binary_crossentropy: 0.0183 - val_loss: 0.0217 - val_binary_crossentropy: 0.0172
# Epoch 25/50
# 19/19 - 1s - loss: 0.0230 - binary_crossentropy: 0.0184 - val_loss: 0.0217 - val_binary_crossentropy: 0.0171
# Epoch 26/50
# 19/19 - 1s - loss: 0.0229 - binary_crossentropy: 0.0183 - val_loss: 0.0217 - val_binary_crossentropy: 0.0171
# Epoch 27/50
# 19/19 - 1s - loss: 0.0229 - binary_crossentropy: 0.0183 - val_loss: 0.0217 - val_binary_crossentropy: 0.0171
# Epoch 28/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0182 - val_loss: 0.0216 - val_binary_crossentropy: 0.0170
# Epoch 29/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0181 - val_loss: 0.0215 - val_binary_crossentropy: 0.0169
# Epoch 30/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0181 - val_loss: 0.0215 - val_binary_crossentropy: 0.0169
# Epoch 31/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0182 - val_loss: 0.0215 - val_binary_crossentropy: 0.0169
# Epoch 32/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0180 - val_loss: 0.0215 - val_binary_crossentropy: 0.0169
# Epoch 33/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0215 - val_binary_crossentropy: 0.0169
# Epoch 34/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0181 - val_loss: 0.0214 - val_binary_crossentropy: 0.0168
# Epoch 35/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0180 - val_loss: 0.0214 - val_binary_crossentropy: 0.0168
# Epoch 36/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0214 - val_binary_crossentropy: 0.0167
# Epoch 37/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0179 - val_loss: 0.0214 - val_binary_crossentropy: 0.0167
# Epoch 38/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0179 - val_loss: 0.0213 - val_binary_crossentropy: 0.0167
# Epoch 39/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0178 - val_loss: 0.0214 - val_binary_crossentropy: 0.0167
# Epoch 40/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0177 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 41/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0178 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 42/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0177 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 43/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0176 - val_loss: 0.0213 - val_binary_crossentropy: 0.0165
# Epoch 44/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0177 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 45/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0175 - val_loss: 0.0213 - val_binary_crossentropy: 0.0165
# Epoch 46/50
# 19/19 - 1s - loss: 0.0220 - binary_crossentropy: 0.0174 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 47/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0175 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 48/50
# 19/19 - 1s - loss: 0.0221 - binary_crossentropy: 0.0175 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 49/50
# 19/19 - 1s - loss: 0.0220 - binary_crossentropy: 0.0173 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 50/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0175 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 1/50
# 19/19 - 2s - loss: 0.3036 - binary_crossentropy: 0.3021 - val_loss: 0.0467 - val_binary_crossentropy: 0.0410
# Epoch 2/50
# 19/19 - 1s - loss: 0.0284 - binary_crossentropy: 0.0243 - val_loss: 0.0314 - val_binary_crossentropy: 0.0256
# Epoch 3/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0205 - val_loss: 0.0266 - val_binary_crossentropy: 0.0214
# Epoch 4/50
# 19/19 - 1s - loss: 0.0248 - binary_crossentropy: 0.0202 - val_loss: 0.0256 - val_binary_crossentropy: 0.0206
# Epoch 5/50
# 19/19 - 1s - loss: 0.0247 - binary_crossentropy: 0.0202 - val_loss: 0.0251 - val_binary_crossentropy: 0.0203
# Epoch 6/50
# 19/19 - 1s - loss: 0.0245 - binary_crossentropy: 0.0200 - val_loss: 0.0244 - val_binary_crossentropy: 0.0196
# Epoch 7/50
# 19/19 - 1s - loss: 0.0244 - binary_crossentropy: 0.0199 - val_loss: 0.0243 - val_binary_crossentropy: 0.0196
# Epoch 8/50
# 19/19 - 1s - loss: 0.0245 - binary_crossentropy: 0.0199 - val_loss: 0.0239 - val_binary_crossentropy: 0.0192
# Epoch 9/50
# 19/19 - 1s - loss: 0.0243 - binary_crossentropy: 0.0198 - val_loss: 0.0237 - val_binary_crossentropy: 0.0191
# Epoch 10/50
# 19/19 - 1s - loss: 0.0244 - binary_crossentropy: 0.0198 - val_loss: 0.0235 - val_binary_crossentropy: 0.0189
# Epoch 11/50
# 19/19 - 1s - loss: 0.0241 - binary_crossentropy: 0.0195 - val_loss: 0.0232 - val_binary_crossentropy: 0.0186
# Epoch 12/50
# 19/19 - 1s - loss: 0.0240 - binary_crossentropy: 0.0195 - val_loss: 0.0230 - val_binary_crossentropy: 0.0184
# Epoch 13/50
# 19/19 - 1s - loss: 0.0239 - binary_crossentropy: 0.0193 - val_loss: 0.0230 - val_binary_crossentropy: 0.0184
# Epoch 14/50
# 19/19 - 1s - loss: 0.0237 - binary_crossentropy: 0.0192 - val_loss: 0.0228 - val_binary_crossentropy: 0.0182
# Epoch 15/50
# 19/19 - 1s - loss: 0.0236 - binary_crossentropy: 0.0190 - val_loss: 0.0227 - val_binary_crossentropy: 0.0181
# Epoch 16/50
# 19/19 - 1s - loss: 0.0235 - binary_crossentropy: 0.0190 - val_loss: 0.0225 - val_binary_crossentropy: 0.0180
# Epoch 17/50
# 19/19 - 1s - loss: 0.0235 - binary_crossentropy: 0.0189 - val_loss: 0.0224 - val_binary_crossentropy: 0.0179
# Epoch 18/50
# 19/19 - 1s - loss: 0.0235 - binary_crossentropy: 0.0189 - val_loss: 0.0223 - val_binary_crossentropy: 0.0177
# Epoch 19/50
# 19/19 - 1s - loss: 0.0233 - binary_crossentropy: 0.0187 - val_loss: 0.0222 - val_binary_crossentropy: 0.0177
# Epoch 20/50
# 19/19 - 1s - loss: 0.0235 - binary_crossentropy: 0.0189 - val_loss: 0.0222 - val_binary_crossentropy: 0.0176
# Epoch 21/50
# 19/19 - 1s - loss: 0.0232 - binary_crossentropy: 0.0187 - val_loss: 0.0221 - val_binary_crossentropy: 0.0175
# Epoch 22/50
# 19/19 - 1s - loss: 0.0230 - binary_crossentropy: 0.0184 - val_loss: 0.0221 - val_binary_crossentropy: 0.0175
# Epoch 23/50
# 19/19 - 1s - loss: 0.0230 - binary_crossentropy: 0.0184 - val_loss: 0.0219 - val_binary_crossentropy: 0.0174
# Epoch 24/50
# 19/19 - 1s - loss: 0.0231 - binary_crossentropy: 0.0185 - val_loss: 0.0219 - val_binary_crossentropy: 0.0174
# Epoch 25/50
# 19/19 - 1s - loss: 0.0231 - binary_crossentropy: 0.0186 - val_loss: 0.0218 - val_binary_crossentropy: 0.0173
# Epoch 26/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0182 - val_loss: 0.0219 - val_binary_crossentropy: 0.0173
# Epoch 27/50
# 19/19 - 1s - loss: 0.0230 - binary_crossentropy: 0.0184 - val_loss: 0.0218 - val_binary_crossentropy: 0.0172
# Epoch 28/50
# 19/19 - 1s - loss: 0.0230 - binary_crossentropy: 0.0184 - val_loss: 0.0217 - val_binary_crossentropy: 0.0172
# Epoch 29/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0181 - val_loss: 0.0216 - val_binary_crossentropy: 0.0171
# Epoch 30/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0182 - val_loss: 0.0216 - val_binary_crossentropy: 0.0170
# Epoch 31/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0216 - val_binary_crossentropy: 0.0170
# Epoch 32/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0179 - val_loss: 0.0215 - val_binary_crossentropy: 0.0169
# Epoch 33/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0181 - val_loss: 0.0215 - val_binary_crossentropy: 0.0169
# Epoch 34/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0179 - val_loss: 0.0215 - val_binary_crossentropy: 0.0169
# Epoch 35/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0215 - val_binary_crossentropy: 0.0169
# Epoch 36/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0177 - val_loss: 0.0214 - val_binary_crossentropy: 0.0168
# Epoch 37/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0179 - val_loss: 0.0214 - val_binary_crossentropy: 0.0168
# Epoch 38/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0179 - val_loss: 0.0214 - val_binary_crossentropy: 0.0168
# Epoch 39/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0178 - val_loss: 0.0213 - val_binary_crossentropy: 0.0167
# Epoch 40/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0178 - val_loss: 0.0213 - val_binary_crossentropy: 0.0167
# Epoch 41/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0178 - val_loss: 0.0213 - val_binary_crossentropy: 0.0167
# Epoch 42/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0176 - val_loss: 0.0214 - val_binary_crossentropy: 0.0167
# Epoch 43/50
# 19/19 - 1s - loss: 0.0221 - binary_crossentropy: 0.0175 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 44/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0177 - val_loss: 0.0213 - val_binary_crossentropy: 0.0167
# Epoch 45/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0176 - val_loss: 0.0213 - val_binary_crossentropy: 0.0166
# Epoch 46/50
# 19/19 - 1s - loss: 0.0221 - binary_crossentropy: 0.0174 - val_loss: 0.0212 - val_binary_crossentropy: 0.0166
# Epoch 47/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0176 - val_loss: 0.0212 - val_binary_crossentropy: 0.0166
# Epoch 48/50
# 19/19 - 1s - loss: 0.0221 - binary_crossentropy: 0.0175 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 49/50
# 19/19 - 1s - loss: 0.0220 - binary_crossentropy: 0.0174 - val_loss: 0.0211 - val_binary_crossentropy: 0.0165
# Epoch 50/50
# 19/19 - 1s - loss: 0.0221 - binary_crossentropy: 0.0174 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 1/50
# 19/19 - 1s - loss: 0.2977 - binary_crossentropy: 0.2961 - val_loss: 0.0438 - val_binary_crossentropy: 0.0379
# Epoch 2/50
# 19/19 - 1s - loss: 0.0288 - binary_crossentropy: 0.0247 - val_loss: 0.0305 - val_binary_crossentropy: 0.0246
# Epoch 3/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0206 - val_loss: 0.0267 - val_binary_crossentropy: 0.0214
# Epoch 4/50
# 19/19 - 1s - loss: 0.0250 - binary_crossentropy: 0.0204 - val_loss: 0.0254 - val_binary_crossentropy: 0.0204
# Epoch 5/50
# 19/19 - 1s - loss: 0.0248 - binary_crossentropy: 0.0203 - val_loss: 0.0247 - val_binary_crossentropy: 0.0198
# Epoch 6/50
# 19/19 - 1s - loss: 0.0246 - binary_crossentropy: 0.0201 - val_loss: 0.0240 - val_binary_crossentropy: 0.0192
# Epoch 7/50
# 19/19 - 1s - loss: 0.0245 - binary_crossentropy: 0.0200 - val_loss: 0.0238 - val_binary_crossentropy: 0.0191
# Epoch 8/50
# 19/19 - 1s - loss: 0.0245 - binary_crossentropy: 0.0200 - val_loss: 0.0233 - val_binary_crossentropy: 0.0186
# Epoch 9/50
# 19/19 - 1s - loss: 0.0243 - binary_crossentropy: 0.0198 - val_loss: 0.0232 - val_binary_crossentropy: 0.0185
# Epoch 10/50
# 19/19 - 1s - loss: 0.0240 - binary_crossentropy: 0.0195 - val_loss: 0.0229 - val_binary_crossentropy: 0.0183
# Epoch 11/50
# 19/19 - 1s - loss: 0.0241 - binary_crossentropy: 0.0196 - val_loss: 0.0228 - val_binary_crossentropy: 0.0182
# Epoch 12/50
# 19/19 - 1s - loss: 0.0239 - binary_crossentropy: 0.0194 - val_loss: 0.0226 - val_binary_crossentropy: 0.0180
# Epoch 13/50
# 19/19 - 1s - loss: 0.0239 - binary_crossentropy: 0.0193 - val_loss: 0.0225 - val_binary_crossentropy: 0.0180
# Epoch 14/50
# 19/19 - 1s - loss: 0.0238 - binary_crossentropy: 0.0193 - val_loss: 0.0223 - val_binary_crossentropy: 0.0178
# Epoch 15/50
# 19/19 - 1s - loss: 0.0236 - binary_crossentropy: 0.0191 - val_loss: 0.0222 - val_binary_crossentropy: 0.0176
# Epoch 16/50
# 19/19 - 1s - loss: 0.0235 - binary_crossentropy: 0.0189 - val_loss: 0.0221 - val_binary_crossentropy: 0.0175
# Epoch 17/50
# 19/19 - 1s - loss: 0.0235 - binary_crossentropy: 0.0189 - val_loss: 0.0219 - val_binary_crossentropy: 0.0174
# Epoch 18/50
# 19/19 - 1s - loss: 0.0233 - binary_crossentropy: 0.0187 - val_loss: 0.0218 - val_binary_crossentropy: 0.0173
# Epoch 19/50
# 19/19 - 1s - loss: 0.0233 - binary_crossentropy: 0.0187 - val_loss: 0.0217 - val_binary_crossentropy: 0.0172
# Epoch 20/50
# 19/19 - 1s - loss: 0.0234 - binary_crossentropy: 0.0188 - val_loss: 0.0217 - val_binary_crossentropy: 0.0171
# Epoch 21/50
# 19/19 - 1s - loss: 0.0232 - binary_crossentropy: 0.0186 - val_loss: 0.0217 - val_binary_crossentropy: 0.0171
# Epoch 22/50
# 19/19 - 1s - loss: 0.0233 - binary_crossentropy: 0.0187 - val_loss: 0.0215 - val_binary_crossentropy: 0.0170
# Epoch 23/50
# 19/19 - 1s - loss: 0.0231 - binary_crossentropy: 0.0185 - val_loss: 0.0215 - val_binary_crossentropy: 0.0170
# Epoch 24/50
# 19/19 - 1s - loss: 0.0230 - binary_crossentropy: 0.0184 - val_loss: 0.0215 - val_binary_crossentropy: 0.0169
# Epoch 25/50
# 19/19 - 1s - loss: 0.0230 - binary_crossentropy: 0.0184 - val_loss: 0.0213 - val_binary_crossentropy: 0.0168
# Epoch 26/50
# 19/19 - 1s - loss: 0.0231 - binary_crossentropy: 0.0185 - val_loss: 0.0213 - val_binary_crossentropy: 0.0168
# Epoch 27/50
# 19/19 - 1s - loss: 0.0230 - binary_crossentropy: 0.0184 - val_loss: 0.0213 - val_binary_crossentropy: 0.0167
# Epoch 28/50
# 19/19 - 1s - loss: 0.0230 - binary_crossentropy: 0.0184 - val_loss: 0.0213 - val_binary_crossentropy: 0.0167
# Epoch 29/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0212 - val_binary_crossentropy: 0.0166
# Epoch 30/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0181 - val_loss: 0.0211 - val_binary_crossentropy: 0.0166
# Epoch 31/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0181 - val_loss: 0.0212 - val_binary_crossentropy: 0.0166
# Epoch 32/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0181 - val_loss: 0.0212 - val_binary_crossentropy: 0.0165
# Epoch 33/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0182 - val_loss: 0.0210 - val_binary_crossentropy: 0.0164
# Epoch 34/50
# 19/19 - 1s - loss: 0.0228 - binary_crossentropy: 0.0181 - val_loss: 0.0211 - val_binary_crossentropy: 0.0165
# Epoch 35/50
# 19/19 - 1s - loss: 0.0227 - binary_crossentropy: 0.0181 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 36/50
# 19/19 - 1s - loss: 0.0226 - binary_crossentropy: 0.0180 - val_loss: 0.0211 - val_binary_crossentropy: 0.0164
# Epoch 37/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0178 - val_loss: 0.0210 - val_binary_crossentropy: 0.0163
# Epoch 38/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0177 - val_loss: 0.0210 - val_binary_crossentropy: 0.0163
# Epoch 39/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0209 - val_binary_crossentropy: 0.0162
# Epoch 40/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0209 - val_binary_crossentropy: 0.0162
# Epoch 41/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0209 - val_binary_crossentropy: 0.0163
# Epoch 42/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0178 - val_loss: 0.0209 - val_binary_crossentropy: 0.0163
# Epoch 43/50
# 19/19 - 1s - loss: 0.0225 - binary_crossentropy: 0.0178 - val_loss: 0.0209 - val_binary_crossentropy: 0.0162
# Epoch 44/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0176 - val_loss: 0.0208 - val_binary_crossentropy: 0.0161
# Epoch 45/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0176 - val_loss: 0.0208 - val_binary_crossentropy: 0.0161
# Epoch 46/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0176 - val_loss: 0.0207 - val_binary_crossentropy: 0.0160
# Epoch 47/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0177 - val_loss: 0.0208 - val_binary_crossentropy: 0.0161
# Epoch 48/50
# 19/19 - 1s - loss: 0.0224 - binary_crossentropy: 0.0177 - val_loss: 0.0207 - val_binary_crossentropy: 0.0161
# Epoch 49/50
# 19/19 - 1s - loss: 0.0222 - binary_crossentropy: 0.0175 - val_loss: 0.0207 - val_binary_crossentropy: 0.0161
# Epoch 50/50
# 19/19 - 1s - loss: 0.0223 - binary_crossentropy: 0.0176 - val_loss: 0.0207 - val_binary_crossentropy: 0.0160
#
# oof_score: 0.0160409071136039
# oof_auc_score: 0.6738923949255359
# ----------------------------------------------------------------------------------------------------

# %%
oof_score
# Out:
# 0.0160409071136039
