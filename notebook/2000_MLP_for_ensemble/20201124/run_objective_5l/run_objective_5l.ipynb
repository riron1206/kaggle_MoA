# %%
# !pwd
import sys
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
sys.executable
# Out:
# C:\Users\81908\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124\run_objective_5l
# 'c:\\users\\81908\\appdata\\local\\pypoetry\\cache\\virtualenvs\\tfgpu-ehdmne1y-py3.8\\scripts\\python.exe'

# %%
# tensorflow2.0 + kerasでGPUメモリの使用量を抑える方法(最小限だけ使うように設定)
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"

# %%
import sys
sys.path.append(r'C:\Users\81908\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124')
import moa_MLPs_funcs
# Out:
# Tensorflow version 2.3.1
# n_classes: 206

# %%
import optuna


def objective(trial):
    model_type = "5l"
    params = {}
    params["activation"] = trial.suggest_categorical("activation", ["relu", "elu"])
    params["denses"] = trial.suggest_categorical(
        "denses",
        [
            [512, 448, 384, 320, 256],
            [1024, 896, 768, 640, 512],
            [2048, 1792, 1536, 1280, 1024],
            [2560, 2048, 1524, 1012, 780],
            [512, 512, 512, 512, 512],
            [1024, 1024, 1024, 1024, 1024],
            [1024, 768, 1280, 1536, 1792],
            [1024, 1280, 1536, 768, 1792],
            [512, 768, 1280, 1536, 1792],
            [512, 1536, 1280, 768, 512],
        ],
    )
    drop_rates = []
    for i in range(6):
        drop_rate = trial.suggest_uniform(f'drop_rate{i}', 0.2, 0.8)
        drop_rates.append(drop_rate)
    params["drop_rates"] = drop_rates
    print("-" * 100)
    print(f"params: {params}")

    oof_score, Y_pred = moa_MLPs_funcs.train_and_evaluate(model_type="5l", params=params)

    return oof_score

# %%
# %%time

n_trials = 100
#n_trials = 50

study = optuna.create_study(
    study_name="study",
    storage=f"sqlite:///study.db",
    load_if_exists=True,
    direction="minimize",
    sampler=optuna.samplers.TPESampler(seed=1),
)
study.optimize(objective, n_trials=n_trials)
study.trials_dataframe().to_csv(f"objective_history.csv", index=False)
with open(f"objective_best_params.txt", mode="w") as f:
    f.write(str(study.best_params))
print(f"\nstudy.best_params:\n{study.best_params}")
# Out:
# [I 2020-11-24 15:01:13,689] A new study created in memory with name: study
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [512, 448, 384, 320, 256] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [1024, 896, 768, 640, 512] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [2048, 1792, 1536, 1280, 1024] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [2560, 2048, 1524, 1012, 780] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [512, 512, 512, 512, 512] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [1024, 1024, 1024, 1024, 1024] which is of type list.
#   warnings.warn(message)
# ----------------------------------------------------------------------------------------------------
# params: {'activation': 'elu', 'denses': [2560, 2048, 1524, 1012, 780], 'drop_rates': [0.6321946960652949, 0.20006862489040694, 0.3813995435791039, 0.2880535344902678, 0.2554031568612787, 0.3117561268266026]}
# WARNING:tensorflow:From C:\Users\81908\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124\moa_MLPs_funcs.py:474: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass shuffle=True, random_state=0 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# Epoch 1/50
# 19/19 - 2s - loss: 0.3572 - binary_crossentropy: 0.3556 - val_loss: 0.5598 - val_binary_crossentropy: 0.5195
# Epoch 2/50
# 19/19 - 1s - loss: 0.0294 - binary_crossentropy: 0.0231 - val_loss: 0.1568 - val_binary_crossentropy: 0.1399
# Epoch 3/50
# 19/19 - 1s - loss: 0.0291 - binary_crossentropy: 0.0219 - val_loss: 0.0598 - val_binary_crossentropy: 0.0492
# Epoch 4/50
# 19/19 - 1s - loss: 0.0273 - binary_crossentropy: 0.0207 - val_loss: 0.0379 - val_binary_crossentropy: 0.0298
# Epoch 5/50
# 19/19 - 1s - loss: 0.0266 - binary_crossentropy: 0.0205 - val_loss: 0.0300 - val_binary_crossentropy: 0.0231
# Epoch 6/50
# 19/19 - 1s - loss: 0.0264 - binary_crossentropy: 0.0205 - val_loss: 0.0281 - val_binary_crossentropy: 0.0217
# Epoch 7/50
# 19/19 - 1s - loss: 0.0262 - binary_crossentropy: 0.0204 - val_loss: 0.0272 - val_binary_crossentropy: 0.0210
# Epoch 8/50
# 19/19 - 1s - loss: 0.0263 - binary_crossentropy: 0.0205 - val_loss: 0.0266 - val_binary_crossentropy: 0.0206
# Epoch 9/50
# 19/19 - 1s - loss: 0.0262 - binary_crossentropy: 0.0204 - val_loss: 0.0263 - val_binary_crossentropy: 0.0203
# Epoch 10/50
# 19/19 - 1s - loss: 0.0261 - binary_crossentropy: 0.0203 - val_loss: 0.0261 - val_binary_crossentropy: 0.0201
# Epoch 11/50
# 19/19 - 1s - loss: 0.0261 - binary_crossentropy: 0.0203 - val_loss: 0.0259 - val_binary_crossentropy: 0.0200
# Epoch 12/50
# 19/19 - 1s - loss: 0.0261 - binary_crossentropy: 0.0203 - val_loss: 0.0258 - val_binary_crossentropy: 0.0199
# Epoch 13/50
# 19/19 - 1s - loss: 0.0261 - binary_crossentropy: 0.0203 - val_loss: 0.0257 - val_binary_crossentropy: 0.0198
# Epoch 14/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0202 - val_loss: 0.0256 - val_binary_crossentropy: 0.0197
# Epoch 15/50
# 19/19 - 1s - loss: 0.0261 - binary_crossentropy: 0.0203 - val_loss: 0.0256 - val_binary_crossentropy: 0.0197
# Epoch 16/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0255 - val_binary_crossentropy: 0.0196
# Epoch 17/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0254 - val_binary_crossentropy: 0.0195
# Epoch 18/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0202 - val_loss: 0.0254 - val_binary_crossentropy: 0.0196
# Epoch 19/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0253 - val_binary_crossentropy: 0.0195
# Epoch 20/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0253 - val_binary_crossentropy: 0.0194
# Epoch 21/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0253 - val_binary_crossentropy: 0.0194
# Epoch 22/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0252 - val_binary_crossentropy: 0.0194
# Epoch 23/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0252 - val_binary_crossentropy: 0.0194
# Epoch 24/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0198 - val_loss: 0.0251 - val_binary_crossentropy: 0.0193
# Epoch 25/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0251 - val_binary_crossentropy: 0.0193
# Epoch 26/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0251 - val_binary_crossentropy: 0.0192
# Epoch 27/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0250 - val_binary_crossentropy: 0.0192
# Epoch 28/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0250 - val_binary_crossentropy: 0.0192
# Epoch 29/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0197 - val_loss: 0.0249 - val_binary_crossentropy: 0.0191
# Epoch 30/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0197 - val_loss: 0.0249 - val_binary_crossentropy: 0.0191
# Epoch 31/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0249 - val_binary_crossentropy: 0.0191
# Epoch 32/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0248 - val_binary_crossentropy: 0.0190
# Epoch 33/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0196 - val_loss: 0.0248 - val_binary_crossentropy: 0.0190
# Epoch 34/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0196 - val_loss: 0.0247 - val_binary_crossentropy: 0.0189
# Epoch 35/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0196 - val_loss: 0.0247 - val_binary_crossentropy: 0.0188
# Epoch 36/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0246 - val_binary_crossentropy: 0.0188
# Epoch 37/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0246 - val_binary_crossentropy: 0.0188
# Epoch 38/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0245 - val_binary_crossentropy: 0.0187
# Epoch 39/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0194 - val_loss: 0.0245 - val_binary_crossentropy: 0.0187
# Epoch 40/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0245 - val_binary_crossentropy: 0.0187
# Epoch 41/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0245 - val_binary_crossentropy: 0.0186
# Epoch 42/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0194 - val_loss: 0.0244 - val_binary_crossentropy: 0.0186
# Epoch 43/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0194 - val_loss: 0.0244 - val_binary_crossentropy: 0.0186
# Epoch 44/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0195 - val_loss: 0.0244 - val_binary_crossentropy: 0.0185
# Epoch 45/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0194 - val_loss: 0.0243 - val_binary_crossentropy: 0.0185
# Epoch 46/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0193 - val_loss: 0.0242 - val_binary_crossentropy: 0.0184
# Epoch 47/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0194 - val_loss: 0.0243 - val_binary_crossentropy: 0.0184
# Epoch 48/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0193 - val_loss: 0.0243 - val_binary_crossentropy: 0.0184
# Epoch 49/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0193 - val_loss: 0.0242 - val_binary_crossentropy: 0.0183
# Epoch 50/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0194 - val_loss: 0.0241 - val_binary_crossentropy: 0.0183
# Epoch 1/50
# 19/19 - 2s - loss: 0.4093 - binary_crossentropy: 0.4078 - val_loss: 7.7894 - val_binary_crossentropy: 7.7862
# Epoch 2/50
# 19/19 - 1s - loss: 0.0294 - binary_crossentropy: 0.0236 - val_loss: 2.8783 - val_binary_crossentropy: 2.8768
# Epoch 3/50
# 19/19 - 1s - loss: 0.0287 - binary_crossentropy: 0.0217 - val_loss: 0.4558 - val_binary_crossentropy: 0.4510
# Epoch 4/50
# 19/19 - 1s - loss: 0.0270 - binary_crossentropy: 0.0205 - val_loss: 0.0848 - val_binary_crossentropy: 0.0793
# Epoch 5/50
# 19/19 - 1s - loss: 0.0264 - binary_crossentropy: 0.0203 - val_loss: 0.0417 - val_binary_crossentropy: 0.0360
# Epoch 6/50
# 19/19 - 1s - loss: 0.0262 - binary_crossentropy: 0.0203 - val_loss: 0.0311 - val_binary_crossentropy: 0.0254
# Epoch 7/50
# 19/19 - 1s - loss: 0.0261 - binary_crossentropy: 0.0202 - val_loss: 0.0280 - val_binary_crossentropy: 0.0223
# Epoch 8/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0202 - val_loss: 0.0271 - val_binary_crossentropy: 0.0214
# Epoch 9/50
# 19/19 - 1s - loss: 0.0261 - binary_crossentropy: 0.0203 - val_loss: 0.0263 - val_binary_crossentropy: 0.0205
# Epoch 10/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0202 - val_loss: 0.0260 - val_binary_crossentropy: 0.0202
# Epoch 11/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0256 - val_binary_crossentropy: 0.0198
# Epoch 12/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0254 - val_binary_crossentropy: 0.0196
# Epoch 13/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0200 - val_loss: 0.0252 - val_binary_crossentropy: 0.0195
# Epoch 14/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0251 - val_binary_crossentropy: 0.0193
# Epoch 15/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0250 - val_binary_crossentropy: 0.0192
# Epoch 16/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0249 - val_binary_crossentropy: 0.0191
# Epoch 17/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0248 - val_binary_crossentropy: 0.0190
# Epoch 18/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0198 - val_loss: 0.0248 - val_binary_crossentropy: 0.0189
# Epoch 19/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0247 - val_binary_crossentropy: 0.0189
# Epoch 20/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0247 - val_binary_crossentropy: 0.0188
# Epoch 21/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0197 - val_loss: 0.0246 - val_binary_crossentropy: 0.0188
# Epoch 22/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0246 - val_binary_crossentropy: 0.0187
# Epoch 23/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0198 - val_loss: 0.0245 - val_binary_crossentropy: 0.0187
# Epoch 24/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0245 - val_binary_crossentropy: 0.0187
# Epoch 25/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0245 - val_binary_crossentropy: 0.0186
# Epoch 26/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0197 - val_loss: 0.0244 - val_binary_crossentropy: 0.0186
# Epoch 27/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0196 - val_loss: 0.0244 - val_binary_crossentropy: 0.0186
# Epoch 28/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0244 - val_binary_crossentropy: 0.0185
# Epoch 29/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0196 - val_loss: 0.0244 - val_binary_crossentropy: 0.0185
# Epoch 30/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0243 - val_binary_crossentropy: 0.0185
# Epoch 31/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0243 - val_binary_crossentropy: 0.0185
# Epoch 32/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0243 - val_binary_crossentropy: 0.0184
# Epoch 33/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0194 - val_loss: 0.0242 - val_binary_crossentropy: 0.0184
# Epoch 34/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0196 - val_loss: 0.0243 - val_binary_crossentropy: 0.0184
# Epoch 35/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0242 - val_binary_crossentropy: 0.0184
# Epoch 36/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0195 - val_loss: 0.0242 - val_binary_crossentropy: 0.0184
# Epoch 37/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0195 - val_loss: 0.0242 - val_binary_crossentropy: 0.0184
# Epoch 38/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0193 - val_loss: 0.0241 - val_binary_crossentropy: 0.0183
# Epoch 39/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0241 - val_binary_crossentropy: 0.0183
# Epoch 40/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0241 - val_binary_crossentropy: 0.0183
# Epoch 41/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0194 - val_loss: 0.0240 - val_binary_crossentropy: 0.0182
# Epoch 42/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0194 - val_loss: 0.0240 - val_binary_crossentropy: 0.0182
# Epoch 43/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0194 - val_loss: 0.0240 - val_binary_crossentropy: 0.0182
# Epoch 44/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0194 - val_loss: 0.0240 - val_binary_crossentropy: 0.0181
# Epoch 45/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0194 - val_loss: 0.0239 - val_binary_crossentropy: 0.0181
# Epoch 46/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0194 - val_loss: 0.0239 - val_binary_crossentropy: 0.0181
# Epoch 47/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0239 - val_binary_crossentropy: 0.0181
# Epoch 48/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0194 - val_loss: 0.0239 - val_binary_crossentropy: 0.0181
# Epoch 49/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0194 - val_loss: 0.0239 - val_binary_crossentropy: 0.0180
# Epoch 50/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0193 - val_loss: 0.0239 - val_binary_crossentropy: 0.0180
# Epoch 1/50
# 19/19 - 2s - loss: 0.3822 - binary_crossentropy: 0.3806 - val_loss: 0.5458 - val_binary_crossentropy: 0.5284
# Epoch 2/50
# 19/19 - 1s - loss: 0.0290 - binary_crossentropy: 0.0228 - val_loss: 0.1599 - val_binary_crossentropy: 0.1441
# Epoch 3/50
# 19/19 - 1s - loss: 0.0287 - binary_crossentropy: 0.0215 - val_loss: 0.0633 - val_binary_crossentropy: 0.0523
# Epoch 4/50
# 19/19 - 1s - loss: 0.0270 - binary_crossentropy: 0.0204 - val_loss: 0.0374 - val_binary_crossentropy: 0.0289
# Epoch 5/50
# 19/19 - 1s - loss: 0.0263 - binary_crossentropy: 0.0202 - val_loss: 0.0316 - val_binary_crossentropy: 0.0244
# Epoch 6/50
# 19/19 - 1s - loss: 0.0262 - binary_crossentropy: 0.0203 - val_loss: 0.0289 - val_binary_crossentropy: 0.0223
# Epoch 7/50
# 19/19 - 1s - loss: 0.0261 - binary_crossentropy: 0.0202 - val_loss: 0.0272 - val_binary_crossentropy: 0.0209
# Epoch 8/50
# 19/19 - 1s - loss: 0.0261 - binary_crossentropy: 0.0203 - val_loss: 0.0267 - val_binary_crossentropy: 0.0206
# Epoch 9/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0202 - val_loss: 0.0263 - val_binary_crossentropy: 0.0202
# Epoch 10/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0262 - val_binary_crossentropy: 0.0202
# Epoch 11/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0202 - val_loss: 0.0260 - val_binary_crossentropy: 0.0200
# Epoch 12/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0260 - val_binary_crossentropy: 0.0200
# Epoch 13/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0259 - val_binary_crossentropy: 0.0199
# Epoch 14/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0258 - val_binary_crossentropy: 0.0199
# Epoch 15/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0200 - val_loss: 0.0257 - val_binary_crossentropy: 0.0198
# Epoch 16/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0200 - val_loss: 0.0256 - val_binary_crossentropy: 0.0197
# Epoch 17/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0200 - val_loss: 0.0255 - val_binary_crossentropy: 0.0196
# Epoch 18/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0256 - val_binary_crossentropy: 0.0197
# Epoch 19/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0255 - val_binary_crossentropy: 0.0196
# Epoch 20/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0254 - val_binary_crossentropy: 0.0195
# Epoch 21/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0254 - val_binary_crossentropy: 0.0195
# Epoch 22/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0199 - val_loss: 0.0254 - val_binary_crossentropy: 0.0195
# Epoch 23/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0253 - val_binary_crossentropy: 0.0195
# Epoch 24/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0253 - val_binary_crossentropy: 0.0194
# Epoch 25/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0253 - val_binary_crossentropy: 0.0194
# Epoch 26/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0252 - val_binary_crossentropy: 0.0194
# Epoch 27/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0252 - val_binary_crossentropy: 0.0193
# Epoch 28/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0251 - val_binary_crossentropy: 0.0193
# Epoch 29/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0251 - val_binary_crossentropy: 0.0192
# Epoch 30/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0251 - val_binary_crossentropy: 0.0192
# Epoch 31/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0250 - val_binary_crossentropy: 0.0192
# Epoch 32/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     336         try:
#     337             if n_jobs == 1:
# --> 338                 self._optimize_sequential(
#     339                     func, n_trials, timeout, catch, callbacks, gc_after_trial, None
#     340                 )
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\study.py in _optimize_sequential(self, func, n_trials, timeout, catch, callbacks, gc_after_trial, time_start)
#     745                     break
#     746
# --> 747             self._run_trial_and_callbacks(func, catch, callbacks, gc_after_trial)
#     748
#     749             self._progress_bar.update((datetime.datetime.now() - time_start).total_seconds())
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\study.py in _run_trial_and_callbacks(self, func, catch, callbacks, gc_after_trial)
#     774     ) -> None:
#     775
# --> 776         trial = self._run_trial(func, catch, gc_after_trial)
#     777         if callbacks is not None:
#     778             frozen_trial = copy.deepcopy(self._storage.get_trial(trial._trial_id))
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\study.py in _run_trial(self, func, catch, gc_after_trial)
#     797
#     798         try:
# --> 799             result = func(trial)
#     800         except exceptions.TrialPruned as e:
#     801             message = "Trial {} pruned. {}".format(trial_number, str(e))
#
# <ipython-input-5-530e1d207bd5> in objective(trial)
#      25     print(f"params: {params}")
#      26
# ---> 27     oof_score, Y_pred = moa_MLPs_funcs.train_and_evaluate(model_type="5l", params=params)
#      28
#      29     return oof_score
#
# ~\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124\moa_MLPs_funcs.py in train_and_evaluate(model_type, params)
#     729     with open("counts.pkl", "wb") as f:
#     730         pickle.dump(counts, f)
# --> 731
#     732     with open(f"Y_pred_{model_type}.pkl", "wb") as f:
#     733         pickle.dump(Y_pred[columns], f)
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1841       `args` and `kwargs`.
#    1842     """
# -> 1843     return self._call_flat(
#    1844         [t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1845          if isinstance(t, (ops.Tensor,
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1921         and executing_eagerly):
#    1922       # No tape is watching; skip to running the function.
# -> 1923       return self._build_call_outputs(self._inference_function.call(
#    1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543       with _InterpolateFunctionError(self):
#     544         if cancellation_manager is None:
# --> 545           outputs = execute.execute(
#     546               str(self.signature.name),
#     547               num_outputs=self._num_outputs,
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
