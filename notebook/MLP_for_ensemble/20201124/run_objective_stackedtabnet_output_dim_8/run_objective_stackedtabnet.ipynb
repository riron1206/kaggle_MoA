# %%
# !pwd
import sys
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
sys.executable
# Out:
# C:\Users\81908\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124\run_objective_stackedtabnet_output_dim_8
# 'c:\\users\\81908\\appdata\\local\\pypoetry\\cache\\virtualenvs\\tfgpu-ehdmne1y-py3.8\\scripts\\python.exe'

# %%
# tensorflow2.0 + kerasでGPUメモリの使用量を抑える方法(最小限だけ使うように設定)
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"

# %%
import sys
sys.path.append(r'C:\Users\81908\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124')
import moa_MLPs_funcs
# Out:
# Tensorflow version 2.3.1
# n_classes: 206

# %%
import optuna


def objective(trial):
    model_type = "stacked_tabnet"
    
    params = dict(
        epsilon=1e-05,
        feature_columns=None,  # データセットのTensorflow特徴列
        virtual_batch_size=None,  # 仮想バッチサイズ。全体のバッチサイズは virtual_batch_size の整数倍じゃないとだめらしい
        num_layers=2,  # 重ねるTabNetsの数
        num_decision_steps=1,  # decision stepsの数
        norm_type="batch",  # 正規化のタイプ
        num_groups=-1,  # group normarizaionのグループの数。よくわからん
        batch_momentum=0.9, # 仮想バッチのMomentum。よくわからん
        relaxation_factor=trial.suggest_categorical("gamma", [1.0, 1.2, 1.5, 2.0]),  # 論文の探索範囲
        sparsity_coefficient=trial.suggest_categorical("lambda_sparse", [0, 0.000001, 0.0001, 0.001, 0.01, 0.1]),  # 論文の探索範囲。sparsity正則化
    )
    # feature_dim must be larger than output dim
    # feature_dim must be a list of length `num_layers`
    params["feature_dim"] = trial.suggest_categorical("Na", [128, 256, 512, 768, 1024, 1536, 2048])  # feature transformation block
    
    params["output_dim"] = 8  # params["feature_dim"]  # int(trial.suggest_uniform("Nd", params["feature_dim"] // 8, params["feature_dim"]))  # decision step

    print("-" * 100)
    print(f"params: {params}")

    oof_score, Y_pred = moa_MLPs_funcs.train_and_evaluate(
        model_type=model_type, params=params
    )

    return oof_score

# %%
# %%time

import warnings
warnings.filterwarnings('ignore')

#n_trials = 100
n_trials = 30
#n_trials = 3

study = optuna.create_study(
    study_name="study",
    storage=f"sqlite:///study.db",
    load_if_exists=True,
    direction="minimize",
    sampler=optuna.samplers.TPESampler(seed=1),
)
study.optimize(objective, n_trials=n_trials)
study.trials_dataframe().to_csv(f"objective_history.csv", index=False)
with open(f"objective_best_params.txt", mode="w") as f:
    f.write(str(study.best_params))
print(f"\nstudy.best_params:\n{study.best_params}")
print(f"\nstudy.best_value:\n{study.best_value}")
# Out:
# [I 2020-11-26 17:31:27,733] A new study created in RDB with name: study
# ----------------------------------------------------------------------------------------------------
# params: {'epsilon': 1e-05, 'feature_columns': None, 'virtual_batch_size': None, 'num_layers': 2, 'num_decision_steps': 1, 'norm_type': 'batch', 'num_groups': -1, 'batch_momentum': 0.9, 'relaxation_factor': 1.2, 'sparsity_coefficient': 0.001, 'feature_dim': 1024, 'output_dim': 8}
# WARNING:tensorflow:From C:\Users\81908\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124\moa_MLPs_funcs.py:694: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# WARNING:tensorflow:Layer stacked_tab_net_classifier is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 19/19 - 2s - loss: 0.6941 - val_loss: 0.6931
# Epoch 2/50
# 19/19 - 1s - loss: 0.6904 - val_loss: 0.6905
# Epoch 3/50
# 19/19 - 2s - loss: 0.6823 - val_loss: 0.6764
# Epoch 4/50
# 19/19 - 2s - loss: 0.6653 - val_loss: 0.6488
# Epoch 5/50
# 19/19 - 2s - loss: 0.6373 - val_loss: 0.6054
# Epoch 6/50
# 19/19 - 2s - loss: 0.5984 - val_loss: 0.5598
# Epoch 7/50
# 19/19 - 2s - loss: 0.5448 - val_loss: 0.4652
# Epoch 8/50
# 19/19 - 2s - loss: 0.4701 - val_loss: 0.3916
# Epoch 9/50
# 19/19 - 2s - loss: 0.3745 - val_loss: 0.2943
# Epoch 10/50
# 19/19 - 1s - loss: 0.2731 - val_loss: 0.2026
# Epoch 11/50
# 19/19 - 2s - loss: 0.1836 - val_loss: 0.1353
# Epoch 12/50
# 19/19 - 2s - loss: 0.1226 - val_loss: 0.1033
# Epoch 13/50
# 19/19 - 2s - loss: 0.0866 - val_loss: 0.0745
# Epoch 14/50
# 19/19 - 2s - loss: 0.0654 - val_loss: 0.0589
# Epoch 15/50
# 19/19 - 2s - loss: 0.0524 - val_loss: 0.0493
# Epoch 16/50
# 19/19 - 2s - loss: 0.0445 - val_loss: 0.0413
# Epoch 17/50
# 19/19 - 2s - loss: 0.0392 - val_loss: 0.0370
# Epoch 18/50
# 19/19 - 2s - loss: 0.0356 - val_loss: 0.0345
# Epoch 19/50
# 19/19 - 2s - loss: 0.0329 - val_loss: 0.0317
# Epoch 20/50
# 19/19 - 2s - loss: 0.0309 - val_loss: 0.0300
# Epoch 21/50
# 19/19 - 2s - loss: 0.0293 - val_loss: 0.0290
# Epoch 22/50
# 19/19 - 2s - loss: 0.0283 - val_loss: 0.0275
# Epoch 23/50
# 19/19 - 2s - loss: 0.0274 - val_loss: 0.0269
# Epoch 24/50
# 19/19 - 2s - loss: 0.0266 - val_loss: 0.0263
# Epoch 25/50
# 19/19 - 2s - loss: 0.0262 - val_loss: 0.0258
# Epoch 26/50
# 19/19 - 2s - loss: 0.0257 - val_loss: 0.0255
# Epoch 27/50
# 19/19 - 2s - loss: 0.0253 - val_loss: 0.0252
# Epoch 28/50
# 19/19 - 2s - loss: 0.0250 - val_loss: 0.0249
# Epoch 29/50
# 19/19 - 2s - loss: 0.0248 - val_loss: 0.0246
# Epoch 30/50
# 19/19 - 1s - loss: 0.0246 - val_loss: 0.0244
# Epoch 31/50
# 19/19 - 1s - loss: 0.0244 - val_loss: 0.0242
# Epoch 32/50
# 19/19 - 1s - loss: 0.0243 - val_loss: 0.0241
# Epoch 33/50
# 19/19 - 1s - loss: 0.0241 - val_loss: 0.0240
# Epoch 34/50
# 19/19 - 1s - loss: 0.0240 - val_loss: 0.0238
# Epoch 35/50
# 19/19 - 1s - loss: 0.0238 - val_loss: 0.0237
# Epoch 36/50
# 19/19 - 1s - loss: 0.0237 - val_loss: 0.0235
# Epoch 37/50
# 19/19 - 1s - loss: 0.0235 - val_loss: 0.0235
# Epoch 38/50
# 19/19 - 1s - loss: 0.0234 - val_loss: 0.0233
# Epoch 39/50
# 19/19 - 1s - loss: 0.0233 - val_loss: 0.0231
# Epoch 40/50
# 19/19 - 1s - loss: 0.0234 - val_loss: 0.0229
# Epoch 41/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0229
# Epoch 42/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0227
# Epoch 43/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0227
# Epoch 44/50
# 19/19 - 2s - loss: 0.0230 - val_loss: 0.0226
# Epoch 45/50
# 19/19 - 2s - loss: 0.0229 - val_loss: 0.0225
# Epoch 46/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0224
# Epoch 47/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0223
# Epoch 48/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0223
# Epoch 49/50
# 19/19 - 2s - loss: 0.0227 - val_loss: 0.0222
# Epoch 50/50
# 19/19 - 2s - loss: 0.0226 - val_loss: 0.0221
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# WARNING:tensorflow:Layer stacked_tab_net_classifier is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 19/19 - 2s - loss: 0.6880 - val_loss: 0.6913
# Epoch 2/50
# 19/19 - 1s - loss: 0.6771 - val_loss: 0.6813
# Epoch 3/50
# 19/19 - 2s - loss: 0.6602 - val_loss: 0.6504
# Epoch 4/50
# 19/19 - 1s - loss: 0.6274 - val_loss: 0.6033
# Epoch 5/50
# 19/19 - 1s - loss: 0.5776 - val_loss: 0.5441
# Epoch 6/50
# 19/19 - 2s - loss: 0.5094 - val_loss: 0.4556
# Epoch 7/50
# 19/19 - 1s - loss: 0.4226 - val_loss: 0.3668
# Epoch 8/50
# 19/19 - 2s - loss: 0.3255 - val_loss: 0.2675
# Epoch 9/50
# 19/19 - 2s - loss: 0.2290 - val_loss: 0.1834
# Epoch 10/50
# 19/19 - 2s - loss: 0.1541 - val_loss: 0.1268
# Epoch 11/50
# 19/19 - 2s - loss: 0.1041 - val_loss: 0.0868
# Epoch 12/50
# 19/19 - 2s - loss: 0.0755 - val_loss: 0.0632
# Epoch 13/50
# 19/19 - 2s - loss: 0.0582 - val_loss: 0.0516
# Epoch 14/50
# 19/19 - 2s - loss: 0.0479 - val_loss: 0.0443
# Epoch 15/50
# 19/19 - 2s - loss: 0.0412 - val_loss: 0.0384
# Epoch 16/50
# 19/19 - 2s - loss: 0.0365 - val_loss: 0.0348
# Epoch 17/50
# 19/19 - 2s - loss: 0.0336 - val_loss: 0.0318
# Epoch 18/50
# 19/19 - 2s - loss: 0.0311 - val_loss: 0.0301
# Epoch 19/50
# 19/19 - 2s - loss: 0.0296 - val_loss: 0.0286
# Epoch 20/50
# 19/19 - 2s - loss: 0.0282 - val_loss: 0.0275
# Epoch 21/50
# 19/19 - 2s - loss: 0.0274 - val_loss: 0.0269
# Epoch 22/50
# 19/19 - 2s - loss: 0.0268 - val_loss: 0.0261
# Epoch 23/50
# 19/19 - 2s - loss: 0.0262 - val_loss: 0.0257
# Epoch 24/50
# 19/19 - 2s - loss: 0.0257 - val_loss: 0.0252
# Epoch 25/50
# 19/19 - 1s - loss: 0.0254 - val_loss: 0.0248
# Epoch 26/50
# 19/19 - 1s - loss: 0.0250 - val_loss: 0.0246
# Epoch 27/50
# 19/19 - 1s - loss: 0.0247 - val_loss: 0.0243
# Epoch 28/50
# 19/19 - 1s - loss: 0.0244 - val_loss: 0.0241
# Epoch 29/50
# 19/19 - 1s - loss: 0.0243 - val_loss: 0.0238
# Epoch 30/50
# 19/19 - 1s - loss: 0.0241 - val_loss: 0.0236
# Epoch 31/50
# 19/19 - 1s - loss: 0.0239 - val_loss: 0.0233
# Epoch 32/50
# 19/19 - 1s - loss: 0.0237 - val_loss: 0.0231
# Epoch 33/50
# 19/19 - 1s - loss: 0.0234 - val_loss: 0.0228
# Epoch 34/50
# 19/19 - 1s - loss: 0.0234 - val_loss: 0.0227
# Epoch 35/50
# 19/19 - 1s - loss: 0.0234 - val_loss: 0.0226
# Epoch 36/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0224
# Epoch 37/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0224
# Epoch 38/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0222
# Epoch 39/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0221
# Epoch 40/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0220
# Epoch 41/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0219
# Epoch 42/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0218
# Epoch 43/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0217
# Epoch 44/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0217
# Epoch 45/50
# 19/19 - 1s - loss: 0.0225 - val_loss: 0.0216
# Epoch 46/50
# 19/19 - 1s - loss: 0.0225 - val_loss: 0.0215
# Epoch 47/50
# 19/19 - 1s - loss: 0.0225 - val_loss: 0.0214
# Epoch 48/50
# 19/19 - 1s - loss: 0.0224 - val_loss: 0.0214
# Epoch 49/50
# 19/19 - 1s - loss: 0.0224 - val_loss: 0.0213
# Epoch 50/50
# 19/19 - 1s - loss: 0.0223 - val_loss: 0.0212
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# WARNING:tensorflow:Layer stacked_tab_net_classifier is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 19/19 - 1s - loss: 0.6883 - val_loss: 0.6921
# Epoch 2/50
# 19/19 - 1s - loss: 0.6779 - val_loss: 0.6793
# Epoch 3/50
# 19/19 - 1s - loss: 0.6618 - val_loss: 0.6494
# Epoch 4/50
# 19/19 - 1s - loss: 0.6328 - val_loss: 0.6075
# Epoch 5/50
# 19/19 - 1s - loss: 0.5891 - val_loss: 0.5521
# Epoch 6/50
# 19/19 - 1s - loss: 0.5281 - val_loss: 0.4804
# Epoch 7/50
# 19/19 - 1s - loss: 0.4495 - val_loss: 0.3993
# Epoch 8/50
# 19/19 - 1s - loss: 0.3556 - val_loss: 0.2958
# Epoch 9/50
# 19/19 - 1s - loss: 0.2583 - val_loss: 0.2064
# Epoch 10/50
# 19/19 - 1s - loss: 0.1763 - val_loss: 0.1397
# Epoch 11/50
# 19/19 - 1s - loss: 0.1183 - val_loss: 0.0977
# Epoch 12/50
# 19/19 - 1s - loss: 0.0841 - val_loss: 0.0693
# Epoch 13/50
# 19/19 - 1s - loss: 0.0639 - val_loss: 0.0563
# Epoch 14/50
# 19/19 - 1s - loss: 0.0514 - val_loss: 0.0453
# Epoch 15/50
# 19/19 - 1s - loss: 0.0433 - val_loss: 0.0397
# Epoch 16/50
# 19/19 - 1s - loss: 0.0380 - val_loss: 0.0354
# Epoch 17/50
# 19/19 - 1s - loss: 0.0343 - val_loss: 0.0332
# Epoch 18/50
# 19/19 - 1s - loss: 0.0317 - val_loss: 0.0307
# Epoch 19/50
# 19/19 - 1s - loss: 0.0297 - val_loss: 0.0286
# Epoch 20/50
# 19/19 - 1s - loss: 0.0282 - val_loss: 0.0276
# Epoch 21/50
# 19/19 - 1s - loss: 0.0270 - val_loss: 0.0266
# Epoch 22/50
# 19/19 - 1s - loss: 0.0263 - val_loss: 0.0259
# Epoch 23/50
# 19/19 - 1s - loss: 0.0256 - val_loss: 0.0252
# Epoch 24/50
# 19/19 - 1s - loss: 0.0252 - val_loss: 0.0247
# Epoch 25/50
# 19/19 - 1s - loss: 0.0247 - val_loss: 0.0245
# Epoch 26/50
# 19/19 - 1s - loss: 0.0244 - val_loss: 0.0242
# Epoch 27/50
# 19/19 - 1s - loss: 0.0242 - val_loss: 0.0239
# Epoch 28/50
# 19/19 - 1s - loss: 0.0240 - val_loss: 0.0237
# Epoch 29/50
# 19/19 - 1s - loss: 0.0237 - val_loss: 0.0236
# Epoch 30/50
# 19/19 - 1s - loss: 0.0236 - val_loss: 0.0234
# Epoch 31/50
# 19/19 - 1s - loss: 0.0236 - val_loss: 0.0234
# Epoch 32/50
# 19/19 - 1s - loss: 0.0234 - val_loss: 0.0232
# Epoch 33/50
# 19/19 - 1s - loss: 0.0233 - val_loss: 0.0232
# Epoch 34/50
# 19/19 - 1s - loss: 0.0234 - val_loss: 0.0231
# Epoch 35/50
# 19/19 - 1s - loss: 0.0233 - val_loss: 0.0230
# Epoch 36/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0230
# Epoch 37/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0230
# Epoch 38/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0229
# Epoch 39/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0228
# Epoch 40/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0228
# Epoch 41/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0227
# Epoch 42/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0227
# Epoch 43/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0226
# Epoch 44/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0226
# Epoch 45/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0225
# Epoch 46/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0225
# Epoch 47/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0224
# Epoch 48/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0223
# Epoch 49/50
# 19/19 - 1s - loss: 0.0224 - val_loss: 0.0222
# Epoch 50/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0222
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# WARNING:tensorflow:Layer stacked_tab_net_classifier is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 19/19 - 2s - loss: 0.6916 - val_loss: 0.6926
# Epoch 2/50
# 19/19 - 1s - loss: 0.6854 - val_loss: 0.6868
# Epoch 3/50
# 19/19 - 1s - loss: 0.6725 - val_loss: 0.6661
# Epoch 4/50
# 19/19 - 1s - loss: 0.6484 - val_loss: 0.6264
# Epoch 5/50
# 19/19 - 1s - loss: 0.6083 - val_loss: 0.5709
# Epoch 6/50
# 19/19 - 1s - loss: 0.5488 - val_loss: 0.5009
# Epoch 7/50
# 19/19 - 1s - loss: 0.4723 - val_loss: 0.4056
# Epoch 8/50
# 19/19 - 1s - loss: 0.3785 - val_loss: 0.3123
# Epoch 9/50
# 19/19 - 1s - loss: 0.2803 - val_loss: 0.2178
# Epoch 10/50
# 19/19 - 1s - loss: 0.1914 - val_loss: 0.1391
# Epoch 11/50
# 19/19 - 1s - loss: 0.1287 - val_loss: 0.1000
# Epoch 12/50
# 19/19 - 1s - loss: 0.0902 - val_loss: 0.0718
# Epoch 13/50
# 19/19 - 1s - loss: 0.0676 - val_loss: 0.0564
# Epoch 14/50
# 19/19 - 1s - loss: 0.0541 - val_loss: 0.0487
# Epoch 15/50
# 19/19 - 1s - loss: 0.0452 - val_loss: 0.0412
# Epoch 16/50
# 19/19 - 1s - loss: 0.0396 - val_loss: 0.0366
# Epoch 17/50
# 19/19 - 1s - loss: 0.0355 - val_loss: 0.0340
# Epoch 18/50
# 19/19 - 1s - loss: 0.0325 - val_loss: 0.0312
# Epoch 19/50
# 19/19 - 1s - loss: 0.0302 - val_loss: 0.0293
# Epoch 20/50
# 19/19 - 1s - loss: 0.0289 - val_loss: 0.0281
# Epoch 21/50
# 19/19 - 1s - loss: 0.0276 - val_loss: 0.0268
# Epoch 22/50
# 19/19 - 1s - loss: 0.0265 - val_loss: 0.0261
# Epoch 23/50
# 19/19 - 1s - loss: 0.0258 - val_loss: 0.0256
# Epoch 24/50
# 19/19 - 1s - loss: 0.0254 - val_loss: 0.0249
# Epoch 25/50
# 19/19 - 1s - loss: 0.0250 - val_loss: 0.0244
# Epoch 26/50
# 19/19 - 1s - loss: 0.0245 - val_loss: 0.0242
# Epoch 27/50
# 19/19 - 1s - loss: 0.0243 - val_loss: 0.0240
# Epoch 28/50
# 19/19 - 1s - loss: 0.0241 - val_loss: 0.0237
# Epoch 29/50
# 19/19 - 1s - loss: 0.0239 - val_loss: 0.0236
# Epoch 30/50
# 19/19 - 1s - loss: 0.0238 - val_loss: 0.0234
# Epoch 31/50
# 19/19 - 1s - loss: 0.0235 - val_loss: 0.0234
# Epoch 32/50
# 19/19 - 1s - loss: 0.0234 - val_loss: 0.0232
# Epoch 33/50
# 19/19 - 1s - loss: 0.0235 - val_loss: 0.0232
# Epoch 34/50
# 19/19 - 1s - loss: 0.0233 - val_loss: 0.0231
# Epoch 35/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0230
# Epoch 36/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0229
# Epoch 37/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0229
# Epoch 38/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0228
# Epoch 39/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0228
# Epoch 40/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0228
# Epoch 41/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0228
# Epoch 42/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0227
# Epoch 43/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0227
# Epoch 44/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0227
# Epoch 45/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0226
# Epoch 46/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0226
# Epoch 47/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0226
# Epoch 48/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0225
# Epoch 49/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0225
# Epoch 50/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0225
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# WARNING:tensorflow:Layer stacked_tab_net_classifier is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 19/19 - 1s - loss: 0.6935 - val_loss: 0.6929
# Epoch 2/50
# 19/19 - 1s - loss: 0.6890 - val_loss: 0.6905
# Epoch 3/50
# 19/19 - 1s - loss: 0.6785 - val_loss: 0.6726
# Epoch 4/50
# 19/19 - 1s - loss: 0.6558 - val_loss: 0.6343
# Epoch 5/50
# 19/19 - 1s - loss: 0.6184 - val_loss: 0.5826
# Epoch 6/50
# 19/19 - 1s - loss: 0.5674 - val_loss: 0.5224
# Epoch 7/50
# 19/19 - 1s - loss: 0.5037 - val_loss: 0.4566
# Epoch 8/50
# 19/19 - 1s - loss: 0.4331 - val_loss: 0.3862
# Epoch 9/50
# 19/19 - 1s - loss: 0.3413 - val_loss: 0.2432
# Epoch 10/50
# 19/19 - 1s - loss: 0.2369 - val_loss: 0.1702
# Epoch 11/50
# 19/19 - 1s - loss: 0.1606 - val_loss: 0.1179
# Epoch 12/50
# 19/19 - 1s - loss: 0.1072 - val_loss: 0.0874
# Epoch 13/50
# 19/19 - 1s - loss: 0.0776 - val_loss: 0.0666
# Epoch 14/50
# 19/19 - 1s - loss: 0.0602 - val_loss: 0.0541
# Epoch 15/50
# 19/19 - 1s - loss: 0.0496 - val_loss: 0.0444
# Epoch 16/50
# 19/19 - 1s - loss: 0.0426 - val_loss: 0.0390
# Epoch 17/50
# 19/19 - 1s - loss: 0.0377 - val_loss: 0.0352
# Epoch 18/50
# 19/19 - 1s - loss: 0.0340 - val_loss: 0.0320
# Epoch 19/50
# 19/19 - 1s - loss: 0.0318 - val_loss: 0.0304
# Epoch 20/50
# 19/19 - 1s - loss: 0.0302 - val_loss: 0.0291
# Epoch 21/50
# 19/19 - 1s - loss: 0.0289 - val_loss: 0.0280
# Epoch 22/50
# 19/19 - 1s - loss: 0.0280 - val_loss: 0.0273
# Epoch 23/50
# 19/19 - 1s - loss: 0.0273 - val_loss: 0.0266
# Epoch 24/50
# 19/19 - 1s - loss: 0.0266 - val_loss: 0.0261
# Epoch 25/50
# 19/19 - 1s - loss: 0.0261 - val_loss: 0.0256
# Epoch 26/50
# 19/19 - 1s - loss: 0.0259 - val_loss: 0.0254
# Epoch 27/50
# 19/19 - 1s - loss: 0.0256 - val_loss: 0.0250
# Epoch 28/50
# 19/19 - 1s - loss: 0.0253 - val_loss: 0.0248
# Epoch 29/50
# 19/19 - 1s - loss: 0.0250 - val_loss: 0.0246
# Epoch 30/50
# 19/19 - 1s - loss: 0.0248 - val_loss: 0.0244
# Epoch 31/50
# 19/19 - 1s - loss: 0.0246 - val_loss: 0.0243
# Epoch 32/50
# 19/19 - 1s - loss: 0.0245 - val_loss: 0.0241
# Epoch 33/50
# 19/19 - 1s - loss: 0.0244 - val_loss: 0.0239
# Epoch 34/50
# 19/19 - 1s - loss: 0.0241 - val_loss: 0.0238
# Epoch 35/50
# 19/19 - 1s - loss: 0.0240 - val_loss: 0.0236
# Epoch 36/50
# 19/19 - 1s - loss: 0.0239 - val_loss: 0.0235
# Epoch 37/50
# 19/19 - 1s - loss: 0.0238 - val_loss: 0.0233
# Epoch 38/50
# 19/19 - 1s - loss: 0.0236 - val_loss: 0.0232
# Epoch 39/50
# 19/19 - 1s - loss: 0.0235 - val_loss: 0.0231
# Epoch 40/50
# 19/19 - 1s - loss: 0.0235 - val_loss: 0.0229
# Epoch 41/50
# 19/19 - 1s - loss: 0.0233 - val_loss: 0.0229
# Epoch 42/50
# 19/19 - 1s - loss: 0.0233 - val_loss: 0.0228
# Epoch 43/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0228
# Epoch 44/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0227
# Epoch 45/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0226
# Epoch 46/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0226
# Epoch 47/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0226
# Epoch 48/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0225
# Epoch 49/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0225
# Epoch 50/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0224
#
# oof_score: 0.018900315669853476
# [I 2020-11-26 17:36:59,933] Trial 0 finished with value: 0.018900315669853476 and parameters: {'gamma': 1.2, 'lambda_sparse': 0.001, 'Na': 1024}. Best is trial 0 with value: 0.018900315669853476.
# oof_auc_score: 0.5802520744649021
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# params: {'epsilon': 1e-05, 'feature_columns': None, 'virtual_batch_size': None, 'num_layers': 2, 'num_decision_steps': 1, 'norm_type': 'batch', 'num_groups': -1, 'batch_momentum': 0.9, 'relaxation_factor': 1.0, 'sparsity_coefficient': 1e-06, 'feature_dim': 768, 'output_dim': 8}
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# WARNING:tensorflow:Layer stacked_tab_net_classifier is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 19/19 - 1s - loss: 0.6942 - val_loss: 0.6930
# Epoch 2/50
# 19/19 - 1s - loss: 0.6906 - val_loss: 0.6906
# Epoch 3/50
# 19/19 - 1s - loss: 0.6826 - val_loss: 0.6762
# Epoch 4/50
# 19/19 - 1s - loss: 0.6657 - val_loss: 0.6485
# Epoch 5/50
# 19/19 - 1s - loss: 0.6362 - val_loss: 0.5954
# Epoch 6/50
# 19/19 - 1s - loss: 0.5911 - val_loss: 0.5332
# Epoch 7/50
# 19/19 - 1s - loss: 0.5297 - val_loss: 0.4660
# Epoch 8/50
# 19/19 - 1s - loss: 0.4548 - val_loss: 0.3598
# Epoch 9/50
# 19/19 - 1s - loss: 0.3582 - val_loss: 0.2689
# Epoch 10/50
# 19/19 - 1s - loss: 0.2610 - val_loss: 0.1991
# Epoch 11/50
# 19/19 - 1s - loss: 0.1785 - val_loss: 0.1384
# Epoch 12/50
# 19/19 - 1s - loss: 0.1205 - val_loss: 0.0952
# Epoch 13/50
# 19/19 - 1s - loss: 0.0857 - val_loss: 0.0728
# Epoch 14/50
# 19/19 - 1s - loss: 0.0643 - val_loss: 0.0546
# Epoch 15/50
# 19/19 - 1s - loss: 0.0515 - val_loss: 0.0469
# Epoch 16/50
# 19/19 - 1s - loss: 0.0432 - val_loss: 0.0397
# Epoch 17/50
# 19/19 - 1s - loss: 0.0377 - val_loss: 0.0353
# Epoch 18/50
# 19/19 - 1s - loss: 0.0342 - val_loss: 0.0315
# Epoch 19/50
# 19/19 - 1s - loss: 0.0315 - val_loss: 0.0297
# Epoch 20/50
# 19/19 - 1s - loss: 0.0296 - val_loss: 0.0281
# Epoch 21/50
# 19/19 - 1s - loss: 0.0281 - val_loss: 0.0274
# Epoch 22/50
# 19/19 - 1s - loss: 0.0272 - val_loss: 0.0266
# Epoch 23/50
# 19/19 - 1s - loss: 0.0263 - val_loss: 0.0256
# Epoch 24/50
# 19/19 - 1s - loss: 0.0256 - val_loss: 0.0250
# Epoch 25/50
# 19/19 - 1s - loss: 0.0252 - val_loss: 0.0247
# Epoch 26/50
# 19/19 - 1s - loss: 0.0248 - val_loss: 0.0244
# Epoch 27/50
# 19/19 - 1s - loss: 0.0245 - val_loss: 0.0241
# Epoch 28/50
# 19/19 - 1s - loss: 0.0242 - val_loss: 0.0237
# Epoch 29/50
# 19/19 - 1s - loss: 0.0240 - val_loss: 0.0236
# Epoch 30/50
# 19/19 - 1s - loss: 0.0238 - val_loss: 0.0234
# Epoch 31/50
# 19/19 - 1s - loss: 0.0237 - val_loss: 0.0233
# Epoch 32/50
# 19/19 - 1s - loss: 0.0236 - val_loss: 0.0232
# Epoch 33/50
# 19/19 - 1s - loss: 0.0234 - val_loss: 0.0231
# Epoch 34/50
# 19/19 - 1s - loss: 0.0233 - val_loss: 0.0230
# Epoch 35/50
# 19/19 - 1s - loss: 0.0233 - val_loss: 0.0229
# Epoch 36/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0228
# Epoch 37/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0228
# Epoch 38/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0227
# Epoch 39/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0227
# Epoch 40/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0227
# Epoch 41/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0226
# Epoch 42/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0226
# Epoch 43/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0226
# Epoch 44/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0225
# Epoch 45/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0224
# Epoch 46/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0224
# Epoch 47/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0224
# Epoch 48/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0223
# Epoch 49/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0223
# Epoch 50/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0222
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# WARNING:tensorflow:Layer stacked_tab_net_classifier is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 19/19 - 1s - loss: 0.6886 - val_loss: 0.6925
# Epoch 2/50
# 19/19 - 1s - loss: 0.6788 - val_loss: 0.6814
# Epoch 3/50
# 19/19 - 1s - loss: 0.6623 - val_loss: 0.6447
# Epoch 4/50
# 19/19 - 1s - loss: 0.6287 - val_loss: 0.5948
# Epoch 5/50
# 19/19 - 1s - loss: 0.5761 - val_loss: 0.5321
# Epoch 6/50
# 19/19 - 1s - loss: 0.5037 - val_loss: 0.4551
# Epoch 7/50
# 19/19 - 1s - loss: 0.4129 - val_loss: 0.3639
# Epoch 8/50
# 19/19 - 1s - loss: 0.3145 - val_loss: 0.2584
# Epoch 9/50
# 19/19 - 1s - loss: 0.2198 - val_loss: 0.1683
# Epoch 10/50
# 19/19 - 1s - loss: 0.1480 - val_loss: 0.1156
# Epoch 11/50
# 19/19 - 1s - loss: 0.1006 - val_loss: 0.0800
# Epoch 12/50
# 19/19 - 1s - loss: 0.0740 - val_loss: 0.0612
# Epoch 13/50
# 19/19 - 1s - loss: 0.0574 - val_loss: 0.0505
# Epoch 14/50
# 19/19 - 1s - loss: 0.0475 - val_loss: 0.0432
# Epoch 15/50
# 19/19 - 1s - loss: 0.0410 - val_loss: 0.0377
# Epoch 16/50
# 19/19 - 1s - loss: 0.0365 - val_loss: 0.0339
# Epoch 17/50
# 19/19 - 1s - loss: 0.0334 - val_loss: 0.0311
# Epoch 18/50
# 19/19 - 1s - loss: 0.0309 - val_loss: 0.0296
# Epoch 19/50
# 19/19 - 1s - loss: 0.0293 - val_loss: 0.0277
# Epoch 20/50
# 19/19 - 1s - loss: 0.0279 - val_loss: 0.0268
# Epoch 21/50
# 19/19 - 1s - loss: 0.0269 - val_loss: 0.0260
# Epoch 22/50
# 19/19 - 1s - loss: 0.0263 - val_loss: 0.0254
# Epoch 23/50
# 19/19 - 1s - loss: 0.0257 - val_loss: 0.0248
# Epoch 24/50
# 19/19 - 1s - loss: 0.0252 - val_loss: 0.0243
# Epoch 25/50
# 19/19 - 1s - loss: 0.0248 - val_loss: 0.0240
# Epoch 26/50
# 19/19 - 1s - loss: 0.0245 - val_loss: 0.0237
# Epoch 27/50
# 19/19 - 1s - loss: 0.0242 - val_loss: 0.0236
# Epoch 28/50
# 19/19 - 1s - loss: 0.0239 - val_loss: 0.0233
# Epoch 29/50
# 19/19 - 1s - loss: 0.0239 - val_loss: 0.0232
# Epoch 30/50
# 19/19 - 1s - loss: 0.0238 - val_loss: 0.0231
# Epoch 31/50
# 19/19 - 1s - loss: 0.0236 - val_loss: 0.0229
# Epoch 32/50
# 19/19 - 1s - loss: 0.0235 - val_loss: 0.0229
# Epoch 33/50
# 19/19 - 1s - loss: 0.0233 - val_loss: 0.0228
# Epoch 34/50
# 19/19 - 1s - loss: 0.0234 - val_loss: 0.0227
# Epoch 35/50
# 19/19 - 1s - loss: 0.0233 - val_loss: 0.0226
# Epoch 36/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0225
# Epoch 37/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0225
# Epoch 38/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0224
# Epoch 39/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0224
# Epoch 40/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0223
# Epoch 41/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0222
# Epoch 42/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0221
# Epoch 43/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0221
# Epoch 44/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0220
# Epoch 45/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0219
# Epoch 46/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0219
# Epoch 47/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0218
# Epoch 48/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0219
# Epoch 49/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0218
# Epoch 50/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0216
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# WARNING:tensorflow:Layer stacked_tab_net_classifier is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 19/19 - 1s - loss: 0.6888 - val_loss: 0.6912
# Epoch 2/50
# 19/19 - 1s - loss: 0.6795 - val_loss: 0.6804
# Epoch 3/50
# 19/19 - 1s - loss: 0.6632 - val_loss: 0.6504
# Epoch 4/50
# 19/19 - 1s - loss: 0.6326 - val_loss: 0.6051
# Epoch 5/50
# 19/19 - 1s - loss: 0.5856 - val_loss: 0.5447
# Epoch 6/50
# 19/19 - 1s - loss: 0.5207 - val_loss: 0.4741
# Epoch 7/50
# 19/19 - 1s - loss: 0.4385 - val_loss: 0.3820
# Epoch 8/50
# 19/19 - 1s - loss: 0.3420 - val_loss: 0.2823
# Epoch 9/50
# 19/19 - 2s - loss: 0.2450 - val_loss: 0.1921
# Epoch 10/50
# 19/19 - 1s - loss: 0.1673 - val_loss: 0.1296
# Epoch 11/50
# 19/19 - 1s - loss: 0.1139 - val_loss: 0.0895
# Epoch 12/50
# 19/19 - 1s - loss: 0.0821 - val_loss: 0.0701
# Epoch 13/50
# 19/19 - 1s - loss: 0.0631 - val_loss: 0.0560
# Epoch 14/50
# 19/19 - 1s - loss: 0.0511 - val_loss: 0.0470
# Epoch 15/50
# 19/19 - 1s - loss: 0.0432 - val_loss: 0.0405
# Epoch 16/50
# 19/19 - 1s - loss: 0.0381 - val_loss: 0.0366
# Epoch 17/50
# 19/19 - 1s - loss: 0.0344 - val_loss: 0.0332
# Epoch 18/50
# 19/19 - 1s - loss: 0.0319 - val_loss: 0.0309
# Epoch 19/50
# 19/19 - 1s - loss: 0.0298 - val_loss: 0.0290
# Epoch 20/50
# 19/19 - 1s - loss: 0.0284 - val_loss: 0.0278
# Epoch 21/50
# 19/19 - 1s - loss: 0.0272 - val_loss: 0.0266
# Epoch 22/50
# 19/19 - 1s - loss: 0.0264 - val_loss: 0.0260
# Epoch 23/50
# 19/19 - 1s - loss: 0.0256 - val_loss: 0.0254
# Epoch 24/50
# 19/19 - 1s - loss: 0.0252 - val_loss: 0.0248
# Epoch 25/50
# 19/19 - 1s - loss: 0.0248 - val_loss: 0.0244
# Epoch 26/50
# 19/19 - 1s - loss: 0.0244 - val_loss: 0.0241
# Epoch 27/50
# 19/19 - 1s - loss: 0.0242 - val_loss: 0.0239
# Epoch 28/50
# 19/19 - 1s - loss: 0.0239 - val_loss: 0.0236
# Epoch 29/50
# 19/19 - 1s - loss: 0.0237 - val_loss: 0.0235
# Epoch 30/50
# 19/19 - 1s - loss: 0.0235 - val_loss: 0.0233
# Epoch 31/50
# 19/19 - 1s - loss: 0.0235 - val_loss: 0.0232
# Epoch 32/50
# 19/19 - 1s - loss: 0.0233 - val_loss: 0.0231
# Epoch 33/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0230
# Epoch 34/50
# 19/19 - 1s - loss: 0.0233 - val_loss: 0.0229
# Epoch 35/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0228
# Epoch 36/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0228
# Epoch 37/50
# 19/19 - 2s - loss: 0.0229 - val_loss: 0.0227
# Epoch 38/50
# 19/19 - 2s - loss: 0.0229 - val_loss: 0.0226
# Epoch 39/50
# 19/19 - 2s - loss: 0.0229 - val_loss: 0.0226
# Epoch 40/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0225
# Epoch 41/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0225
# Epoch 42/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0224
# Epoch 43/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0224
# Epoch 44/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0223
# Epoch 45/50
# 19/19 - 1s - loss: 0.0225 - val_loss: 0.0223
# Epoch 46/50
# 19/19 - 2s - loss: 0.0224 - val_loss: 0.0222
# Epoch 47/50
# 19/19 - 1s - loss: 0.0225 - val_loss: 0.0222
# Epoch 48/50
# 19/19 - 1s - loss: 0.0225 - val_loss: 0.0221
# Epoch 49/50
# 19/19 - 1s - loss: 0.0223 - val_loss: 0.0221
# Epoch 50/50
# 19/19 - 1s - loss: 0.0225 - val_loss: 0.0220
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# WARNING:tensorflow:Layer stacked_tab_net_classifier is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 19/19 - 2s - loss: 0.6913 - val_loss: 0.6922
# Epoch 2/50
# 19/19 - 1s - loss: 0.6849 - val_loss: 0.6861
# Epoch 3/50
# 19/19 - 1s - loss: 0.6729 - val_loss: 0.6648
# Epoch 4/50
# 19/19 - 2s - loss: 0.6503 - val_loss: 0.6303
# Epoch 5/50
# 19/19 - 1s - loss: 0.6148 - val_loss: 0.5857
# Epoch 6/50
# 19/19 - 1s - loss: 0.5645 - val_loss: 0.5214
# Epoch 7/50
# 19/19 - 1s - loss: 0.4949 - val_loss: 0.4317
# Epoch 8/50
# 19/19 - 1s - loss: 0.4022 - val_loss: 0.3386
# Epoch 9/50
# 19/19 - 1s - loss: 0.3045 - val_loss: 0.2480
# Epoch 10/50
# 19/19 - 1s - loss: 0.2134 - val_loss: 0.1749
# Epoch 11/50
# 19/19 - 2s - loss: 0.1454 - val_loss: 0.1142
# Epoch 12/50
# 19/19 - 2s - loss: 0.1017 - val_loss: 0.0835
# Epoch 13/50
# 19/19 - 2s - loss: 0.0753 - val_loss: 0.0638
# Epoch 14/50
# 19/19 - 2s - loss: 0.0593 - val_loss: 0.0506
# Epoch 15/50
# 19/19 - 2s - loss: 0.0487 - val_loss: 0.0438
# Epoch 16/50
# 19/19 - 2s - loss: 0.0422 - val_loss: 0.0387
# Epoch 17/50
# 19/19 - 2s - loss: 0.0376 - val_loss: 0.0356
# Epoch 18/50
# 19/19 - 2s - loss: 0.0343 - val_loss: 0.0324
# Epoch 19/50
# 19/19 - 2s - loss: 0.0318 - val_loss: 0.0305
# Epoch 20/50
# 19/19 - 2s - loss: 0.0301 - val_loss: 0.0289
# Epoch 21/50
# 19/19 - 2s - loss: 0.0287 - val_loss: 0.0276
# Epoch 22/50
# 19/19 - 2s - loss: 0.0273 - val_loss: 0.0269
# Epoch 23/50
# 19/19 - 2s - loss: 0.0265 - val_loss: 0.0259
# Epoch 24/50
# 19/19 - 2s - loss: 0.0259 - val_loss: 0.0253
# Epoch 25/50
# 19/19 - 2s - loss: 0.0254 - val_loss: 0.0248
# Epoch 26/50
# 19/19 - 2s - loss: 0.0249 - val_loss: 0.0246
# Epoch 27/50
# 19/19 - 2s - loss: 0.0247 - val_loss: 0.0242
# Epoch 28/50
# 19/19 - 2s - loss: 0.0244 - val_loss: 0.0240
# Epoch 29/50
# 19/19 - 2s - loss: 0.0241 - val_loss: 0.0237
# Epoch 30/50
# 19/19 - 2s - loss: 0.0240 - val_loss: 0.0236
# Epoch 31/50
# 19/19 - 2s - loss: 0.0237 - val_loss: 0.0234
# Epoch 32/50
# 19/19 - 2s - loss: 0.0236 - val_loss: 0.0233
# Epoch 33/50
# 19/19 - 2s - loss: 0.0237 - val_loss: 0.0233
# Epoch 34/50
# 19/19 - 2s - loss: 0.0234 - val_loss: 0.0231
# Epoch 35/50
# 19/19 - 2s - loss: 0.0233 - val_loss: 0.0230
# Epoch 36/50
# 19/19 - 2s - loss: 0.0232 - val_loss: 0.0229
# Epoch 37/50
# 19/19 - 2s - loss: 0.0232 - val_loss: 0.0228
# Epoch 38/50
# 19/19 - 2s - loss: 0.0231 - val_loss: 0.0228
# Epoch 39/50
# 19/19 - 2s - loss: 0.0230 - val_loss: 0.0227
# Epoch 40/50
# 19/19 - 2s - loss: 0.0230 - val_loss: 0.0226
# Epoch 41/50
# 19/19 - 2s - loss: 0.0230 - val_loss: 0.0226
# Epoch 42/50
# 19/19 - 2s - loss: 0.0228 - val_loss: 0.0224
# Epoch 43/50
# 19/19 - 2s - loss: 0.0227 - val_loss: 0.0224
# Epoch 44/50
# 19/19 - 2s - loss: 0.0228 - val_loss: 0.0224
# Epoch 45/50
# 19/19 - 2s - loss: 0.0228 - val_loss: 0.0223
# Epoch 46/50
# 19/19 - 2s - loss: 0.0226 - val_loss: 0.0223
# Epoch 47/50
# 19/19 - 2s - loss: 0.0227 - val_loss: 0.0222
# Epoch 48/50
# 19/19 - 2s - loss: 0.0225 - val_loss: 0.0221
# Epoch 49/50
# 19/19 - 2s - loss: 0.0225 - val_loss: 0.0221
# Epoch 50/50
# 19/19 - 2s - loss: 0.0225 - val_loss: 0.0220
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# WARNING:tensorflow:Layer stacked_tab_net_classifier is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 19/19 - 2s - loss: 0.6938 - val_loss: 0.6928
# Epoch 2/50
# 19/19 - 1s - loss: 0.6886 - val_loss: 0.6885
# Epoch 3/50
# 19/19 - 1s - loss: 0.6779 - val_loss: 0.6697
# Epoch 4/50
# 19/19 - 2s - loss: 0.6545 - val_loss: 0.6314
# Epoch 5/50
# 19/19 - 2s - loss: 0.6157 - val_loss: 0.5821
# Epoch 6/50
# 19/19 - 2s - loss: 0.5653 - val_loss: 0.5195
# Epoch 7/50
# 19/19 - 2s - loss: 0.5044 - val_loss: 0.4552
# Epoch 8/50
# 19/19 - 2s - loss: 0.4384 - val_loss: 0.3847
# Epoch 9/50
# 19/19 - 2s - loss: 0.3689 - val_loss: 0.3407
# Epoch 10/50
# 19/19 - 2s - loss: 0.2814 - val_loss: 0.2062
# Epoch 11/50
# 19/19 - 1s - loss: 0.1922 - val_loss: 0.1450
# Epoch 12/50
# 19/19 - 1s - loss: 0.1298 - val_loss: 0.1076
# Epoch 13/50
# 19/19 - 1s - loss: 0.0925 - val_loss: 0.0815
# Epoch 14/50
# 19/19 - 1s - loss: 0.0679 - val_loss: 0.0624
# Epoch 15/50
# 19/19 - 2s - loss: 0.0534 - val_loss: 0.0480
# Epoch 16/50
# 19/19 - 2s - loss: 0.0452 - val_loss: 0.0423
# Epoch 17/50
# 19/19 - 2s - loss: 0.0396 - val_loss: 0.0375
# Epoch 18/50
# 19/19 - 2s - loss: 0.0359 - val_loss: 0.0347
# Epoch 19/50
# 19/19 - 2s - loss: 0.0332 - val_loss: 0.0322
# Epoch 20/50
# 19/19 - 2s - loss: 0.0313 - val_loss: 0.0303
# Epoch 21/50
# 19/19 - 2s - loss: 0.0297 - val_loss: 0.0289
# Epoch 22/50
# 19/19 - 2s - loss: 0.0286 - val_loss: 0.0279
# Epoch 23/50
# 19/19 - 2s - loss: 0.0276 - val_loss: 0.0268
# Epoch 24/50
# 19/19 - 2s - loss: 0.0267 - val_loss: 0.0260
# Epoch 25/50
# 19/19 - 2s - loss: 0.0260 - val_loss: 0.0252
# Epoch 26/50
# 19/19 - 2s - loss: 0.0255 - val_loss: 0.0248
# Epoch 27/50
# 19/19 - 2s - loss: 0.0253 - val_loss: 0.0245
# Epoch 28/50
# 19/19 - 2s - loss: 0.0248 - val_loss: 0.0241
# Epoch 29/50
# 19/19 - 2s - loss: 0.0244 - val_loss: 0.0239
# Epoch 30/50
# 19/19 - 2s - loss: 0.0242 - val_loss: 0.0237
# Epoch 31/50
# 19/19 - 2s - loss: 0.0240 - val_loss: 0.0234
# Epoch 32/50
# 19/19 - 2s - loss: 0.0239 - val_loss: 0.0232
# Epoch 33/50
# 19/19 - 2s - loss: 0.0239 - val_loss: 0.0233
# Epoch 34/50
# 19/19 - 2s - loss: 0.0236 - val_loss: 0.0230
# Epoch 35/50
# 19/19 - 2s - loss: 0.0235 - val_loss: 0.0229
# Epoch 36/50
# 19/19 - 2s - loss: 0.0234 - val_loss: 0.0228
# Epoch 37/50
# 19/19 - 2s - loss: 0.0233 - val_loss: 0.0227
# Epoch 38/50
# 19/19 - 2s - loss: 0.0231 - val_loss: 0.0225
# Epoch 39/50
# 19/19 - 2s - loss: 0.0232 - val_loss: 0.0225
# Epoch 40/50
# 19/19 - 2s - loss: 0.0231 - val_loss: 0.0224
# Epoch 41/50
# 19/19 - 2s - loss: 0.0229 - val_loss: 0.0223
# Epoch 42/50
# 19/19 - 2s - loss: 0.0229 - val_loss: 0.0222
# Epoch 43/50
# 19/19 - 2s - loss: 0.0229 - val_loss: 0.0222
# Epoch 44/50
# 19/19 - 2s - loss: 0.0228 - val_loss: 0.0221
# Epoch 45/50
# 19/19 - 2s - loss: 0.0227 - val_loss: 0.0220
# Epoch 46/50
# 19/19 - 2s - loss: 0.0227 - val_loss: 0.0220
# Epoch 47/50
# 19/19 - 2s - loss: 0.0228 - val_loss: 0.0219
# Epoch 48/50
# 19/19 - 2s - loss: 0.0228 - val_loss: 0.0218
# Epoch 49/50
# 19/19 - 2s - loss: 0.0226 - val_loss: 0.0218
# Epoch 50/50
# 19/19 - 1s - loss: 0.0225 - val_loss: 0.0217
#
# oof_score: 0.018723874071894894
# [I 2020-11-26 17:43:24,875] Trial 1 finished with value: 0.018723874071894894 and parameters: {'gamma': 1.0, 'lambda_sparse': 1e-06, 'Na': 768}. Best is trial 1 with value: 0.018723874071894894.
# oof_auc_score: 0.5878831642010066
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# params: {'epsilon': 1e-05, 'feature_columns': None, 'virtual_batch_size': None, 'num_layers': 2, 'num_decision_steps': 1, 'norm_type': 'batch', 'num_groups': -1, 'batch_momentum': 0.9, 'relaxation_factor': 1.2, 'sparsity_coefficient': 0, 'feature_dim': 128, 'output_dim': 8}
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# WARNING:tensorflow:Layer stacked_tab_net_classifier is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 19/19 - 2s - loss: 0.6952 - val_loss: 0.6932
# Epoch 2/50
# 19/19 - 1s - loss: 0.6923 - val_loss: 0.6912
# Epoch 3/50
# 19/19 - 1s - loss: 0.6856 - val_loss: 0.6790
# Epoch 4/50
# 19/19 - 1s - loss: 0.6667 - val_loss: 0.6467
# Epoch 5/50
# 19/19 - 1s - loss: 0.6267 - val_loss: 0.5873
# Epoch 6/50
# 19/19 - 1s - loss: 0.5644 - val_loss: 0.5080
# Epoch 7/50
# 19/19 - 1s - loss: 0.4782 - val_loss: 0.4141
# Epoch 8/50
# 19/19 - 1s - loss: 0.3725 - val_loss: 0.3141
# Epoch 9/50
# 19/19 - 1s - loss: 0.2568 - val_loss: 0.2033
# Epoch 10/50
# 19/19 - 1s - loss: 0.1666 - val_loss: 0.1277
# Epoch 11/50
# 19/19 - 1s - loss: 0.1093 - val_loss: 0.0870
# Epoch 12/50
# 19/19 - 1s - loss: 0.0768 - val_loss: 0.0643
# Epoch 13/50
# 19/19 - 1s - loss: 0.0584 - val_loss: 0.0511
# Epoch 14/50
# 19/19 - 1s - loss: 0.0474 - val_loss: 0.0426
# Epoch 15/50
# 19/19 - 1s - loss: 0.0404 - val_loss: 0.0376
# Epoch 16/50
# 19/19 - 1s - loss: 0.0358 - val_loss: 0.0341
# Epoch 17/50
# 19/19 - 1s - loss: 0.0327 - val_loss: 0.0314
# Epoch 18/50
# 19/19 - 1s - loss: 0.0306 - val_loss: 0.0298
# Epoch 19/50
# 19/19 - 1s - loss: 0.0289 - val_loss: 0.0282
# Epoch 20/50
# 19/19 - 1s - loss: 0.0278 - val_loss: 0.0272
# Epoch 21/50
# 19/19 - 1s - loss: 0.0267 - val_loss: 0.0266
# Epoch 22/50
# 19/19 - 1s - loss: 0.0262 - val_loss: 0.0258
# Epoch 23/50
# 19/19 - 1s - loss: 0.0257 - val_loss: 0.0254
# Epoch 24/50
# 19/19 - 1s - loss: 0.0251 - val_loss: 0.0248
# Epoch 25/50
# 19/19 - 1s - loss: 0.0248 - val_loss: 0.0245
# Epoch 26/50
# 19/19 - 1s - loss: 0.0245 - val_loss: 0.0242
# Epoch 27/50
# 19/19 - 1s - loss: 0.0243 - val_loss: 0.0240
# Epoch 28/50
# 19/19 - 1s - loss: 0.0240 - val_loss: 0.0238
# Epoch 29/50
# 19/19 - 1s - loss: 0.0238 - val_loss: 0.0235
# Epoch 30/50
# 19/19 - 1s - loss: 0.0237 - val_loss: 0.0234
# Epoch 31/50
# 19/19 - 1s - loss: 0.0236 - val_loss: 0.0233
# Epoch 32/50
# 19/19 - 1s - loss: 0.0236 - val_loss: 0.0232
# Epoch 33/50
# 19/19 - 1s - loss: 0.0234 - val_loss: 0.0231
# Epoch 34/50
# 19/19 - 1s - loss: 0.0233 - val_loss: 0.0231
# Epoch 35/50
# 19/19 - 1s - loss: 0.0233 - val_loss: 0.0230
# Epoch 36/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0229
# Epoch 37/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0229
# Epoch 38/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0229
# Epoch 39/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0228
# Epoch 40/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0228
# Epoch 41/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0228
# Epoch 42/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0227
# Epoch 43/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0227
# Epoch 44/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0227
# Epoch 45/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0227
# Epoch 46/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0226
# Epoch 47/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0226
# Epoch 48/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0226
# Epoch 49/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0225
# Epoch 50/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0225
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# WARNING:tensorflow:Layer stacked_tab_net_classifier is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 19/19 - 1s - loss: 0.6897 - val_loss: 0.6924
# Epoch 2/50
# 19/19 - 1s - loss: 0.6824 - val_loss: 0.6842
# Epoch 3/50
# 19/19 - 1s - loss: 0.6658 - val_loss: 0.6496
# Epoch 4/50
# 19/19 - 1s - loss: 0.6300 - val_loss: 0.5878
# Epoch 5/50
# 19/19 - 1s - loss: 0.5649 - val_loss: 0.5008
# Epoch 6/50
# 19/19 - 1s - loss: 0.4747 - val_loss: 0.4012
# Epoch 7/50
# 19/19 - 1s - loss: 0.3671 - val_loss: 0.3003
# Epoch 8/50
# 19/19 - 1s - loss: 0.2597 - val_loss: 0.2078
# Epoch 9/50
# 19/19 - 1s - loss: 0.1711 - val_loss: 0.1346
# Epoch 10/50
# 19/19 - 1s - loss: 0.1135 - val_loss: 0.0929
# Epoch 11/50
# 19/19 - 1s - loss: 0.0788 - val_loss: 0.0688
# Epoch 12/50
# 19/19 - 1s - loss: 0.0597 - val_loss: 0.0530
# Epoch 13/50
# 19/19 - 1s - loss: 0.0482 - val_loss: 0.0442
# Epoch 14/50
# 19/19 - 1s - loss: 0.0410 - val_loss: 0.0385
# Epoch 15/50
# 19/19 - 1s - loss: 0.0364 - val_loss: 0.0348
# Epoch 16/50
# 19/19 - 1s - loss: 0.0331 - val_loss: 0.0316
# Epoch 17/50
# 19/19 - 1s - loss: 0.0310 - val_loss: 0.0300
# Epoch 18/50
# 19/19 - 1s - loss: 0.0291 - val_loss: 0.0284
# Epoch 19/50
# 19/19 - 1s - loss: 0.0280 - val_loss: 0.0273
# Epoch 20/50
# 19/19 - 1s - loss: 0.0270 - val_loss: 0.0266
# Epoch 21/50
# 19/19 - 1s - loss: 0.0264 - val_loss: 0.0260
# Epoch 22/50
# 19/19 - 1s - loss: 0.0259 - val_loss: 0.0254
# Epoch 23/50
# 19/19 - 1s - loss: 0.0255 - val_loss: 0.0250
# Epoch 24/50
# 19/19 - 1s - loss: 0.0251 - val_loss: 0.0247
# Epoch 25/50
# 19/19 - 1s - loss: 0.0248 - val_loss: 0.0244
# Epoch 26/50
# 19/19 - 1s - loss: 0.0245 - val_loss: 0.0241
# Epoch 27/50
# 19/19 - 1s - loss: 0.0243 - val_loss: 0.0239
# Epoch 28/50
# 19/19 - 1s - loss: 0.0240 - val_loss: 0.0236
# Epoch 29/50
# 19/19 - 1s - loss: 0.0239 - val_loss: 0.0233
# Epoch 30/50
# 19/19 - 1s - loss: 0.0237 - val_loss: 0.0232
# Epoch 31/50
# 19/19 - 1s - loss: 0.0236 - val_loss: 0.0230
# Epoch 32/50
# 19/19 - 1s - loss: 0.0234 - val_loss: 0.0229
# Epoch 33/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0228
# Epoch 34/50
# 19/19 - 1s - loss: 0.0233 - val_loss: 0.0227
# Epoch 35/50
# 19/19 - 1s - loss: 0.0233 - val_loss: 0.0226
# Epoch 36/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0226
# Epoch 37/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0225
# Epoch 38/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0224
# Epoch 39/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0225
# Epoch 40/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0223
# Epoch 41/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0223
# Epoch 42/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0222
# Epoch 43/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0223
# Epoch 44/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0222
# Epoch 45/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0221
# Epoch 46/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0221
# Epoch 47/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0221
# Epoch 48/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0220
# Epoch 49/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0220
# Epoch 50/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0220
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# WARNING:tensorflow:Layer stacked_tab_net_classifier is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 19/19 - 2s - loss: 0.6907 - val_loss: 0.6921
# Epoch 2/50
# 19/19 - 1s - loss: 0.6845 - val_loss: 0.6834
# Epoch 3/50
# 19/19 - 1s - loss: 0.6683 - val_loss: 0.6488
# Epoch 4/50
# 19/19 - 1s - loss: 0.6343 - val_loss: 0.5966
# Epoch 5/50
# 19/19 - 1s - loss: 0.5743 - val_loss: 0.5182
# Epoch 6/50
# 19/19 - 1s - loss: 0.4849 - val_loss: 0.4164
# Epoch 7/50
# 19/19 - 1s - loss: 0.3750 - val_loss: 0.3011
# Epoch 8/50
# 19/19 - 1s - loss: 0.2627 - val_loss: 0.2108
# Epoch 9/50
# 19/19 - 1s - loss: 0.1712 - val_loss: 0.1387
# Epoch 10/50
# 19/19 - 1s - loss: 0.1128 - val_loss: 0.0924
# Epoch 11/50
# 19/19 - 1s - loss: 0.0784 - val_loss: 0.0670
# Epoch 12/50
# 19/19 - 1s - loss: 0.0594 - val_loss: 0.0517
# Epoch 13/50
# 19/19 - 1s - loss: 0.0479 - val_loss: 0.0436
# Epoch 14/50
# 19/19 - 1s - loss: 0.0407 - val_loss: 0.0378
# Epoch 15/50
# 19/19 - 1s - loss: 0.0359 - val_loss: 0.0340
# Epoch 16/50
# 19/19 - 1s - loss: 0.0328 - val_loss: 0.0317
# Epoch 17/50
# 19/19 - 1s - loss: 0.0305 - val_loss: 0.0298
# Epoch 18/50
# 19/19 - 1s - loss: 0.0290 - val_loss: 0.0284
# Epoch 19/50
# 19/19 - 1s - loss: 0.0277 - val_loss: 0.0274
# Epoch 20/50
# 19/19 - 1s - loss: 0.0268 - val_loss: 0.0265
# Epoch 21/50
# 19/19 - 1s - loss: 0.0261 - val_loss: 0.0259
# Epoch 22/50
# 19/19 - 1s - loss: 0.0256 - val_loss: 0.0254
# Epoch 23/50
# 19/19 - 1s - loss: 0.0250 - val_loss: 0.0251
# Epoch 24/50
# 19/19 - 1s - loss: 0.0248 - val_loss: 0.0248
# Epoch 25/50
# 19/19 - 1s - loss: 0.0244 - val_loss: 0.0244
# Epoch 26/50
# 19/19 - 1s - loss: 0.0242 - val_loss: 0.0241
# Epoch 27/50
# 19/19 - 1s - loss: 0.0241 - val_loss: 0.0239
# Epoch 28/50
# 19/19 - 1s - loss: 0.0238 - val_loss: 0.0238
# Epoch 29/50
# 19/19 - 1s - loss: 0.0236 - val_loss: 0.0236
# Epoch 30/50
# 19/19 - 1s - loss: 0.0235 - val_loss: 0.0235
# Epoch 31/50
# 19/19 - 1s - loss: 0.0235 - val_loss: 0.0234
# Epoch 32/50
# 19/19 - 1s - loss: 0.0233 - val_loss: 0.0232
# Epoch 33/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0231
# Epoch 34/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0231
# Epoch 35/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0230
# Epoch 36/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0229
# Epoch 37/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0228
# Epoch 38/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0228
# Epoch 39/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0227
# Epoch 40/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0227
# Epoch 41/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0226
# Epoch 42/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0226
# Epoch 43/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0225
# Epoch 44/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0225
# Epoch 45/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0225
# Epoch 46/50
# 19/19 - 1s - loss: 0.0225 - val_loss: 0.0224
# Epoch 47/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0224
# Epoch 48/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0223
# Epoch 49/50
# 19/19 - 1s - loss: 0.0225 - val_loss: 0.0223
# Epoch 50/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0223
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# WARNING:tensorflow:Layer stacked_tab_net_classifier is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 19/19 - 2s - loss: 0.6936 - val_loss: 0.6929
# Epoch 2/50
# 19/19 - 1s - loss: 0.6890 - val_loss: 0.6883
# Epoch 3/50
# 19/19 - 1s - loss: 0.6760 - val_loss: 0.6672
# Epoch 4/50
# 19/19 - 1s - loss: 0.6460 - val_loss: 0.6156
# Epoch 5/50
# 19/19 - 1s - loss: 0.5920 - val_loss: 0.5384
# Epoch 6/50
# 19/19 - 1s - loss: 0.5104 - val_loss: 0.4373
# Epoch 7/50
# 19/19 - 1s - loss: 0.4085 - val_loss: 0.3338
# Epoch 8/50
# 19/19 - 1s - loss: 0.2974 - val_loss: 0.2332
# Epoch 9/50
# 19/19 - 1s - loss: 0.2035 - val_loss: 0.1536
# Epoch 10/50
# 19/19 - 1s - loss: 0.1350 - val_loss: 0.1083
# Epoch 11/50
# 19/19 - 1s - loss: 0.0929 - val_loss: 0.0780
# Epoch 12/50
# 19/19 - 1s - loss: 0.0686 - val_loss: 0.0593
# Epoch 13/50
# 19/19 - 1s - loss: 0.0541 - val_loss: 0.0484
# Epoch 14/50
# 19/19 - 1s - loss: 0.0452 - val_loss: 0.0423
# Epoch 15/50
# 19/19 - 1s - loss: 0.0392 - val_loss: 0.0366
# Epoch 16/50
# 19/19 - 1s - loss: 0.0353 - val_loss: 0.0338
# Epoch 17/50
# 19/19 - 1s - loss: 0.0325 - val_loss: 0.0316
# Epoch 18/50
# 19/19 - 1s - loss: 0.0305 - val_loss: 0.0296
# Epoch 19/50
# 19/19 - 1s - loss: 0.0289 - val_loss: 0.0285
# Epoch 20/50
# 19/19 - 1s - loss: 0.0279 - val_loss: 0.0275
# Epoch 21/50
# 19/19 - 1s - loss: 0.0270 - val_loss: 0.0267
# Epoch 22/50
# 19/19 - 1s - loss: 0.0261 - val_loss: 0.0261
# Epoch 23/50
# 19/19 - 1s - loss: 0.0257 - val_loss: 0.0255
# Epoch 24/50
# 19/19 - 1s - loss: 0.0252 - val_loss: 0.0251
# Epoch 25/50
# 19/19 - 1s - loss: 0.0249 - val_loss: 0.0247
# Epoch 26/50
# 19/19 - 1s - loss: 0.0245 - val_loss: 0.0243
# Epoch 27/50
# 19/19 - 1s - loss: 0.0244 - val_loss: 0.0241
# Epoch 28/50
# 19/19 - 1s - loss: 0.0242 - val_loss: 0.0238
# Epoch 29/50
# 19/19 - 1s - loss: 0.0239 - val_loss: 0.0236
# Epoch 30/50
# 19/19 - 1s - loss: 0.0239 - val_loss: 0.0235
# Epoch 31/50
# 19/19 - 1s - loss: 0.0235 - val_loss: 0.0233
# Epoch 32/50
# 19/19 - 1s - loss: 0.0234 - val_loss: 0.0233
# Epoch 33/50
# 19/19 - 1s - loss: 0.0236 - val_loss: 0.0232
# Epoch 34/50
# 19/19 - 1s - loss: 0.0233 - val_loss: 0.0231
# Epoch 35/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0230
# Epoch 36/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0229
# Epoch 37/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0229
# Epoch 38/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0229
# Epoch 39/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0228
# Epoch 40/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0228
# Epoch 41/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0227
# Epoch 42/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0227
# Epoch 43/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0226
# Epoch 44/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0226
# Epoch 45/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0226
# Epoch 46/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0225
# Epoch 47/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0225
# Epoch 48/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0225
# Epoch 49/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0224
# Epoch 50/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0224
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# WARNING:tensorflow:Layer stacked_tab_net_classifier is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 19/19 - 2s - loss: 0.6963 - val_loss: 0.6934
# Epoch 2/50
# 19/19 - 1s - loss: 0.6919 - val_loss: 0.6911
# Epoch 3/50
# 19/19 - 1s - loss: 0.6830 - val_loss: 0.6760
# Epoch 4/50
# 19/19 - 1s - loss: 0.6602 - val_loss: 0.6340
# Epoch 5/50
# 19/19 - 1s - loss: 0.6180 - val_loss: 0.5716
# Epoch 6/50
# 19/19 - 1s - loss: 0.5545 - val_loss: 0.4914
# Epoch 7/50
# 19/19 - 1s - loss: 0.4689 - val_loss: 0.4073
# Epoch 8/50
# 19/19 - 1s - loss: 0.3712 - val_loss: 0.3115
# Epoch 9/50
# 19/19 - 1s - loss: 0.2726 - val_loss: 0.2179
# Epoch 10/50
# 19/19 - 1s - loss: 0.1846 - val_loss: 0.1477
# Epoch 11/50
# 19/19 - 1s - loss: 0.1248 - val_loss: 0.0987
# Epoch 12/50
# 19/19 - 1s - loss: 0.0874 - val_loss: 0.0736
# Epoch 13/50
# 19/19 - 1s - loss: 0.0656 - val_loss: 0.0572
# Epoch 14/50
# 19/19 - 1s - loss: 0.0525 - val_loss: 0.0472
# Epoch 15/50
# 19/19 - 1s - loss: 0.0439 - val_loss: 0.0404
# Epoch 16/50
# 19/19 - 1s - loss: 0.0386 - val_loss: 0.0352
# Epoch 17/50
# 19/19 - 1s - loss: 0.0346 - val_loss: 0.0330
# Epoch 18/50
# 19/19 - 1s - loss: 0.0318 - val_loss: 0.0305
# Epoch 19/50
# 19/19 - 1s - loss: 0.0300 - val_loss: 0.0290
# Epoch 20/50
# 19/19 - 1s - loss: 0.0286 - val_loss: 0.0276
# Epoch 21/50
# 19/19 - 1s - loss: 0.0274 - val_loss: 0.0265
# Epoch 22/50
# 19/19 - 1s - loss: 0.0267 - val_loss: 0.0257
# Epoch 23/50
# 19/19 - 1s - loss: 0.0259 - val_loss: 0.0252
# Epoch 24/50
# 19/19 - 1s - loss: 0.0253 - val_loss: 0.0246
# Epoch 25/50
# 19/19 - 1s - loss: 0.0249 - val_loss: 0.0242
# Epoch 26/50
# 19/19 - 1s - loss: 0.0246 - val_loss: 0.0239
# Epoch 27/50
# 19/19 - 1s - loss: 0.0245 - val_loss: 0.0237
# Epoch 28/50
# 19/19 - 1s - loss: 0.0242 - val_loss: 0.0235
# Epoch 29/50
# 19/19 - 1s - loss: 0.0239 - val_loss: 0.0233
# Epoch 30/50
# 19/19 - 1s - loss: 0.0237 - val_loss: 0.0232
# Epoch 31/50
# 19/19 - 1s - loss: 0.0236 - val_loss: 0.0231
# Epoch 32/50
# 19/19 - 1s - loss: 0.0236 - val_loss: 0.0229
# Epoch 33/50
# 19/19 - 1s - loss: 0.0236 - val_loss: 0.0229
# Epoch 34/50
# 19/19 - 1s - loss: 0.0233 - val_loss: 0.0228
# Epoch 35/50
# 19/19 - 1s - loss: 0.0233 - val_loss: 0.0227
# Epoch 36/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0227
# Epoch 37/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0226
# Epoch 38/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0226
# Epoch 39/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0225
# Epoch 40/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0225
# Epoch 41/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0224
# Epoch 42/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0224
# Epoch 43/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0224
# Epoch 44/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0223
# Epoch 45/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0223
# Epoch 46/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0222
# Epoch 47/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0222
# Epoch 48/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0222
# Epoch 49/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0221
# Epoch 50/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0221
#
# oof_score: 0.01904909150771326
# [I 2020-11-26 17:48:53,210] Trial 2 finished with value: 0.01904909150771326 and parameters: {'gamma': 1.2, 'lambda_sparse': 0, 'Na': 128}. Best is trial 1 with value: 0.018723874071894894.
# oof_auc_score: 0.5709790679418182
# ----------------------------------------------------------------------------------------------------
#
# study.best_params:
# {'Na': 768, 'gamma': 1.0, 'lambda_sparse': 1e-06}
#
# study.best_value:
# 0.018723874071894894
# Wall time: 17min 25s
