# %%
# !pwd
import sys
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
sys.executable
# Out:
# C:\Users\81908\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124\run_objective_stackedtabnet
# 'c:\\users\\81908\\appdata\\local\\pypoetry\\cache\\virtualenvs\\tfgpu-ehdmne1y-py3.8\\scripts\\python.exe'

# %%
# tensorflow2.0 + kerasでGPUメモリの使用量を抑える方法(最小限だけ使うように設定)
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"

# %%
import sys
sys.path.append(r'C:\Users\81908\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124')
import moa_MLPs_funcs
# Out:
# Tensorflow version 2.3.1
# n_classes: 206

# %%
params = {
    "batch_momentum": 0.95,
    "feature_dim": 512,
    "norm_type": "batch",
    "num_decision_steps": 1,
    #"num_layers": 2,
    "num_layers": 5,
}
model_type = "stacked_tabnet"

# %%
oof_score, Y_pred = moa_MLPs_funcs.train_and_evaluate(model_type=model_type, params=params)
# Out:
# WARNING:tensorflow:From C:\Users\81908\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124\moa_MLPs_funcs.py:694: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass shuffle=True, random_state=0 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# WARNING:tensorflow:Layer stacked_tab_net_classifier is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 19/19 - 2s - loss: 0.7002 - val_loss: 0.6923
# Epoch 2/50
# 19/19 - 1s - loss: 0.6815 - val_loss: 0.6770
# Epoch 3/50
# 19/19 - 1s - loss: 0.6298 - val_loss: 0.5820
# Epoch 4/50
# 19/19 - 1s - loss: 0.4627 - val_loss: 0.3181
# Epoch 5/50
# 19/19 - 1s - loss: 0.2815 - val_loss: 0.1562
# Epoch 6/50
# 19/19 - 1s - loss: 0.1758 - val_loss: 0.1019
# Epoch 7/50
# 19/19 - 1s - loss: 0.1083 - val_loss: 0.0612
# Epoch 8/50
# 19/19 - 1s - loss: 0.0698 - val_loss: 0.0426
# Epoch 9/50
# 19/19 - 1s - loss: 0.0486 - val_loss: 0.0358
# Epoch 10/50
# 19/19 - 1s - loss: 0.0379 - val_loss: 0.0312
# Epoch 11/50
# 19/19 - 1s - loss: 0.0317 - val_loss: 0.0281
# Epoch 12/50
# 19/19 - 1s - loss: 0.0282 - val_loss: 0.0264
# Epoch 13/50
# 19/19 - 1s - loss: 0.0264 - val_loss: 0.0252
# Epoch 14/50
# 19/19 - 1s - loss: 0.0253 - val_loss: 0.0245
# Epoch 15/50
# 19/19 - 1s - loss: 0.0248 - val_loss: 0.0241
# Epoch 16/50
# 19/19 - 1s - loss: 0.0243 - val_loss: 0.0238
# Epoch 17/50
# 19/19 - 1s - loss: 0.0240 - val_loss: 0.0234
# Epoch 18/50
# 19/19 - 1s - loss: 0.0239 - val_loss: 0.0233
# Epoch 19/50
# 19/19 - 1s - loss: 0.0236 - val_loss: 0.0231
# Epoch 20/50
# 19/19 - 1s - loss: 0.0234 - val_loss: 0.0229
# Epoch 21/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0228
# Epoch 22/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0227
# Epoch 23/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0227
# Epoch 24/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0226
# Epoch 25/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0226
# Epoch 26/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0226
# Epoch 27/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0225
# Epoch 28/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0225
# Epoch 29/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0224
# Epoch 30/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0224
# Epoch 31/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0224
# Epoch 32/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0224
# Epoch 33/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0224
# Epoch 34/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0224
# Epoch 35/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0223
# Epoch 36/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0223
# Epoch 37/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0222
# Epoch 38/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0222
# Epoch 39/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0222
# Epoch 40/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0222
# Epoch 41/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0222
# Epoch 42/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0221
# Epoch 43/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0221
# Epoch 44/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0221
# Epoch 45/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0221
# Epoch 46/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0221
# Epoch 47/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0221
# Epoch 48/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0220
# Epoch 49/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0220
# Epoch 50/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0220
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# WARNING:tensorflow:Layer stacked_tab_net_classifier is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 19/19 - 2s - loss: 0.7009 - val_loss: 0.6923
# Epoch 2/50
# 19/19 - 1s - loss: 0.6825 - val_loss: 0.6766
# Epoch 3/50
# 19/19 - 1s - loss: 0.6348 - val_loss: 0.5863
# Epoch 4/50
# 19/19 - 1s - loss: 0.4879 - val_loss: 0.3294
# Epoch 5/50
# 19/19 - 1s - loss: 0.3054 - val_loss: 0.1709
# Epoch 6/50
# 19/19 - 1s - loss: 0.2018 - val_loss: 0.1052
# Epoch 7/50
# 19/19 - 1s - loss: 0.1286 - val_loss: 0.0714
# Epoch 8/50
# 19/19 - 1s - loss: 0.0809 - val_loss: 0.0506
# Epoch 9/50
# 19/19 - 1s - loss: 0.0527 - val_loss: 0.0374
# Epoch 10/50
# 19/19 - 1s - loss: 0.0390 - val_loss: 0.0317
# Epoch 11/50
# 19/19 - 1s - loss: 0.0330 - val_loss: 0.0290
# Epoch 12/50
# 19/19 - 1s - loss: 0.0296 - val_loss: 0.0270
# Epoch 13/50
# 19/19 - 1s - loss: 0.0276 - val_loss: 0.0258
# Epoch 14/50
# 19/19 - 1s - loss: 0.0263 - val_loss: 0.0249
# Epoch 15/50
# 19/19 - 1s - loss: 0.0255 - val_loss: 0.0243
# Epoch 16/50
# 19/19 - 1s - loss: 0.0247 - val_loss: 0.0238
# Epoch 17/50
# 19/19 - 1s - loss: 0.0245 - val_loss: 0.0236
# Epoch 18/50
# 19/19 - 1s - loss: 0.0239 - val_loss: 0.0232
# Epoch 19/50
# 19/19 - 1s - loss: 0.0238 - val_loss: 0.0231
# Epoch 20/50
# 19/19 - 1s - loss: 0.0235 - val_loss: 0.0229
# Epoch 21/50
# 19/19 - 1s - loss: 0.0234 - val_loss: 0.0228
# Epoch 22/50
# 19/19 - 1s - loss: 0.0234 - val_loss: 0.0227
# Epoch 23/50
# 19/19 - 1s - loss: 0.0234 - val_loss: 0.0226
# Epoch 24/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0225
# Epoch 25/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0225
# Epoch 26/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0224
# Epoch 27/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0224
# Epoch 28/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0224
# Epoch 29/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0224
# Epoch 30/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0223
# Epoch 31/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0223
# Epoch 32/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0223
# Epoch 33/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0222
# Epoch 34/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0222
# Epoch 35/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0222
# Epoch 36/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0222
# Epoch 37/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0222
# Epoch 38/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0222
# Epoch 39/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0221
# Epoch 40/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0221
# Epoch 41/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0221
# Epoch 42/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0221
# Epoch 43/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0221
# Epoch 44/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0220
# Epoch 45/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0220
# Epoch 46/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0220
# Epoch 47/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0220
# Epoch 48/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0220
# Epoch 49/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0220
# Epoch 50/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0219
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
# Epoch 1/50
# WARNING:tensorflow:Layer stacked_tab_net_classifier is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 19/19 - 2s - loss: 0.6994 - val_loss: 0.6928
# Epoch 2/50
# 19/19 - 1s - loss: 0.6787 - val_loss: 0.6773
# Epoch 3/50
# 19/19 - 1s - loss: 0.5984 - val_loss: 0.5601
# Epoch 4/50
# 19/19 - 1s - loss: 0.3942 - val_loss: 0.2842
# Epoch 5/50
# 19/19 - 1s - loss: 0.2280 - val_loss: 0.1502
# Epoch 6/50
# 19/19 - 1s - loss: 0.1286 - val_loss: 0.0808
# Epoch 7/50
# 19/19 - 1s - loss: 0.0754 - val_loss: 0.0506
# Epoch 8/50
# 19/19 - 1s - loss: 0.0508 - val_loss: 0.0405
# Epoch 9/50
# 19/19 - 1s - loss: 0.0397 - val_loss: 0.0344
# Epoch 10/50
# 19/19 - 1s - loss: 0.0333 - val_loss: 0.0310
# Epoch 11/50
# 19/19 - 1s - loss: 0.0300 - val_loss: 0.0285
# Epoch 12/50
# 19/19 - 1s - loss: 0.0278 - val_loss: 0.0269
# Epoch 13/50
# 19/19 - 1s - loss: 0.0266 - val_loss: 0.0260
# Epoch 14/50
# 19/19 - 1s - loss: 0.0257 - val_loss: 0.0253
# Epoch 15/50
# 19/19 - 1s - loss: 0.0249 - val_loss: 0.0247
# Epoch 16/50
# 19/19 - 1s - loss: 0.0245 - val_loss: 0.0243
# Epoch 17/50
# 19/19 - 1s - loss: 0.0242 - val_loss: 0.0240
# Epoch 18/50
# 19/19 - 1s - loss: 0.0240 - val_loss: 0.0238
# Epoch 19/50
# 19/19 - 1s - loss: 0.0237 - val_loss: 0.0237
# Epoch 20/50
# 19/19 - 1s - loss: 0.0235 - val_loss: 0.0235
# Epoch 21/50
# 19/19 - 1s - loss: 0.0234 - val_loss: 0.0234
# Epoch 22/50
# 19/19 - 1s - loss: 0.0234 - val_loss: 0.0233
# Epoch 23/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0232
# Epoch 24/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0231
# Epoch 25/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0231
# Epoch 26/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0230
# Epoch 27/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0229
# Epoch 28/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0229
# Epoch 29/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0229
# Epoch 30/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0228
# Epoch 31/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0228
# Epoch 32/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0228
# Epoch 33/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0228
# Epoch 34/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0227
# Epoch 35/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0227
# Epoch 36/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0226
# Epoch 37/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0226
# Epoch 38/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0226
# Epoch 39/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0225
# Epoch 40/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0224
# Epoch 41/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0224
# Epoch 42/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0224
# Epoch 43/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0223
# Epoch 44/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0223
# Epoch 45/50
# 19/19 - 1s - loss: 0.0225 - val_loss: 0.0223
# Epoch 46/50
# 19/19 - 1s - loss: 0.0224 - val_loss: 0.0222
# Epoch 47/50
# 19/19 - 1s - loss: 0.0225 - val_loss: 0.0222
# Epoch 48/50
# 19/19 - 1s - loss: 0.0225 - val_loss: 0.0222
# Epoch 49/50
# 19/19 - 1s - loss: 0.0223 - val_loss: 0.0221
# Epoch 50/50
# 19/19 - 1s - loss: 0.0225 - val_loss: 0.0221
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# WARNING:tensorflow:Layer stacked_tab_net_classifier is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 19/19 - 2s - loss: 0.7038 - val_loss: 0.6929
# Epoch 2/50
# 19/19 - 1s - loss: 0.6861 - val_loss: 0.6820
# Epoch 3/50
# 19/19 - 1s - loss: 0.6410 - val_loss: 0.6092
# Epoch 4/50
# 19/19 - 1s - loss: 0.4934 - val_loss: 0.3086
# Epoch 5/50
# 19/19 - 1s - loss: 0.2816 - val_loss: 0.1459
# Epoch 6/50
# 19/19 - 1s - loss: 0.1599 - val_loss: 0.0953
# Epoch 7/50
# 19/19 - 1s - loss: 0.0957 - val_loss: 0.0631
# Epoch 8/50
# 19/19 - 1s - loss: 0.0626 - val_loss: 0.0426
# Epoch 9/50
# 19/19 - 1s - loss: 0.0462 - val_loss: 0.0352
# Epoch 10/50
# 19/19 - 1s - loss: 0.0367 - val_loss: 0.0306
# Epoch 11/50
# 19/19 - 1s - loss: 0.0315 - val_loss: 0.0286
# Epoch 12/50
# 19/19 - 1s - loss: 0.0287 - val_loss: 0.0267
# Epoch 13/50
# 19/19 - 1s - loss: 0.0269 - val_loss: 0.0257
# Epoch 14/50
# 19/19 - 1s - loss: 0.0258 - val_loss: 0.0251
# Epoch 15/50
# 19/19 - 1s - loss: 0.0251 - val_loss: 0.0245
# Epoch 16/50
# 19/19 - 1s - loss: 0.0246 - val_loss: 0.0242
# Epoch 17/50
# 19/19 - 1s - loss: 0.0242 - val_loss: 0.0239
# Epoch 18/50
# 19/19 - 1s - loss: 0.0239 - val_loss: 0.0236
# Epoch 19/50
# 19/19 - 1s - loss: 0.0237 - val_loss: 0.0235
# Epoch 20/50
# 19/19 - 1s - loss: 0.0238 - val_loss: 0.0234
# Epoch 21/50
# 19/19 - 1s - loss: 0.0235 - val_loss: 0.0233
# Epoch 22/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0232
# Epoch 23/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0231
# Epoch 24/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0229
# Epoch 25/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0229
# Epoch 26/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0228
# Epoch 27/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0228
# Epoch 28/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0227
# Epoch 29/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0227
# Epoch 30/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0226
# Epoch 31/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0225
# Epoch 32/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0225
# Epoch 33/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0225
# Epoch 34/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0224
# Epoch 35/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0224
# Epoch 36/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0224
# Epoch 37/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0223
# Epoch 38/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0223
# Epoch 39/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0223
# Epoch 40/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0223
# Epoch 41/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0223
# Epoch 42/50
# 19/19 - 1s - loss: 0.0225 - val_loss: 0.0222
# Epoch 43/50
# 19/19 - 1s - loss: 0.0225 - val_loss: 0.0222
# Epoch 44/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0222
# Epoch 45/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0221
# Epoch 46/50
# 19/19 - 1s - loss: 0.0224 - val_loss: 0.0221
# Epoch 47/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0221
# Epoch 48/50
# 19/19 - 1s - loss: 0.0224 - val_loss: 0.0221
# Epoch 49/50
# 19/19 - 1s - loss: 0.0224 - val_loss: 0.0220
# Epoch 50/50
# 19/19 - 1s - loss: 0.0224 - val_loss: 0.0220
# Please check your arguments if you have upgraded adabelief-tf from version 0.0.1.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  -------------
# adabelief-tf=0.0.1       1e-08  Not supported      Not supported
# Current version (0.1.0)  1e-14  supported          default: True
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
#
# Epoch 1/50
# WARNING:tensorflow:Layer stacked_tab_net_classifier is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# 19/19 - 2s - loss: 0.6992 - val_loss: 0.6927
# Epoch 2/50
# 19/19 - 1s - loss: 0.6800 - val_loss: 0.6765
# Epoch 3/50
# 19/19 - 1s - loss: 0.6182 - val_loss: 0.5667
# Epoch 4/50
# 19/19 - 1s - loss: 0.4332 - val_loss: 0.3201
# Epoch 5/50
# 19/19 - 1s - loss: 0.2609 - val_loss: 0.1562
# Epoch 6/50
# 19/19 - 1s - loss: 0.1518 - val_loss: 0.0928
# Epoch 7/50
# 19/19 - 1s - loss: 0.0868 - val_loss: 0.0562
# Epoch 8/50
# 19/19 - 1s - loss: 0.0551 - val_loss: 0.0398
# Epoch 9/50
# 19/19 - 1s - loss: 0.0406 - val_loss: 0.0331
# Epoch 10/50
# 19/19 - 1s - loss: 0.0334 - val_loss: 0.0294
# Epoch 11/50
# 19/19 - 1s - loss: 0.0299 - val_loss: 0.0276
# Epoch 12/50
# 19/19 - 1s - loss: 0.0276 - val_loss: 0.0262
# Epoch 13/50
# 19/19 - 1s - loss: 0.0263 - val_loss: 0.0253
# Epoch 14/50
# 19/19 - 1s - loss: 0.0255 - val_loss: 0.0247
# Epoch 15/50
# 19/19 - 1s - loss: 0.0248 - val_loss: 0.0242
# Epoch 16/50
# 19/19 - 1s - loss: 0.0245 - val_loss: 0.0238
# Epoch 17/50
# 19/19 - 1s - loss: 0.0241 - val_loss: 0.0235
# Epoch 18/50
# 19/19 - 1s - loss: 0.0238 - val_loss: 0.0233
# Epoch 19/50
# 19/19 - 1s - loss: 0.0237 - val_loss: 0.0231
# Epoch 20/50
# 19/19 - 1s - loss: 0.0236 - val_loss: 0.0229
# Epoch 21/50
# 19/19 - 1s - loss: 0.0234 - val_loss: 0.0228
# Epoch 22/50
# 19/19 - 1s - loss: 0.0234 - val_loss: 0.0227
# Epoch 23/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0226
# Epoch 24/50
# 19/19 - 1s - loss: 0.0231 - val_loss: 0.0225
# Epoch 25/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0224
# Epoch 26/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0224
# Epoch 27/50
# 19/19 - 1s - loss: 0.0232 - val_loss: 0.0223
# Epoch 28/50
# 19/19 - 1s - loss: 0.0230 - val_loss: 0.0224
# Epoch 29/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0223
# Epoch 30/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0222
# Epoch 31/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0222
# Epoch 32/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0222
# Epoch 33/50
# 19/19 - 1s - loss: 0.0229 - val_loss: 0.0221
# Epoch 34/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0221
# Epoch 35/50
# 19/19 - 1s - loss: 0.0228 - val_loss: 0.0220
# Epoch 36/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0220
# Epoch 37/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0220
# Epoch 38/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0219
# Epoch 39/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0219
# Epoch 40/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0219
# Epoch 41/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0219
# Epoch 42/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0218
# Epoch 43/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0218
# Epoch 44/50
# 19/19 - 1s - loss: 0.0225 - val_loss: 0.0218
# Epoch 45/50
# 19/19 - 1s - loss: 0.0225 - val_loss: 0.0218
# Epoch 46/50
# 19/19 - 1s - loss: 0.0225 - val_loss: 0.0218
# Epoch 47/50
# 19/19 - 1s - loss: 0.0226 - val_loss: 0.0217
# Epoch 48/50
# 19/19 - 1s - loss: 0.0227 - val_loss: 0.0217
# Epoch 49/50
# 19/19 - 1s - loss: 0.0225 - val_loss: 0.0216
# Epoch 50/50
# 19/19 - 1s - loss: 0.0225 - val_loss: 0.0216
#
# oof_score: 0.018610942090386662
# oof_auc_score: 0.5451452652594138
# ----------------------------------------------------------------------------------------------------

# %%
oof_score
# Out:
# 0.018610942090386662
