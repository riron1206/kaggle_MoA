# %%
# !pwd
import sys
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
sys.executable
# Out:
# C:\Users\81908\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124\run_objective_4l
# 'c:\\users\\81908\\appdata\\local\\pypoetry\\cache\\virtualenvs\\tfgpu-ehdmne1y-py3.8\\scripts\\python.exe'

# %%
# tensorflow2.0 + kerasでGPUメモリの使用量を抑える方法(最小限だけ使うように設定)
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"

# %%
import sys
sys.path.append(r'C:\Users\81908\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124')
import moa_MLPs_funcs
# Out:
# Tensorflow version 2.3.1
# n_classes: 206

# %%
import optuna


def objective(trial):
    model_type = "4l"
    params = {}
    params["activation"] = trial.suggest_categorical("activation", ["relu", "elu"])
    params["denses"] = trial.suggest_categorical(
        "denses",
        [
            [512, 448, 384, 320],
            [1024, 896, 768, 640],
            [2048, 1792, 1536, 1280],
            [2560, 2048, 1524, 1012],
            [512, 512, 512, 512],
            [1024, 1024, 1024, 1024],
            [1024, 768, 1536, 1792],
            [1024, 1536, 768, 1792],
            [512, 768, 1536, 1792],
            [512, 1536, 768, 512],
        ],
    )
    drop_rates = []
    for i in range(5):
        drop_rate = trial.suggest_uniform(f'drop_rate{i}', 0.2, 0.8)
        drop_rates.append(drop_rate)
    params["drop_rates"] = drop_rates
    print("-" * 100)
    print(f"params: {params}")

    oof_score, Y_pred = moa_MLPs_funcs.train_and_evaluate(model_type="4l", params=params)

    return oof_score

# %%
# %%time

n_trials = 100
#n_trials = 50
#n_trials = 3

study = optuna.create_study(
    study_name="study",
    storage=f"sqlite:///study.db",
    load_if_exists=True,
    direction="minimize",
    sampler=optuna.samplers.TPESampler(seed=1),
)
study.optimize(objective, n_trials=n_trials)
study.trials_dataframe().to_csv(f"objective_history.csv", index=False)
with open(f"objective_best_params.txt", mode="w") as f:
    f.write(str(study.best_params))
print(f"\nstudy.best_params:\n{study.best_params}")
# Out:
# [I 2020-11-24 15:14:14,297] A new study created in memory with name: study
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [512, 448, 384, 320] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [1024, 896, 768, 640] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [2048, 1792, 1536, 1280] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [2560, 2048, 1524, 1012] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [512, 512, 512, 512] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [1024, 1024, 1024, 1024] which is of type list.
#   warnings.warn(message)
# ----------------------------------------------------------------------------------------------------
# params: {'activation': 'elu', 'denses': [2560, 2048, 1524, 1012], 'drop_rates': [0.6321946960652949, 0.20006862489040694, 0.3813995435791039, 0.2880535344902678, 0.2554031568612787]}
# WARNING:tensorflow:From C:\Users\81908\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124\moa_MLPs_funcs.py:509: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass shuffle=True, random_state=0 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# Epoch 1/50
# 19/19 - 2s - loss: 0.2562 - binary_crossentropy: 0.2535 - val_loss: 7.7791 - val_binary_crossentropy: 7.7651
# Epoch 2/50
# 19/19 - 1s - loss: 0.0303 - binary_crossentropy: 0.0228 - val_loss: 1.5225 - val_binary_crossentropy: 1.5115
# Epoch 3/50
# 19/19 - 1s - loss: 0.0286 - binary_crossentropy: 0.0211 - val_loss: 0.2323 - val_binary_crossentropy: 0.2233
# Epoch 4/50
# 19/19 - 1s - loss: 0.0266 - binary_crossentropy: 0.0200 - val_loss: 0.0545 - val_binary_crossentropy: 0.0469
# Epoch 5/50
# 19/19 - 1s - loss: 0.0261 - binary_crossentropy: 0.0201 - val_loss: 0.0325 - val_binary_crossentropy: 0.0257
# Epoch 6/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0285 - val_binary_crossentropy: 0.0222
# Epoch 7/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0200 - val_loss: 0.0271 - val_binary_crossentropy: 0.0210
# Epoch 8/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0202 - val_loss: 0.0264 - val_binary_crossentropy: 0.0203
# Epoch 9/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0261 - val_binary_crossentropy: 0.0201
# Epoch 10/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0258 - val_binary_crossentropy: 0.0199
# Epoch 11/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0256 - val_binary_crossentropy: 0.0197
# Epoch 12/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0255 - val_binary_crossentropy: 0.0197
# Epoch 13/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0254 - val_binary_crossentropy: 0.0195
# Epoch 14/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0253 - val_binary_crossentropy: 0.0195
# Epoch 15/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0253 - val_binary_crossentropy: 0.0194
# Epoch 16/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0253 - val_binary_crossentropy: 0.0195
# Epoch 17/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0253 - val_binary_crossentropy: 0.0194
# Epoch 18/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0253 - val_binary_crossentropy: 0.0195
# Epoch 19/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0199 - val_loss: 0.0252 - val_binary_crossentropy: 0.0194
# Epoch 20/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0252 - val_binary_crossentropy: 0.0194
# Epoch 21/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0252 - val_binary_crossentropy: 0.0193
# Epoch 22/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0199 - val_loss: 0.0252 - val_binary_crossentropy: 0.0193
# Epoch 23/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0252 - val_binary_crossentropy: 0.0193
# Epoch 24/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0251 - val_binary_crossentropy: 0.0193
# Epoch 25/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0251 - val_binary_crossentropy: 0.0193
# Epoch 26/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0251 - val_binary_crossentropy: 0.0192
# Epoch 27/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0250 - val_binary_crossentropy: 0.0192
# Epoch 28/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0250 - val_binary_crossentropy: 0.0192
# Epoch 29/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0250 - val_binary_crossentropy: 0.0192
# Epoch 30/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0249 - val_binary_crossentropy: 0.0191
# Epoch 31/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0250 - val_binary_crossentropy: 0.0192
# Epoch 32/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0198 - val_loss: 0.0249 - val_binary_crossentropy: 0.0191
# Epoch 33/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0250 - val_binary_crossentropy: 0.0192
# Epoch 34/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0249 - val_binary_crossentropy: 0.0190
# Epoch 35/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0249 - val_binary_crossentropy: 0.0191
# Epoch 36/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0248 - val_binary_crossentropy: 0.0190
# Epoch 37/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0196 - val_loss: 0.0248 - val_binary_crossentropy: 0.0190
# Epoch 38/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0196 - val_loss: 0.0248 - val_binary_crossentropy: 0.0190
# Epoch 39/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0247 - val_binary_crossentropy: 0.0189
# Epoch 40/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0247 - val_binary_crossentropy: 0.0189
# Epoch 41/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0247 - val_binary_crossentropy: 0.0189
# Epoch 42/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0195 - val_loss: 0.0246 - val_binary_crossentropy: 0.0188
# Epoch 43/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0195 - val_loss: 0.0245 - val_binary_crossentropy: 0.0188
# Epoch 44/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0245 - val_binary_crossentropy: 0.0187
# Epoch 45/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0195 - val_loss: 0.0245 - val_binary_crossentropy: 0.0187
# Epoch 46/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0245 - val_binary_crossentropy: 0.0187
# Epoch 47/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0244 - val_binary_crossentropy: 0.0187
# Epoch 48/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0194 - val_loss: 0.0244 - val_binary_crossentropy: 0.0185
# Epoch 49/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0194 - val_loss: 0.0244 - val_binary_crossentropy: 0.0186
# Epoch 50/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0243 - val_binary_crossentropy: 0.0185
# Epoch 1/50
# 19/19 - 2s - loss: 0.3941 - binary_crossentropy: 0.3924 - val_loss: 4.4088 - val_binary_crossentropy: 4.4097
# Epoch 2/50
# 19/19 - 1s - loss: 0.0288 - binary_crossentropy: 0.0227 - val_loss: 0.0842 - val_binary_crossentropy: 0.0737
# Epoch 3/50
# 19/19 - 1s - loss: 0.0284 - binary_crossentropy: 0.0214 - val_loss: 0.0458 - val_binary_crossentropy: 0.0369
# Epoch 4/50
# 19/19 - 1s - loss: 0.0267 - binary_crossentropy: 0.0203 - val_loss: 0.0332 - val_binary_crossentropy: 0.0257
# Epoch 5/50
# 19/19 - 1s - loss: 0.0263 - binary_crossentropy: 0.0202 - val_loss: 0.0286 - val_binary_crossentropy: 0.0218
# Epoch 6/50
# 19/19 - 1s - loss: 0.0261 - binary_crossentropy: 0.0202 - val_loss: 0.0274 - val_binary_crossentropy: 0.0210
# Epoch 7/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0201 - val_loss: 0.0264 - val_binary_crossentropy: 0.0202
# Epoch 8/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0259 - val_binary_crossentropy: 0.0198
# Epoch 9/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0202 - val_loss: 0.0255 - val_binary_crossentropy: 0.0195
# Epoch 10/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0254 - val_binary_crossentropy: 0.0194
# Epoch 11/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0252 - val_binary_crossentropy: 0.0193
# Epoch 12/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0251 - val_binary_crossentropy: 0.0192
# Epoch 13/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0251 - val_binary_crossentropy: 0.0192
# Epoch 14/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0250 - val_binary_crossentropy: 0.0191
# Epoch 15/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0249 - val_binary_crossentropy: 0.0191
# Epoch 16/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0249 - val_binary_crossentropy: 0.0190
# Epoch 17/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0248 - val_binary_crossentropy: 0.0190
# Epoch 18/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0198 - val_loss: 0.0248 - val_binary_crossentropy: 0.0190
# Epoch 19/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0248 - val_binary_crossentropy: 0.0189
# Epoch 20/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0248 - val_binary_crossentropy: 0.0189
# Epoch 21/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0247 - val_binary_crossentropy: 0.0189
# Epoch 22/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0247 - val_binary_crossentropy: 0.0189
# Epoch 23/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0247 - val_binary_crossentropy: 0.0188
# Epoch 24/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0247 - val_binary_crossentropy: 0.0188
# Epoch 25/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0246 - val_binary_crossentropy: 0.0188
# Epoch 26/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0246 - val_binary_crossentropy: 0.0187
# Epoch 27/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0246 - val_binary_crossentropy: 0.0187
# Epoch 28/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0196 - val_loss: 0.0245 - val_binary_crossentropy: 0.0187
# Epoch 29/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0245 - val_binary_crossentropy: 0.0187
# Epoch 30/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0245 - val_binary_crossentropy: 0.0187
# Epoch 31/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0197 - val_loss: 0.0244 - val_binary_crossentropy: 0.0186
# Epoch 32/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0196 - val_loss: 0.0244 - val_binary_crossentropy: 0.0186
# Epoch 33/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0194 - val_loss: 0.0244 - val_binary_crossentropy: 0.0185
# Epoch 34/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0196 - val_loss: 0.0243 - val_binary_crossentropy: 0.0185
# Epoch 35/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0243 - val_binary_crossentropy: 0.0184
# Epoch 36/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0243 - val_binary_crossentropy: 0.0185
# Epoch 37/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0243 - val_binary_crossentropy: 0.0184
# Epoch 38/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0194 - val_loss: 0.0242 - val_binary_crossentropy: 0.0184
# Epoch 39/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0196 - val_loss: 0.0242 - val_binary_crossentropy: 0.0184
# Epoch 40/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0195 - val_loss: 0.0242 - val_binary_crossentropy: 0.0184
# Epoch 41/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0194 - val_loss: 0.0241 - val_binary_crossentropy: 0.0183
# Epoch 42/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0241 - val_binary_crossentropy: 0.0183
# Epoch 43/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0241 - val_binary_crossentropy: 0.0182
# Epoch 44/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0241 - val_binary_crossentropy: 0.0182
# Epoch 45/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0240 - val_binary_crossentropy: 0.0182
# Epoch 46/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0240 - val_binary_crossentropy: 0.0182
# Epoch 47/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0195 - val_loss: 0.0240 - val_binary_crossentropy: 0.0182
# Epoch 48/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0240 - val_binary_crossentropy: 0.0182
# Epoch 49/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0240 - val_binary_crossentropy: 0.0181
# Epoch 50/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0194 - val_loss: 0.0240 - val_binary_crossentropy: 0.0181
# Epoch 1/50
# 19/19 - 2s - loss: 0.3301 - binary_crossentropy: 0.3280 - val_loss: 8.4871 - val_binary_crossentropy: 8.4845
# Epoch 2/50
# 19/19 - 1s - loss: 0.0294 - binary_crossentropy: 0.0227 - val_loss: 0.2874 - val_binary_crossentropy: 0.2758
# Epoch 3/50
# 19/19 - 1s - loss: 0.0283 - binary_crossentropy: 0.0211 - val_loss: 0.0530 - val_binary_crossentropy: 0.0435
# Epoch 4/50
# 19/19 - 1s - loss: 0.0268 - binary_crossentropy: 0.0202 - val_loss: 0.0360 - val_binary_crossentropy: 0.0281
# Epoch 5/50
# 19/19 - 1s - loss: 0.0262 - binary_crossentropy: 0.0201 - val_loss: 0.0307 - val_binary_crossentropy: 0.0238
# Epoch 6/50
# 19/19 - 1s - loss: 0.0261 - binary_crossentropy: 0.0202 - val_loss: 0.0287 - val_binary_crossentropy: 0.0223
# Epoch 7/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0274 - val_binary_crossentropy: 0.0212
# Epoch 8/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0268 - val_binary_crossentropy: 0.0208
# Epoch 9/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0263 - val_binary_crossentropy: 0.0204
# Epoch 10/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0261 - val_binary_crossentropy: 0.0202
# Epoch 11/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0260 - val_binary_crossentropy: 0.0201
# Epoch 12/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0259 - val_binary_crossentropy: 0.0200
# Epoch 13/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0258 - val_binary_crossentropy: 0.0199
# Epoch 14/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0257 - val_binary_crossentropy: 0.0198
# Epoch 15/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0256 - val_binary_crossentropy: 0.0198
# Epoch 16/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0256 - val_binary_crossentropy: 0.0197
# Epoch 17/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0255 - val_binary_crossentropy: 0.0196
# Epoch 18/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0255 - val_binary_crossentropy: 0.0196
# Epoch 19/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0254 - val_binary_crossentropy: 0.0196
# Epoch 20/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0254 - val_binary_crossentropy: 0.0195
# Epoch 21/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0253 - val_binary_crossentropy: 0.0195
# Epoch 22/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0253 - val_binary_crossentropy: 0.0194
# Epoch 23/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0252 - val_binary_crossentropy: 0.0194
# Epoch 24/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0252 - val_binary_crossentropy: 0.0194
# Epoch 25/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0252 - val_binary_crossentropy: 0.0193
# Epoch 26/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0197 - val_loss: 0.0251 - val_binary_crossentropy: 0.0193
# Epoch 27/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0251 - val_binary_crossentropy: 0.0193
# Epoch 28/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0250 - val_binary_crossentropy: 0.0192
# Epoch 29/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0250 - val_binary_crossentropy: 0.0192
# Epoch 30/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0249 - val_binary_crossentropy: 0.0191
# Epoch 31/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0249 - val_binary_crossentropy: 0.0191
# Epoch 32/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0248 - val_binary_crossentropy: 0.0190
# Epoch 33/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0248 - val_binary_crossentropy: 0.0190
# Epoch 34/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0196 - val_loss: 0.0247 - val_binary_crossentropy: 0.0189
# Epoch 35/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0247 - val_binary_crossentropy: 0.0189
# Epoch 36/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0247 - val_binary_crossentropy: 0.0188
# Epoch 37/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0247 - val_binary_crossentropy: 0.0188
# Epoch 38/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0246 - val_binary_crossentropy: 0.0187
# Epoch 39/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0194 - val_loss: 0.0245 - val_binary_crossentropy: 0.0187
# Epoch 40/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0193 - val_loss: 0.0245 - val_binary_crossentropy: 0.0186
# Epoch 41/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0245 - val_binary_crossentropy: 0.0186
# Epoch 42/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0194 - val_loss: 0.0245 - val_binary_crossentropy: 0.0186
# Epoch 43/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0193 - val_loss: 0.0244 - val_binary_crossentropy: 0.0186
# Epoch 44/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0194 - val_loss: 0.0244 - val_binary_crossentropy: 0.0186
# Epoch 45/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0193 - val_loss: 0.0243 - val_binary_crossentropy: 0.0185
# Epoch 46/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0192 - val_loss: 0.0243 - val_binary_crossentropy: 0.0185
# Epoch 47/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0193 - val_loss: 0.0243 - val_binary_crossentropy: 0.0185
# Epoch 48/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0193 - val_loss: 0.0243 - val_binary_crossentropy: 0.0185
# Epoch 49/50
# 19/19 - 1s - loss: 0.0250 - binary_crossentropy: 0.0191 - val_loss: 0.0242 - val_binary_crossentropy: 0.0183
# Epoch 50/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0193 - val_loss: 0.0242 - val_binary_crossentropy: 0.0184
# Epoch 1/50
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0110s vs `on_train_batch_end` time: 0.0170s). Check your callbacks.
# 19/19 - 2s - loss: 0.3511 - binary_crossentropy: 0.3491 - val_loss: 2.8533 - val_binary_crossentropy: 2.8176
# Epoch 2/50
# 19/19 - 1s - loss: 0.0289 - binary_crossentropy: 0.0224 - val_loss: 0.1089 - val_binary_crossentropy: 0.0929
# Epoch 3/50
# 19/19 - 1s - loss: 0.0281 - binary_crossentropy: 0.0209 - val_loss: 0.0514 - val_binary_crossentropy: 0.0408
# Epoch 4/50
# 19/19 - 1s - loss: 0.0267 - binary_crossentropy: 0.0201 - val_loss: 0.0355 - val_binary_crossentropy: 0.0274
# Epoch 5/50
# 19/19 - 1s - loss: 0.0261 - binary_crossentropy: 0.0201 - val_loss: 0.0301 - val_binary_crossentropy: 0.0232
# Epoch 6/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0200 - val_loss: 0.0281 - val_binary_crossentropy: 0.0217
# Epoch 7/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0272 - val_binary_crossentropy: 0.0210
# Epoch 8/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0202 - val_loss: 0.0267 - val_binary_crossentropy: 0.0206
# Epoch 9/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0263 - val_binary_crossentropy: 0.0203
# Epoch 10/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0202 - val_loss: 0.0260 - val_binary_crossentropy: 0.0200
# Epoch 11/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0258 - val_binary_crossentropy: 0.0199
# Epoch 12/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0256 - val_binary_crossentropy: 0.0197
# Epoch 13/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0256 - val_binary_crossentropy: 0.0197
# Epoch 14/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0256 - val_binary_crossentropy: 0.0198
# Epoch 15/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0255 - val_binary_crossentropy: 0.0196
# Epoch 16/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0254 - val_binary_crossentropy: 0.0195
# Epoch 17/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0253 - val_binary_crossentropy: 0.0195
# Epoch 18/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0253 - val_binary_crossentropy: 0.0195
# Epoch 19/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0253 - val_binary_crossentropy: 0.0194
# Epoch 20/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0252 - val_binary_crossentropy: 0.0194
# Epoch 21/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0252 - val_binary_crossentropy: 0.0193
# Epoch 22/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0250 - val_binary_crossentropy: 0.0192
# Epoch 23/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0250 - val_binary_crossentropy: 0.0192
# Epoch 24/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0250 - val_binary_crossentropy: 0.0192
# Epoch 25/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0250 - val_binary_crossentropy: 0.0191
# Epoch 26/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0249 - val_binary_crossentropy: 0.0191
# Epoch 27/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0248 - val_binary_crossentropy: 0.0190
# Epoch 28/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0248 - val_binary_crossentropy: 0.0190
# Epoch 29/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0248 - val_binary_crossentropy: 0.0189
# Epoch 30/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0247 - val_binary_crossentropy: 0.0189
# Epoch 31/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0247 - val_binary_crossentropy: 0.0189
# Epoch 32/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0247 - val_binary_crossentropy: 0.0188
# Epoch 33/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0247 - val_binary_crossentropy: 0.0189
# Epoch 34/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0247 - val_binary_crossentropy: 0.0188
# Epoch 35/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0195 - val_loss: 0.0246 - val_binary_crossentropy: 0.0188
# Epoch 36/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0194 - val_loss: 0.0246 - val_binary_crossentropy: 0.0188
# Epoch 37/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0246 - val_binary_crossentropy: 0.0188
# Epoch 38/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0194 - val_loss: 0.0246 - val_binary_crossentropy: 0.0188
# Epoch 39/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0246 - val_binary_crossentropy: 0.0188
# Epoch 40/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0246 - val_binary_crossentropy: 0.0187
# Epoch 41/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0246 - val_binary_crossentropy: 0.0187
# Epoch 42/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0193 - val_loss: 0.0245 - val_binary_crossentropy: 0.0187
# Epoch 43/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0193 - val_loss: 0.0245 - val_binary_crossentropy: 0.0187
# Epoch 44/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0244 - val_binary_crossentropy: 0.0186
# Epoch 45/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0194 - val_loss: 0.0244 - val_binary_crossentropy: 0.0186
# Epoch 46/50
# 19/19 - 1s - loss: 0.0250 - binary_crossentropy: 0.0192 - val_loss: 0.0243 - val_binary_crossentropy: 0.0185
# Epoch 47/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0193 - val_loss: 0.0243 - val_binary_crossentropy: 0.0185
# Epoch 48/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0192 - val_loss: 0.0243 - val_binary_crossentropy: 0.0184
# Epoch 49/50
# 19/19 - 1s - loss: 0.0250 - binary_crossentropy: 0.0192 - val_loss: 0.0242 - val_binary_crossentropy: 0.0184
# Epoch 50/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0192 - val_loss: 0.0242 - val_binary_crossentropy: 0.0184
# Epoch 1/50
# 19/19 - 2s - loss: 0.2627 - binary_crossentropy: 0.2600 - val_loss: 3.5520 - val_binary_crossentropy: 3.5307
# Epoch 2/50
# 19/19 - 1s - loss: 0.0306 - binary_crossentropy: 0.0231 - val_loss: 0.5598 - val_binary_crossentropy: 0.5453
# Epoch 3/50
# 19/19 - 1s - loss: 0.0288 - binary_crossentropy: 0.0212 - val_loss: 0.1198 - val_binary_crossentropy: 0.1095
# Epoch 4/50
# 19/19 - 1s - loss: 0.0269 - binary_crossentropy: 0.0203 - val_loss: 0.0421 - val_binary_crossentropy: 0.0342
# Epoch 5/50
# 19/19 - 1s - loss: 0.0263 - binary_crossentropy: 0.0203 - val_loss: 0.0311 - val_binary_crossentropy: 0.0244
# Epoch 6/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0201 - val_loss: 0.0283 - val_binary_crossentropy: 0.0221
# Epoch 7/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0202 - val_loss: 0.0271 - val_binary_crossentropy: 0.0211
# Epoch 8/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0202 - val_loss: 0.0264 - val_binary_crossentropy: 0.0204
# Epoch 9/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0202 - val_loss: 0.0260 - val_binary_crossentropy: 0.0201
# Epoch 10/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0200 - val_loss: 0.0259 - val_binary_crossentropy: 0.0200
# Epoch 11/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0202 - val_loss: 0.0256 - val_binary_crossentropy: 0.0197
# Epoch 12/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0255 - val_binary_crossentropy: 0.0197
# Epoch 13/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0254 - val_binary_crossentropy: 0.0196
# Epoch 14/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0253 - val_binary_crossentropy: 0.0194
# Epoch 15/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0252 - val_binary_crossentropy: 0.0194
# Epoch 16/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0252 - val_binary_crossentropy: 0.0194
# Epoch 17/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0252 - val_binary_crossentropy: 0.0194
# Epoch 18/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0251 - val_binary_crossentropy: 0.0193
# Epoch 19/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0200 - val_loss: 0.0251 - val_binary_crossentropy: 0.0193
# Epoch 20/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0251 - val_binary_crossentropy: 0.0192
# Epoch 21/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0251 - val_binary_crossentropy: 0.0192
# Epoch 22/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0250 - val_binary_crossentropy: 0.0192
# Epoch 23/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0251 - val_binary_crossentropy: 0.0192
# Epoch 24/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0250 - val_binary_crossentropy: 0.0192
# Epoch 25/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0250 - val_binary_crossentropy: 0.0191
# Epoch 26/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0199 - val_loss: 0.0250 - val_binary_crossentropy: 0.0191
# Epoch 27/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0249 - val_binary_crossentropy: 0.0191
# Epoch 28/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0199 - val_loss: 0.0249 - val_binary_crossentropy: 0.0191
# Epoch 29/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0249 - val_binary_crossentropy: 0.0191
# Epoch 30/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0249 - val_binary_crossentropy: 0.0191
# Epoch 31/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0249 - val_binary_crossentropy: 0.0190
# Epoch 32/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0248 - val_binary_crossentropy: 0.0190
# Epoch 33/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0248 - val_binary_crossentropy: 0.0189
# Epoch 34/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0197 - val_loss: 0.0247 - val_binary_crossentropy: 0.0189
# Epoch 35/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0247 - val_binary_crossentropy: 0.0189
# Epoch 36/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0196 - val_loss: 0.0247 - val_binary_crossentropy: 0.0189
# Epoch 37/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0246 - val_binary_crossentropy: 0.0188
# Epoch 38/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0245 - val_binary_crossentropy: 0.0187
# Epoch 39/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0245 - val_binary_crossentropy: 0.0186
# Epoch 40/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0195 - val_loss: 0.0244 - val_binary_crossentropy: 0.0186
# Epoch 41/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0244 - val_binary_crossentropy: 0.0185
# Epoch 42/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0243 - val_binary_crossentropy: 0.0185
# Epoch 43/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0195 - val_loss: 0.0243 - val_binary_crossentropy: 0.0185
# Epoch 44/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0194 - val_loss: 0.0242 - val_binary_crossentropy: 0.0184
# Epoch 45/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0194 - val_loss: 0.0242 - val_binary_crossentropy: 0.0184
# Epoch 46/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0194 - val_loss: 0.0241 - val_binary_crossentropy: 0.0183
# Epoch 47/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0241 - val_binary_crossentropy: 0.0183
# Epoch 48/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0240 - val_binary_crossentropy: 0.0182
# Epoch 49/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0193 - val_loss: 0.0240 - val_binary_crossentropy: 0.0181
# Epoch 50/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0193 - val_loss: 0.0239 - val_binary_crossentropy: 0.0181
# [I 2020-11-24 15:20:09,318] Trial 0 finished with value: 0.017965821485058774 and parameters: {'activation': 'elu', 'denses': [2560, 2048, 1524, 1012], 'drop_rate0': 0.6321946960652949, 'drop_rate1': 0.20006862489040694, 'drop_rate2': 0.3813995435791039, 'drop_rate3': 0.2880535344902678, 'drop_rate4': 0.2554031568612787}. Best is trial 0 with value: 0.017965821485058774.
# oof_score: 0.017965821485058774
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# params: {'activation': 'relu', 'denses': [1024, 1024, 1024, 1024], 'drop_rates': [0.6018476220820881, 0.7613234424836193, 0.7077865500116103, 0.3879641101593651, 0.5147288957437228]}
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [512, 448, 384, 320] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [1024, 896, 768, 640] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [2048, 1792, 1536, 1280] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [2560, 2048, 1524, 1012] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [512, 512, 512, 512] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [1024, 1024, 1024, 1024] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass shuffle=True, random_state=0 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# Epoch 1/50
# 19/19 - 2s - loss: 0.2624 - binary_crossentropy: 0.2598 - val_loss: 0.0591 - val_binary_crossentropy: 0.0504
# Epoch 2/50
# 19/19 - 1s - loss: 0.0316 - binary_crossentropy: 0.0237 - val_loss: 0.0449 - val_binary_crossentropy: 0.0349
# Epoch 3/50
# 19/19 - 1s - loss: 0.0294 - binary_crossentropy: 0.0217 - val_loss: 0.0315 - val_binary_crossentropy: 0.0233
# Epoch 4/50
# 19/19 - 1s - loss: 0.0270 - binary_crossentropy: 0.0204 - val_loss: 0.0284 - val_binary_crossentropy: 0.0215
# Epoch 5/50
# 19/19 - 1s - loss: 0.0264 - binary_crossentropy: 0.0203 - val_loss: 0.0269 - val_binary_crossentropy: 0.0205
# Epoch 6/50
# 19/19 - 1s - loss: 0.0262 - binary_crossentropy: 0.0203 - val_loss: 0.0263 - val_binary_crossentropy: 0.0201
# Epoch 7/50
# 19/19 - 1s - loss: 0.0261 - binary_crossentropy: 0.0202 - val_loss: 0.0260 - val_binary_crossentropy: 0.0200
# Epoch 8/50
# 19/19 - 1s - loss: 0.0262 - binary_crossentropy: 0.0203 - val_loss: 0.0258 - val_binary_crossentropy: 0.0199
# Epoch 9/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0202 - val_loss: 0.0257 - val_binary_crossentropy: 0.0198
# Epoch 10/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0201 - val_loss: 0.0255 - val_binary_crossentropy: 0.0196
# Epoch 11/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0255 - val_binary_crossentropy: 0.0196
# Epoch 12/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0254 - val_binary_crossentropy: 0.0195
# Epoch 13/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0253 - val_binary_crossentropy: 0.0194
# Epoch 14/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0252 - val_binary_crossentropy: 0.0194
# Epoch 15/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0251 - val_binary_crossentropy: 0.0193
# Epoch 16/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0250 - val_binary_crossentropy: 0.0191
# Epoch 17/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0250 - val_binary_crossentropy: 0.0191
# Epoch 18/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0249 - val_binary_crossentropy: 0.0190
# Epoch 19/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0248 - val_binary_crossentropy: 0.0189
# Epoch 20/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0198 - val_loss: 0.0247 - val_binary_crossentropy: 0.0189
# Epoch 21/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0196 - val_loss: 0.0247 - val_binary_crossentropy: 0.0188
# Epoch 22/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0197 - val_loss: 0.0246 - val_binary_crossentropy: 0.0187
# Epoch 23/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0245 - val_binary_crossentropy: 0.0186
# Epoch 24/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0245 - val_binary_crossentropy: 0.0186
# Epoch 25/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0196 - val_loss: 0.0245 - val_binary_crossentropy: 0.0186
# Epoch 26/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0196 - val_loss: 0.0243 - val_binary_crossentropy: 0.0185
# Epoch 27/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0242 - val_binary_crossentropy: 0.0184
# Epoch 28/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0242 - val_binary_crossentropy: 0.0183
# Epoch 29/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0242 - val_binary_crossentropy: 0.0183
# Epoch 30/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0195 - val_loss: 0.0241 - val_binary_crossentropy: 0.0183
# Epoch 31/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0241 - val_binary_crossentropy: 0.0183
# Epoch 32/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0240 - val_binary_crossentropy: 0.0182
# Epoch 33/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0240 - val_binary_crossentropy: 0.0182
# Epoch 34/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0194 - val_loss: 0.0240 - val_binary_crossentropy: 0.0181
# Epoch 35/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0194 - val_loss: 0.0239 - val_binary_crossentropy: 0.0180
# Epoch 36/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0194 - val_loss: 0.0239 - val_binary_crossentropy: 0.0180
# Epoch 37/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0193 - val_loss: 0.0239 - val_binary_crossentropy: 0.0180
# Epoch 38/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0193 - val_loss: 0.0238 - val_binary_crossentropy: 0.0180
# Epoch 39/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0193 - val_loss: 0.0238 - val_binary_crossentropy: 0.0179
# Epoch 40/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0237 - val_binary_crossentropy: 0.0179
# Epoch 41/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0192 - val_loss: 0.0238 - val_binary_crossentropy: 0.0180
# Epoch 42/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0192 - val_loss: 0.0237 - val_binary_crossentropy: 0.0179
# Epoch 43/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0192 - val_loss: 0.0237 - val_binary_crossentropy: 0.0178
# Epoch 44/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0194 - val_loss: 0.0237 - val_binary_crossentropy: 0.0178
# Epoch 45/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0192 - val_loss: 0.0237 - val_binary_crossentropy: 0.0177
# Epoch 46/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0192 - val_loss: 0.0237 - val_binary_crossentropy: 0.0178
# Epoch 47/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0192 - val_loss: 0.0237 - val_binary_crossentropy: 0.0178
# Epoch 48/50
# 19/19 - 1s - loss: 0.0250 - binary_crossentropy: 0.0192 - val_loss: 0.0236 - val_binary_crossentropy: 0.0177
# Epoch 49/50
# 19/19 - 1s - loss: 0.0250 - binary_crossentropy: 0.0191 - val_loss: 0.0236 - val_binary_crossentropy: 0.0177
# Epoch 50/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0192 - val_loss: 0.0236 - val_binary_crossentropy: 0.0176
# Epoch 1/50
# 19/19 - 2s - loss: 0.2941 - binary_crossentropy: 0.2917 - val_loss: 0.0505 - val_binary_crossentropy: 0.0419
# Epoch 2/50
# 19/19 - 1s - loss: 0.0312 - binary_crossentropy: 0.0235 - val_loss: 0.0427 - val_binary_crossentropy: 0.0329
# Epoch 3/50
# 19/19 - 1s - loss: 0.0297 - binary_crossentropy: 0.0219 - val_loss: 0.0304 - val_binary_crossentropy: 0.0223
# Epoch 4/50
# 19/19 - 1s - loss: 0.0270 - binary_crossentropy: 0.0202 - val_loss: 0.0275 - val_binary_crossentropy: 0.0207
# Epoch 5/50
# 19/19 - 1s - loss: 0.0263 - binary_crossentropy: 0.0203 - val_loss: 0.0262 - val_binary_crossentropy: 0.0199
# Epoch 6/50
# 19/19 - 1s - loss: 0.0262 - binary_crossentropy: 0.0203 - val_loss: 0.0257 - val_binary_crossentropy: 0.0196
# Epoch 7/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0202 - val_loss: 0.0256 - val_binary_crossentropy: 0.0195
# Epoch 8/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0202 - val_loss: 0.0255 - val_binary_crossentropy: 0.0195
# Epoch 9/50
# 19/19 - 1s - loss: 0.0261 - binary_crossentropy: 0.0202 - val_loss: 0.0254 - val_binary_crossentropy: 0.0194
# Epoch 10/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0201 - val_loss: 0.0253 - val_binary_crossentropy: 0.0193
# Epoch 11/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0200 - val_loss: 0.0252 - val_binary_crossentropy: 0.0193
# Epoch 12/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0252 - val_binary_crossentropy: 0.0192
# Epoch 13/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0200 - val_loss: 0.0251 - val_binary_crossentropy: 0.0192
# Epoch 14/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0200 - val_loss: 0.0250 - val_binary_crossentropy: 0.0191
# Epoch 15/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0200 - val_loss: 0.0250 - val_binary_crossentropy: 0.0191
# Epoch 16/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0249 - val_binary_crossentropy: 0.0190
# Epoch 17/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0201 - val_loss: 0.0248 - val_binary_crossentropy: 0.0189
# Epoch 18/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0248 - val_binary_crossentropy: 0.0189
# Epoch 19/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0247 - val_binary_crossentropy: 0.0188
# Epoch 20/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0247 - val_binary_crossentropy: 0.0188
# Epoch 21/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0198 - val_loss: 0.0246 - val_binary_crossentropy: 0.0187
# Epoch 22/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0246 - val_binary_crossentropy: 0.0187
# Epoch 23/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0199 - val_loss: 0.0246 - val_binary_crossentropy: 0.0187
# Epoch 24/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0198 - val_loss: 0.0245 - val_binary_crossentropy: 0.0186
# Epoch 25/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0245 - val_binary_crossentropy: 0.0186
# Epoch 26/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0197 - val_loss: 0.0244 - val_binary_crossentropy: 0.0185
# Epoch 27/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0244 - val_binary_crossentropy: 0.0185
# Epoch 28/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0243 - val_binary_crossentropy: 0.0184
# Epoch 29/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0243 - val_binary_crossentropy: 0.0184
# Epoch 30/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0242 - val_binary_crossentropy: 0.0184
# Epoch 31/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0242 - val_binary_crossentropy: 0.0183
# Epoch 32/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0241 - val_binary_crossentropy: 0.0182
# Epoch 33/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0194 - val_loss: 0.0241 - val_binary_crossentropy: 0.0182
# Epoch 34/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0241 - val_binary_crossentropy: 0.0182
# Epoch 35/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0196 - val_loss: 0.0239 - val_binary_crossentropy: 0.0181
# Epoch 36/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0195 - val_loss: 0.0239 - val_binary_crossentropy: 0.0181
# Epoch 37/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0239 - val_binary_crossentropy: 0.0180
# Epoch 38/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0193 - val_loss: 0.0238 - val_binary_crossentropy: 0.0180
# Epoch 39/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0195 - val_loss: 0.0238 - val_binary_crossentropy: 0.0180
# Epoch 40/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0237 - val_binary_crossentropy: 0.0179
# Epoch 41/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0193 - val_loss: 0.0238 - val_binary_crossentropy: 0.0179
# Epoch 42/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0194 - val_loss: 0.0237 - val_binary_crossentropy: 0.0179
# Epoch 43/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0193 - val_loss: 0.0236 - val_binary_crossentropy: 0.0178
# Epoch 44/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0193 - val_loss: 0.0237 - val_binary_crossentropy: 0.0178
# Epoch 45/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0193 - val_loss: 0.0236 - val_binary_crossentropy: 0.0178
# Epoch 46/50
# ...
# Epoch 3/50
# 19/19 - 1s - loss: 0.0296 - binary_crossentropy: 0.0218 - val_loss: 0.0322 - val_binary_crossentropy: 0.0241
# Epoch 4/50
# 19/19 - 1s - loss: 0.0273 - binary_crossentropy: 0.0206 - val_loss: 0.0283 - val_binary_crossentropy: 0.0214
# Epoch 5/50
# 19/19 - 1s - loss: 0.0266 - binary_crossentropy: 0.0205 - val_loss: 0.0265 - val_binary_crossentropy: 0.0201
# Epoch 6/50
# 19/19 - 1s - loss: 0.0262 - binary_crossentropy: 0.0203 - val_loss: 0.0259 - val_binary_crossentropy: 0.0197
# Epoch 7/50
# 19/19 - 1s - loss: 0.0262 - binary_crossentropy: 0.0203 - val_loss: 0.0256 - val_binary_crossentropy: 0.0195
# Epoch 8/50
# 19/19 - 1s - loss: 0.0262 - binary_crossentropy: 0.0203 - val_loss: 0.0254 - val_binary_crossentropy: 0.0193
# Epoch 9/50
# 19/19 - 1s - loss: 0.0261 - binary_crossentropy: 0.0202 - val_loss: 0.0253 - val_binary_crossentropy: 0.0192
# Epoch 10/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0253 - val_binary_crossentropy: 0.0192
# Epoch 11/50
# 19/19 - 1s - loss: 0.0260 - binary_crossentropy: 0.0202 - val_loss: 0.0252 - val_binary_crossentropy: 0.0192
# Epoch 12/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0200 - val_loss: 0.0251 - val_binary_crossentropy: 0.0191
# Epoch 13/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0250 - val_binary_crossentropy: 0.0191
# Epoch 14/50
# 19/19 - 1s - loss: 0.0259 - binary_crossentropy: 0.0201 - val_loss: 0.0250 - val_binary_crossentropy: 0.0190
# Epoch 15/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0200 - val_loss: 0.0249 - val_binary_crossentropy: 0.0190
# Epoch 16/50
# 19/19 - 1s - loss: 0.0258 - binary_crossentropy: 0.0199 - val_loss: 0.0249 - val_binary_crossentropy: 0.0189
# Epoch 17/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0248 - val_binary_crossentropy: 0.0189
# Epoch 18/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0198 - val_loss: 0.0247 - val_binary_crossentropy: 0.0189
# Epoch 19/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0246 - val_binary_crossentropy: 0.0188
# Epoch 20/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0246 - val_binary_crossentropy: 0.0187
# Epoch 21/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0246 - val_binary_crossentropy: 0.0187
# Epoch 22/50
# 19/19 - 1s - loss: 0.0257 - binary_crossentropy: 0.0199 - val_loss: 0.0245 - val_binary_crossentropy: 0.0187
# Epoch 23/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0244 - val_binary_crossentropy: 0.0186
# Epoch 24/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0244 - val_binary_crossentropy: 0.0186
# Epoch 25/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0244 - val_binary_crossentropy: 0.0185
# Epoch 26/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0197 - val_loss: 0.0243 - val_binary_crossentropy: 0.0185
# Epoch 27/50
# 19/19 - 1s - loss: 0.0256 - binary_crossentropy: 0.0198 - val_loss: 0.0243 - val_binary_crossentropy: 0.0184
# Epoch 28/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0197 - val_loss: 0.0242 - val_binary_crossentropy: 0.0184
# Epoch 29/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0195 - val_loss: 0.0242 - val_binary_crossentropy: 0.0183
# Epoch 30/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0195 - val_loss: 0.0241 - val_binary_crossentropy: 0.0183
# Epoch 31/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0195 - val_loss: 0.0242 - val_binary_crossentropy: 0.0183
# Epoch 32/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0195 - val_loss: 0.0240 - val_binary_crossentropy: 0.0182
# Epoch 33/50
# 19/19 - 1s - loss: 0.0255 - binary_crossentropy: 0.0196 - val_loss: 0.0240 - val_binary_crossentropy: 0.0181
# Epoch 34/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0195 - val_loss: 0.0240 - val_binary_crossentropy: 0.0181
# Epoch 35/50
# 19/19 - 1s - loss: 0.0254 - binary_crossentropy: 0.0195 - val_loss: 0.0239 - val_binary_crossentropy: 0.0181
# Epoch 36/50
# 19/19 - 1s - loss: 0.0253 - binary_crossentropy: 0.0194 - val_loss: 0.0239 - val_binary_crossentropy: 0.0180
# Epoch 37/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0194 - val_loss: 0.0238 - val_binary_crossentropy: 0.0180
# Epoch 38/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0193 - val_loss: 0.0238 - val_binary_crossentropy: 0.0179
# Epoch 39/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0193 - val_loss: 0.0238 - val_binary_crossentropy: 0.0180
# Epoch 40/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0193 - val_loss: 0.0238 - val_binary_crossentropy: 0.0179
# Epoch 41/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0193 - val_loss: 0.0238 - val_binary_crossentropy: 0.0179
# Epoch 42/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0193 - val_loss: 0.0237 - val_binary_crossentropy: 0.0178
# Epoch 43/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0193 - val_loss: 0.0237 - val_binary_crossentropy: 0.0178
# Epoch 44/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0193 - val_loss: 0.0236 - val_binary_crossentropy: 0.0178
# Epoch 45/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0192 - val_loss: 0.0236 - val_binary_crossentropy: 0.0178
# Epoch 46/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0192 - val_loss: 0.0236 - val_binary_crossentropy: 0.0178
# Epoch 47/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0193 - val_loss: 0.0236 - val_binary_crossentropy: 0.0178
# Epoch 48/50
# 19/19 - 1s - loss: 0.0252 - binary_crossentropy: 0.0194 - val_loss: 0.0236 - val_binary_crossentropy: 0.0177
# Epoch 49/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0192 - val_loss: 0.0236 - val_binary_crossentropy: 0.0177
# Epoch 50/50
# 19/19 - 1s - loss: 0.0251 - binary_crossentropy: 0.0192 - val_loss: 0.0235 - val_binary_crossentropy: 0.0177
# [I 2020-11-24 15:25:17,443] Trial 1 finished with value: 0.01744356453303943 and parameters: {'activation': 'relu', 'denses': [1024, 1024, 1024, 1024], 'drop_rate0': 0.6018476220820881, 'drop_rate1': 0.7613234424836193, 'drop_rate2': 0.7077865500116103, 'drop_rate3': 0.3879641101593651, 'drop_rate4': 0.5147288957437228}. Best is trial 1 with value: 0.01744356453303943.
# oof_score: 0.01744356453303943
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# params: {'activation': 'relu', 'denses': [2048, 1792, 1536, 1280], 'drop_rates': [0.33774632823789535, 0.5206483453682103, 0.7483772147475398, 0.47432288479219303, 0.4584191403108251]}
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [512, 448, 384, 320] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [1024, 896, 768, 640] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [2048, 1792, 1536, 1280] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [2560, 2048, 1524, 1012] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [512, 512, 512, 512] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\distributions.py:404: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [1024, 1024, 1024, 1024] which is of type list.
#   warnings.warn(message)
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass shuffle=True, random_state=0 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# Epoch 1/50
# 19/19 - 2s - loss: 0.2539 - binary_crossentropy: 0.2511 - val_loss: 0.1374 - val_binary_crossentropy: 0.1244
# Epoch 2/50
# 19/19 - 2s - loss: 0.0316 - binary_crossentropy: 0.0237 - val_loss: 0.0554 - val_binary_crossentropy: 0.0449
# Epoch 3/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     336         try:
#     337             if n_jobs == 1:
# --> 338                 self._optimize_sequential(
#     339                     func, n_trials, timeout, catch, callbacks, gc_after_trial, None
#     340                 )
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\study.py in _optimize_sequential(self, func, n_trials, timeout, catch, callbacks, gc_after_trial, time_start)
#     745                     break
#     746
# --> 747             self._run_trial_and_callbacks(func, catch, callbacks, gc_after_trial)
#     748
#     749             self._progress_bar.update((datetime.datetime.now() - time_start).total_seconds())
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\study.py in _run_trial_and_callbacks(self, func, catch, callbacks, gc_after_trial)
#     774     ) -> None:
#     775
# --> 776         trial = self._run_trial(func, catch, gc_after_trial)
#     777         if callbacks is not None:
#     778             frozen_trial = copy.deepcopy(self._storage.get_trial(trial._trial_id))
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\optuna\study.py in _run_trial(self, func, catch, gc_after_trial)
#     797
#     798         try:
# --> 799             result = func(trial)
#     800         except exceptions.TrialPruned as e:
#     801             message = "Trial {} pruned. {}".format(trial_number, str(e))
#
# <ipython-input-4-f177b51da2e5> in objective(trial)
#      25     print(f"params: {params}")
#      26
# ---> 27     oof_score, Y_pred = moa_MLPs_funcs.train_and_evaluate(model_type="4l", params=params)
#      28
#      29     return oof_score
#
# ~\jupyter_notebook\poetry_work\tfgpu\01_MoA_compe\notebook\MLP_for_ensemble\20201124\moa_MLPs_funcs.py in train_and_evaluate(model_type, params)
#     765                     model_path, factor=factor, patience=patience
#     766                 )
# --> 767                 history = model.fit(
#     768                     generator,
#     769                     callbacks=callbacks,
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1841       `args` and `kwargs`.
#    1842     """
# -> 1843     return self._call_flat(
#    1844         [t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1845          if isinstance(t, (ops.Tensor,
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1921         and executing_eagerly):
#    1922       # No tape is watching; skip to running the function.
# -> 1923       return self._build_call_outputs(self._inference_function.call(
#    1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543       with _InterpolateFunctionError(self):
#     544         if cancellation_manager is None:
# --> 545           outputs = execute.execute(
#     546               str(self.signature.name),
#     547               num_outputs=self._num_outputs,
#
# c:\users\81908\appdata\local\pypoetry\cache\virtualenvs\tfgpu-ehdmne1y-py3.8\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
